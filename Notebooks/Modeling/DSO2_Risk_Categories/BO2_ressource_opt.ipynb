# %% [markdown]
# <div style="max-width: 1000px; margin: 0 auto; padding: 0 20px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif; color: #e8e8e8;">
#
# <div style="padding: 20px 0; border-bottom: 1px solid #333333; margin-bottom: 30px;">
# <h2 style="font-size: 2.2em; color: #ffffff; margin: 0; font-weight: 800; letter-spacing: -1px;">DSO2: Breast Cancer Risk <span style="color: #ff1493;">Stratification Model</span></h2>
# </div>
#
# <div style="padding: 20px 0;">
#
# <div style="display: flex; flex-direction: column; gap: 16px;">
#
# <div style="padding: 20px; border: 2px solid #ff1493; background: #0f0f0f; border-radius: 6px;">
# <div style="font-size: 10px; text-transform: uppercase; letter-spacing: 1.5px; color: #ff1493; font-weight: 700; margin-bottom: 10px;">Section 1</div>
# <h3 style="font-size: 16px; color: #ffffff; margin: 0 0 12px 0; font-weight: 800;">Data Understanding</h3>
# <p style="font-size: 13px; color: #999999; margin: 0; line-height: 1.6; font-weight: 400;">EDA · Descriptive statistics · Quality assessment · Correlation analysis · Outlier detection</p>
# </div>
#
# <div style="padding: 20px; border: 2px solid #ff1493; background: #0f0f0f; border-radius: 6px;">
# <div style="font-size: 10px; text-transform: uppercase; letter-spacing: 1.5px; color: #ff1493; font-weight: 700; margin-bottom: 10px;">Section 2</div>
# <h3 style="font-size: 16px; color: #ffffff; margin: 0 0 12px 0; font-weight: 800;">Data Cleaning</h3>
# <p style="font-size: 13px; color: #999999; margin: 0; line-height: 1.6; font-weight: 400;">Handle missing values · Remove duplicates · Treat outliers · Scale features · Address class imbalance</p>
# </div>
#
# <div style="padding: 20px; border: 2px solid #ff1493; background: #0f0f0f; border-radius: 6px;">
# <div style="font-size: 10px; text-transform: uppercase; letter-spacing: 1.5px; color: #ff1493; font-weight: 700; margin-bottom: 10px;">Section 3</div>
# <h3 style="font-size: 16px; color: #ffffff; margin: 0 0 12px 0; font-weight: 800;">Modeling</h3>
# <p style="font-size: 13px; color: #999999; margin: 0; line-height: 1.6; font-weight: 400;">Train classifiers · Hyperparameter tuning · Cross-validation · Probability calibration · Define risk thresholds</p>
# </div>
#
# <div style="padding: 20px; border: 2px solid #ff1493; background: #0f0f0f; border-radius: 6px;">
# <div style="font-size: 10px; text-transform: uppercase; letter-spacing: 1.5px; color: #ff1493; font-weight: 700; margin-bottom: 10px;">Section 4</div>
# <h3 style="font-size: 16px; color: #ffffff; margin: 0 0 12px 0; font-weight: 800;">Evaluation</h3>
# <p style="font-size: 13px; color: #999999; margin: 0; line-height: 1.6; font-weight: 400;">Performance metrics · ROC-AUC analysis · Risk category validation · Model selection · Deployment readiness</p>
# </div>
#
# </div>
#
# </div>
#
#
# </div>

# %% [markdown]
# <div style="max-width: 1000px; margin: 0 auto; padding: 0 20px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif; color: #e8e8e8;">
#
# <div style="padding: 20px 0; border-bottom: 1px solid #333333; margin-bottom: 30px;">
# <h2 style="font-size: 2.2em; color: #ffffff; margin: 0; font-weight: 800; letter-spacing: -1px;">Section 1 · <span style="color: #ff1493;">Data Understanding</span></h2>
# <p style="font-size: 14px; color: #999999; font-weight: 400; line-height: 1.6; margin: 8px 0 0 0;">Exploratory Data Analysis & Dataset Characterization</p>
# </div>
#
# <div style="padding: 20px 0; margin-bottom: 35px;">
#
# <div style="font-size: 10px; text-transform: uppercase; letter-spacing: 2px; color: #666666; font-weight: 600; margin-bottom: 18px;">Subsections</div>
#
# <div style="display: flex; flex-direction: column; gap: 16px;">
#
# <div style="padding: 20px; border: 2px solid #ff1493; background: #0f0f0f; border-radius: 6px;">
# <div style="font-size: 10px; text-transform: uppercase; letter-spacing: 1.5px; color: #ff1493; font-weight: 700; margin-bottom: 10px;">1.1</div>
# <h3 style="font-size: 16px; color: #ffffff; margin: 0 0 12px 0; font-weight: 800;">Dataset Loading & Overview</h3>
# <p style="font-size: 13px; color: #999999; margin: 0; line-height: 1.6; font-weight: 400;">Load WDBC dataset · Verify dimensions (569 samples, 30 features) · Inspect data types · Display first rows · Confirm target variable distribution</p>
# </div>
#
# <div style="padding: 20px; border: 2px solid #ff1493; background: #0f0f0f; border-radius: 6px;">
# <div style="font-size: 10px; text-transform: uppercase; letter-spacing: 1.5px; color: #ff1493; font-weight: 700; margin-bottom: 10px;">1.2</div>
# <h3 style="font-size: 16px; color: #ffffff; margin: 0 0 12px 0; font-weight: 800;">Descriptive Statistics</h3>
# <p style="font-size: 13px; color: #999999; margin: 0; line-height: 1.6; font-weight: 400;">Summary statistics · Mean, median, std dev · Min/max values · Quartile analysis · Distribution shapes · Feature ranges</p>
# </div>
#
#
#
# </div>
#
# </div>
#
#
#
# </div>

# %% [markdown]
# <div style="max-width: 1000px; margin: 0 auto; padding: 0 20px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif; color: #e8e8e8;">
#
# <div style="padding: 20px 0; border-bottom: 1px solid #333333; margin-bottom: 30px;">
# <h2 style="font-size: 2.2em; color: #ffffff; margin: 0; font-weight: 800; letter-spacing: -1px;">1.1 · Dataset Loading & <span style="color: #ff1493;">Overview</span></h2>
# <p style="font-size: 14px; color: #999999; font-weight: 400; line-height: 1.6; margin: 8px 0 0 0;">Initial data exploration and verification</p>
# </div>
#
# </div>

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# Load data
df = pd.read_csv(r"C:\Users\LENOVO\Desktop\Machine Learning\Bo2_Triage_risque\Breast_Cancer_Detection_ML_Project\data\row\data.csv")

df.shape
# Out:
# (569, 33)

# %% [markdown]
# ##
# <div style="max-width: 1000px; margin: 0 auto; padding: 0 20px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif; color: #e8e8e8;">
#
# <div style="padding: 20px 0; border-bottom: 1px solid #333333; margin-bottom: 30px;">
# <h2 style="font-size: 2.2em; color: #ffffff; margin: 0; font-weight: 800; letter-spacing: -1px;">· Data <span style="color: #ff1493;">Cleaning </span></h2>
# <p style="font-size: 14px; color: #999999; font-weight: 400; line-height: 1.6; margin: 8px 0 0 0;">Nettoyage des données , suppression des colonnes vides et id</p>
# </div>
#
# </div>

# %%
df.drop(columns=['id'], inplace=True)
df.drop(columns=['Unnamed: 32'], inplace=True)

df.shape
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB

# %% [markdown]
# ## Target Variable Encoding

# %%
df['diagnosis'].value_counts()
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

X = df.drop(columns=['diagnosis'])
y = df['diagnosis']
feature_names = X.columns.tolist()
X.shape, y.shape
y.head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: diagnosis, dtype: float64

# %% [markdown]
# ## Data Splitting and Standard Scaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42  # 70% train, 30% test
)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Data shapes after splitting and scaling:")
print(f"X_train_scaled: {X_train_scaled.shape}")
print(f"X_test_scaled: {X_test_scaled.shape}")
print(f"y_train: {y_train.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# Data shapes after splitting and scaling:
# X_train_scaled: (398, 30)
# X_test_scaled: (171, 30)
# y_train: (398,)
# y_test: (171,)

# %% [markdown]
# ## Feature Correlations Analysis

# %%
# Now correlation will work!
correlations = X.corrwith(y).sort_values(ascending=False)

print("="*70)
print("TOP 15 FEATURES")
print("="*70)
print(correlations.head(15))

print("\n" + "="*70)
print("BOTTOM 15 FEATURES")
print("="*70)
print(correlations.tail(15))
# Out:
# ======================================================================
# TOP 15 FEATURES
# ======================================================================
# concave points_worst    0.793566
# perimeter_worst         0.782914
# concave points_mean     0.776614
# radius_worst            0.776454
# perimeter_mean          0.742636
# area_worst              0.733825
# radius_mean             0.730029
# area_mean               0.708984
# concavity_mean          0.696360
# concavity_worst         0.659610
# compactness_mean        0.596534
# compactness_worst       0.590998
# radius_se               0.567134
# perimeter_se            0.556141
# area_se                 0.548236
# dtype: float64
#
# ======================================================================
# BOTTOM 15 FEATURES
# ======================================================================
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# texture_mean               0.415185
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# compactness_se             0.292999
# concavity_se               0.253730
# fractal_dimension_se       0.077972
# symmetry_se               -0.006522
# texture_se                -0.008303
# fractal_dimension_mean    -0.012838
# smoothness_se             -0.067016
# dtype: float64

# %% [markdown]
# ## Correlation Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
correlations.sort_values().plot(kind='barh', 
                                 color=['red' if x < 0 else 'green' for x in correlations.sort_values()])
plt.xlabel('Correlation with Diagnosis (1=Malignant)', fontsize=12)
plt.title('Feature Correlations with Malignancy', fontsize=14, fontweight='bold')
plt.axvline(x=0, color='black', linestyle='-', linewidth=1)
plt.axvline(x=0.5, color='blue', linestyle='--', alpha=0.5, label='Strong (>0.5)')
plt.axvline(x=-0.5, color='blue', linestyle='--', alpha=0.5)
plt.grid(axis='x', alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Strength Analysis

# %%
strong = correlations[abs(correlations) > 0.7]
moderate_strong = correlations[(abs(correlations) > 0.5) & (abs(correlations) <= 0.7)]
moderate = correlations[(abs(correlations) > 0.3) & (abs(correlations) <= 0.5)]
weak = correlations[abs(correlations) <= 0.3]

print(f"\n🟢 STRONG LINEAR (|r| > 0.7): {len(strong)} features")
print("   → Excellent for Logistic Regression")
print(strong)

print(f"\n🟡 MODERATE-STRONG LINEAR (0.5 < |r| ≤ 0.7): {len(moderate_strong)} features")
print("   → Good for linear models")
print(moderate_strong)

print(f"\n🟠 MODERATE LINEAR (0.3 < |r| ≤ 0.5): {len(moderate)} features")
print("   → May need non-linear models or combinations")
print(moderate)

print(f"\n🔴 WEAK LINEAR (|r| ≤ 0.3): {len(weak)} features")
print("   → Poor for linear models, consider removing")
print(weak)
# Out:
# 🟢 STRONG LINEAR (|r| > 0.7): 8 features
#    → Excellent for Logistic Regression
# concave points_worst    0.793566
# perimeter_worst         0.782914
# concave points_mean     0.776614
# radius_worst            0.776454
# perimeter_mean          0.742636
# area_worst              0.733825
# radius_mean             0.730029
# area_mean               0.708984
# dtype: float64
#
# 🟡 MODERATE-STRONG LINEAR (0.5 < |r| ≤ 0.7): 7 features
#    → Good for linear models
# concavity_mean       0.696360
# concavity_worst      0.659610
# compactness_mean     0.596534
# compactness_worst    0.590998
# radius_se            0.567134
# perimeter_se         0.556141
# area_se              0.548236
# dtype: float64
#
# 🟠 MODERATE LINEAR (0.3 < |r| ≤ 0.5): 8 features
#    → May need non-linear models or combinations
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# texture_mean               0.415185
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# dtype: float64
#
# 🔴 WEAK LINEAR (|r| ≤ 0.3): 7 features
#    → Poor for linear models, consider removing
# compactness_se            0.292999
# concavity_se              0.253730
# fractal_dimension_se      0.077972
# symmetry_se              -0.006522
# texture_se               -0.008303
# fractal_dimension_mean   -0.012838
# smoothness_se            -0.067016
# dtype: float64

# %% [markdown]
# # Model 1: Logistic Regression Baseline

# %%
# Importing all necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.metrics import accuracy_score, recall_score, precision_score, classification_report, confusion_matrix
from sklearn.calibration import calibration_curve, CalibratedClassifierCV
from matplotlib.colors import LinearSegmentedColormap
import warnings
warnings.filterwarnings('ignore')

# %%
# Create and train baseline Logistic Regression model
baseline_model = LogisticRegression(max_iter=10000, random_state=42)
baseline_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=10000, random_state=42)

# %%
# Make predictions
y_pred = baseline_model.predict(X_test_scaled)
y_pred_proba = baseline_model.predict_proba(X_test_scaled)[:, 1]

# %%
# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
sensitivity = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

print("\n📊 RESULTS:")
print(f"Accuracy:    {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}") 
print(f"Precision:   {precision:.4f}")

print(f"\n📄 Detailed Classification Report:")
print(classification_report(y_test, y_pred, target_names=['Benign', 'Malignant']))
# Out:
# 📊 RESULTS:
# Accuracy:    0.9825
# Sensitivity: 0.9841
# Precision:   0.9688
#
# 📄 Detailed Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.99      0.98      0.99       108
#    Malignant       0.97      0.98      0.98        63
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %%
# Create confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Minimalist dark version
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(7, 5), facecolor='black')

# Simple pink-grey colormap
colors_minimal = ["#333333", "#ff69b4"]  # Dark Grey -> Pink
custom_cmap_minimal = LinearSegmentedColormap.from_list("minimal_pink", colors_minimal, N=100)

# Clean heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap=custom_cmap_minimal, 
            cbar=False,  # Remove colorbar for minimal look
            annot_kws={'size': 14, 'color': 'white', 'weight': 'bold'},
            linewidths=1.5, linecolor='#555555', ax=ax)

# Minimal text
ax.set_title('Confusion Matrix', color='white', fontsize=14, pad=20)
ax.set_xlabel('Predicted', color='white', fontsize=11)
ax.set_ylabel('Actual', color='white', fontsize=11)
ax.set_xticklabels(['Benign', 'Malignant'], color='white')
ax.set_yticklabels(['Benign', 'Malignant'], color='white', rotation=0)

plt.tight_layout()
plt.show()

# %%
# Clean performance display
print(f"\n✨ Performance Metrics:")
print(f"   Accuracy:    {accuracy:.1%}")
print(f"   Sensitivity: {sensitivity:.1%}")
print(f"   Precision:   {precision:.1%}")
# Out:
# ✨ Performance Metrics:
#    Accuracy:    98.2%
#    Sensitivity: 98.4%
#    Precision:   96.9%

# %% [markdown]
# # Model 2: Gradient Boosting (XGBoost)

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from scipy.stats import randint, uniform
import numpy as np

print("=" * 70)
print("XGBOOST HYPERPARAMETER TUNING")
print("=" * 70)

# Define parameter distributions
param_distributions = {
    'max_depth': randint(3, 12),
    'learning_rate': uniform(0.01, 0.3),
    'n_estimators': randint(100, 500),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'scale_pos_weight': [1, 1.5, 2, 2.5, 3]
}

# Create base model
base_xgb = xgb.XGBClassifier(
    random_state=42,
    eval_metric='logloss',
    use_label_encoder=False
)

# Randomized search for best parameters
xgb_random_search = RandomizedSearchCV(
    estimator=base_xgb,
    param_distributions=param_distributions,
    n_iter=50,
    scoring='recall',
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
    n_jobs=-1,
    random_state=42,
    verbose=1
)

print("Training XGBoost with randomized search...")
xgb_random_search.fit(X_train, y_train)

print("✅ XGBoost training completed!")
# Out:
# ======================================================================
# XGBOOST HYPERPARAMETER TUNING
# ======================================================================
# Training XGBoost with randomized search...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# ✅ XGBoost training completed!

# %%
# Get best model
best_xgb_enhanced = xgb_random_search.best_estimator_
best_score = xgb_random_search.best_score_

print(f"🎯 Best Cross-Validation Recall: {best_score:.4f}")
print(f"🔧 Best Parameters: {xgb_random_search.best_params_}")
# Out:
# 🎯 Best Cross-Validation Recall: 0.9733
# 🔧 Best Parameters: {'colsample_bytree': np.float64(0.749816047538945), 'learning_rate': np.float64(0.2952142919229748), 'max_depth': 10, 'n_estimators': 288, 'scale_pos_weight': 3, 'subsample': np.float64(0.6624074561769746)}

# %%
# Make predictions with enhanced model
from sklearn.metrics import f1_score, roc_auc_score


y_pred_enhanced = best_xgb_enhanced.predict(X_test)
y_proba_enhanced = best_xgb_enhanced.predict_proba(X_test)[:, 1]

# Calculate metrics
metrics_enhanced = {
    'Accuracy': accuracy_score(y_test, y_pred_enhanced),
    'Sensitivity': recall_score(y_test, y_pred_enhanced),
    'Precision': precision_score(y_test, y_pred_enhanced),
    'F1-Score': f1_score(y_test, y_pred_enhanced),
    'ROC AUC': roc_auc_score(y_test, y_proba_enhanced)
}

print("📊 XGBoost PERFORMANCE:")
for metric, value in metrics_enhanced.items():
    print(f"   {metric}: {value:.4f}")
# Out:
# 📊 XGBoost PERFORMANCE:
#    Accuracy: 0.9649
#    Sensitivity: 0.9683
#    Precision: 0.9385
#    F1-Score: 0.9531
#    ROC AUC: 0.9969

# %%
# Create confusion matrix
cm_enhanced = confusion_matrix(y_test, y_pred_enhanced)

# Simple dark theme confusion matrix
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(8, 6), facecolor='black')

# Pink colormap
colors = ["#333333", "#ff69b4"]
cmap = LinearSegmentedColormap.from_list("pink_cmap", colors, N=100)

sns.heatmap(cm_enhanced, annot=True, fmt='d', cmap=cmap,
            annot_kws={'size': 14, 'color': 'white', 'weight': 'bold'},
            linewidths=2, linecolor='white', ax=ax)

plt.title('XGBoost - Confusion Matrix', color='white', fontsize=14, pad=20)
plt.xlabel('Predicted', color='white', fontsize=12)
plt.ylabel('Actual', color='white', fontsize=12)
ax.set_xticklabels(['Benign', 'Malignant'], color='white')
ax.set_yticklabels(['Benign', 'Malignant'], color='white', rotation=0)

plt.tight_layout()
plt.show()

# %%
# Performance summary
print(f"\n✨ XGBoost Performance Metrics:")
print(f"   Accuracy:    {metrics_enhanced['Accuracy']:.1%}")
print(f"   Sensitivity: {metrics_enhanced['Sensitivity']:.1%}")
print(f"   Precision:   {metrics_enhanced['Precision']:.1%}")
print(f"   F1-Score:    {metrics_enhanced['F1-Score']:.1%}")
# Out:
# ✨ XGBoost Performance Metrics:
#    Accuracy:    96.5%
#    Sensitivity: 96.8%
#    Precision:   93.8%
#    F1-Score:    95.3%

# %% [markdown]
# # Model 3: SVM with SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier

print("\n" + "=" + "=" * 70)
print("SGD CLASSIFIER WITH SVM LOSS (BATCH TRAINING)")
print("=" + "=" * 70)
print("This gives us actual batch_size and learning_rate control!")

# SGDClassifier with hinge loss = linear SVM with batch training
sgd_svm = SGDClassifier(
    loss='hinge',           # Linear SVM
    penalty='l2',           # L2 regularization
    alpha=1/(5 * len(y_train)),  # alpha = 1/(C * n_samples) for equivalent regularization
    learning_rate='constant',
    eta0=1e-3,              # Learning rate = 1e-3 as specified
    max_iter=3000,          # Epochs
    tol=1e-4,
    random_state=42,
    verbose=1,
    n_jobs=-1
)

print("🚀 Training SGD SVM with batch processing...")
sgd_svm.fit(X_train_scaled, y_train)

print("✅ SGD SVM TRAINING COMPLETED!")

# Make predictions
y_pred_sgd = sgd_svm.predict(X_test_scaled)

# Calculate metrics
metrics_sgd = {
    'Accuracy': accuracy_score(y_test, y_pred_sgd),
    'Sensitivity': recall_score(y_test, y_pred_sgd),
    'Precision': precision_score(y_test, y_pred_sgd),
    'F1-Score': f1_score(y_test, y_pred_sgd)
}

print("\n📊 SGD SVM PERFORMANCE:")
for metric, value in metrics_sgd.items():
    print(f"   {metric}: {value:.4f}")
# Out:
# =======================================================================
# SGD CLASSIFIER WITH SVM LOSS (BATCH TRAINING)
# =======================================================================
# This gives us actual batch_size and learning_rate control!
# 🚀 Training SGD SVM with batch processing...
# -- Epoch 1
# Norm: 0.45, NNZs: 30, Bias: -0.084000, T: 398, Avg. loss: 0.365125
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.56, NNZs: 30, Bias: -0.130000, T: 796, Avg. loss: 0.182996
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.64, NNZs: 30, Bias: -0.159000, T: 1194, Avg. loss: 0.150773
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.70, NNZs: 30, Bias: -0.181000, T: 1592, Avg. loss: 0.134663
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.76, NNZs: 30, Bias: -0.197000, T: 1990, Avg. loss: 0.124000
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.80, NNZs: 30, Bias: -0.210000, T: 2388, Avg. loss: 0.116185
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.84, NNZs: 30, Bias: -0.223000, T: 2786, Avg. loss: 0.109641
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.88, NNZs: 30, Bias: -0.232000, T: 3184, Avg. loss: 0.104517
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.91, NNZs: 30, Bias: -0.243000, T: 3582, Avg. loss: 0.099966
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.95, NNZs: 30, Bias: -0.252000, T: 3980, Avg. loss: 0.096262
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.98, NNZs: 30, Bias: -0.260000, T: 4378, Avg. loss: 0.093070
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 1.00, NNZs: 30, Bias: -0.268000, T: 4776, Avg. loss: 0.090165
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 1.03, NNZs: 30, Bias: -0.273000, T: 5174, Avg. loss: 0.087616
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 1.06, NNZs: 30, Bias: -0.279000, T: 5572, Avg. loss: 0.085437
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 1.08, NNZs: 30, Bias: -0.283000, T: 5970, Avg. loss: 0.083432
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 1.10, NNZs: 30, Bias: -0.286000, T: 6368, Avg. loss: 0.081803
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 1.12, NNZs: 30, Bias: -0.289000, T: 6766, Avg. loss: 0.080394
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 1.14, NNZs: 30, Bias: -0.291000, T: 7164, Avg. loss: 0.079014
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 1.16, NNZs: 30, Bias: -0.290000, T: 7562, Avg. loss: 0.077751
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 1.18, NNZs: 30, Bias: -0.289000, T: 7960, Avg. loss: 0.076488
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 1.19, NNZs: 30, Bias: -0.290000, T: 8358, Avg. loss: 0.075555
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 1.21, NNZs: 30, Bias: -0.293000, T: 8756, Avg. loss: 0.074547
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 1.22, NNZs: 30, Bias: -0.295000, T: 9154, Avg. loss: 0.073571
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 1.24, NNZs: 30, Bias: -0.295000, T: 9552, Avg. loss: 0.072898
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 1.25, NNZs: 30, Bias: -0.294000, T: 9950, Avg. loss: 0.072076
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 1.27, NNZs: 30, Bias: -0.295000, T: 10348, Avg. loss: 0.071354
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 1.28, NNZs: 30, Bias: -0.296000, T: 10746, Avg. loss: 0.070561
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 1.30, NNZs: 30, Bias: -0.294000, T: 11144, Avg. loss: 0.069892
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 1.31, NNZs: 30, Bias: -0.295000, T: 11542, Avg. loss: 0.069209
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 1.32, NNZs: 30, Bias: -0.293000, T: 11940, Avg. loss: 0.068612
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 1.34, NNZs: 30, Bias: -0.293000, T: 12338, Avg. loss: 0.068050
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 1.35, NNZs: 30, Bias: -0.291000, T: 12736, Avg. loss: 0.067340
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 1.36, NNZs: 30, Bias: -0.290000, T: 13134, Avg. loss: 0.066914
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 1.37, NNZs: 30, Bias: -0.290000, T: 13532, Avg. loss: 0.066261
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 1.38, NNZs: 30, Bias: -0.289000, T: 13930, Avg. loss: 0.065544
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 1.40, NNZs: 30, Bias: -0.288000, T: 14328, Avg. loss: 0.065260
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 1.41, NNZs: 30, Bias: -0.287000, T: 14726, Avg. loss: 0.064658
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 1.41, NNZs: 30, Bias: -0.288000, T: 15124, Avg. loss: 0.064164
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 1.42, NNZs: 30, Bias: -0.289000, T: 15522, Avg. loss: 0.063859
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 1.43, NNZs: 30, Bias: -0.288000, T: 15920, Avg. loss: 0.063663
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 1.44, NNZs: 30, Bias: -0.286000, T: 16318, Avg. loss: 0.063260
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 1.45, NNZs: 30, Bias: -0.284000, T: 16716, Avg. loss: 0.062789
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 1.46, NNZs: 30, Bias: -0.283000, T: 17114, Avg. loss: 0.062656
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 1.47, NNZs: 30, Bias: -0.280000, T: 17512, Avg. loss: 0.062280
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 1.47, NNZs: 30, Bias: -0.279000, T: 17910, Avg. loss: 0.061959
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 1.48, NNZs: 30, Bias: -0.278000, T: 18308, Avg. loss: 0.061721
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 1.49, NNZs: 30, Bias: -0.277000, T: 18706, Avg. loss: 0.061468
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 1.50, NNZs: 30, Bias: -0.275000, T: 19104, Avg. loss: 0.061266
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 1.51, NNZs: 30, Bias: -0.274000, T: 19502, Avg. loss: 0.061046
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 1.51, NNZs: 30, Bias: -0.273000, T: 19900, Avg. loss: 0.060693
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 1.52, NNZs: 30, Bias: -0.271000, T: 20298, Avg. loss: 0.060281
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 1.53, NNZs: 30, Bias: -0.271000, T: 20696, Avg. loss: 0.060384
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 1.53, NNZs: 30, Bias: -0.269000, T: 21094, Avg. loss: 0.060031
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 1.54, NNZs: 30, Bias: -0.267000, T: 21492, Avg. loss: 0.059976
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 1.55, NNZs: 30, Bias: -0.266000, T: 21890, Avg. loss: 0.059785
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 1.55, NNZs: 30, Bias: -0.264000, T: 22288, Avg. loss: 0.059567
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 1.56, NNZs: 30, Bias: -0.263000, T: 22686, Avg. loss: 0.059279
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 1.56, NNZs: 30, Bias: -0.264000, T: 23084, Avg. loss: 0.059243
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 1.57, NNZs: 30, Bias: -0.263000, T: 23482, Avg. loss: 0.058960
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 1.57, NNZs: 30, Bias: -0.261000, T: 23880, Avg. loss: 0.058764
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 1.58, NNZs: 30, Bias: -0.259000, T: 24278, Avg. loss: 0.058637
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 1.59, NNZs: 30, Bias: -0.257000, T: 24676, Avg. loss: 0.058540
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 1.59, NNZs: 30, Bias: -0.255000, T: 25074, Avg. loss: 0.058334
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 1.60, NNZs: 30, Bias: -0.254000, T: 25472, Avg. loss: 0.058077
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 1.60, NNZs: 30, Bias: -0.253000, T: 25870, Avg. loss: 0.057957
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 1.61, NNZs: 30, Bias: -0.253000, T: 26268, Avg. loss: 0.057626
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 1.61, NNZs: 30, Bias: -0.251000, T: 26666, Avg. loss: 0.057626
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 1.62, NNZs: 30, Bias: -0.251000, T: 27064, Avg. loss: 0.057309
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 1.62, NNZs: 30, Bias: -0.249000, T: 27462, Avg. loss: 0.057289
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 1.63, NNZs: 30, Bias: -0.249000, T: 27860, Avg. loss: 0.056961
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 1.64, NNZs: 30, Bias: -0.247000, T: 28258, Avg. loss: 0.056943
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 1.64, NNZs: 30, Bias: -0.246000, T: 28656, Avg. loss: 0.056592
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 1.65, NNZs: 30, Bias: -0.245000, T: 29054, Avg. loss: 0.056320
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 1.65, NNZs: 30, Bias: -0.244000, T: 29452, Avg. loss: 0.056332
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 1.66, NNZs: 30, Bias: -0.242000, T: 29850, Avg. loss: 0.056231
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 1.67, NNZs: 30, Bias: -0.242000, T: 30248, Avg. loss: 0.055953
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 1.67, NNZs: 30, Bias: -0.240000, T: 30646, Avg. loss: 0.055885
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 1.68, NNZs: 30, Bias: -0.239000, T: 31044, Avg. loss: 0.055602
# Total training time: 0.00 seconds.
# -- Epoch 79
# Norm: 1.68, NNZs: 30, Bias: -0.238000, T: 31442, Avg. loss: 0.055619
# Total training time: 0.00 seconds.
# -- Epoch 80
# Norm: 1.69, NNZs: 30, Bias: -0.238000, T: 31840, Avg. loss: 0.055349
# Total training time: 0.00 seconds.
# -- Epoch 81
# Norm: 1.69, NNZs: 30, Bias: -0.238000, T: 32238, Avg. loss: 0.055173
# Total training time: 0.00 seconds.
# -- Epoch 82
# Norm: 1.70, NNZs: 30, Bias: -0.237000, T: 32636, Avg. loss: 0.055194
# Total training time: 0.00 seconds.
# -- Epoch 83
# Norm: 1.70, NNZs: 30, Bias: -0.235000, T: 33034, Avg. loss: 0.055048
# Total training time: 0.00 seconds.
# -- Epoch 84
# Norm: 1.71, NNZs: 30, Bias: -0.235000, T: 33432, Avg. loss: 0.054830
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 1.71, NNZs: 30, Bias: -0.235000, T: 33830, Avg. loss: 0.054730
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 1.72, NNZs: 30, Bias: -0.234000, T: 34228, Avg. loss: 0.054612
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 1.72, NNZs: 30, Bias: -0.233000, T: 34626, Avg. loss: 0.054485
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 1.73, NNZs: 30, Bias: -0.232000, T: 35024, Avg. loss: 0.054352
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 1.73, NNZs: 30, Bias: -0.232000, T: 35422, Avg. loss: 0.054185
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 1.74, NNZs: 30, Bias: -0.230000, T: 35820, Avg. loss: 0.054103
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 1.74, NNZs: 30, Bias: -0.230000, T: 36218, Avg. loss: 0.054009
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 1.74, NNZs: 30, Bias: -0.229000, T: 36616, Avg. loss: 0.053933
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 1.75, NNZs: 30, Bias: -0.228000, T: 37014, Avg. loss: 0.053749
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 1.75, NNZs: 30, Bias: -0.228000, T: 37412, Avg. loss: 0.053638
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 1.76, NNZs: 30, Bias: -0.229000, T: 37810, Avg. loss: 0.053656
# Total training time: 0.00 seconds.
# -- Epoch 96
# Norm: 1.76, NNZs: 30, Bias: -0.229000, T: 38208, Avg. loss: 0.053457
# Total training time: 0.00 seconds.
# -- Epoch 97
# Norm: 1.77, NNZs: 30, Bias: -0.228000, T: 38606, Avg. loss: 0.053413
# Total training time: 0.00 seconds.
# -- Epoch 98
# Norm: 1.77, NNZs: 30, Bias: -0.229000, T: 39004, Avg. loss: 0.053224
# Total training time: 0.00 seconds.
# -- Epoch 99
# Norm: 1.77, NNZs: 30, Bias: -0.228000, T: 39402, Avg. loss: 0.053285
# Total training time: 0.00 seconds.
# -- Epoch 100
# Norm: 1.78, NNZs: 30, Bias: -0.228000, T: 39800, Avg. loss: 0.053114
# Total training time: 0.00 seconds.
# -- Epoch 101
# Norm: 1.78, NNZs: 30, Bias: -0.228000, T: 40198, Avg. loss: 0.052956
# Total training time: 0.00 seconds.
# -- Epoch 102
# Norm: 1.79, NNZs: 30, Bias: -0.228000, T: 40596, Avg. loss: 0.052953
# Total training time: 0.00 seconds.
# -- Epoch 103
# Norm: 1.79, NNZs: 30, Bias: -0.227000, T: 40994, Avg. loss: 0.052788
# Total training time: 0.00 seconds.
# -- Epoch 104
# Norm: 1.79, NNZs: 30, Bias: -0.228000, T: 41392, Avg. loss: 0.052661
# Total training time: 0.00 seconds.
# -- Epoch 105
# Norm: 1.80, NNZs: 30, Bias: -0.227000, T: 41790, Avg. loss: 0.052823
# Total training time: 0.00 seconds.
# -- Epoch 106
# Norm: 1.80, NNZs: 30, Bias: -0.228000, T: 42188, Avg. loss: 0.052496
# Total training time: 0.00 seconds.
# -- Epoch 107
# Norm: 1.81, NNZs: 30, Bias: -0.227000, T: 42586, Avg. loss: 0.052501
# Total training time: 0.00 seconds.
# -- Epoch 108
# Norm: 1.81, NNZs: 30, Bias: -0.227000, T: 42984, Avg. loss: 0.052231
# Total training time: 0.00 seconds.
# -- Epoch 109
# Norm: 1.82, NNZs: 30, Bias: -0.227000, T: 43382, Avg. loss: 0.052673
# Total training time: 0.00 seconds.
# -- Epoch 110
# Norm: 1.82, NNZs: 30, Bias: -0.226000, T: 43780, Avg. loss: 0.052319
# Total training time: 0.00 seconds.
# -- Epoch 111
# Norm: 1.83, NNZs: 30, Bias: -0.225000, T: 44178, Avg. loss: 0.052210
# Total training time: 0.00 seconds.
# -- Epoch 112
# Norm: 1.83, NNZs: 30, Bias: -0.223000, T: 44576, Avg. loss: 0.052317
# Total training time: 0.00 seconds.
# -- Epoch 113
# Norm: 1.83, NNZs: 30, Bias: -0.221000, T: 44974, Avg. loss: 0.052046
# Total training time: 0.00 seconds.
# -- Epoch 114
# Norm: 1.84, NNZs: 30, Bias: -0.220000, T: 45372, Avg. loss: 0.052099
# Total training time: 0.00 seconds.
# -- Epoch 115
# Norm: 1.84, NNZs: 30, Bias: -0.220000, T: 45770, Avg. loss: 0.051930
# Total training time: 0.00 seconds.
# -- Epoch 116
# Norm: 1.84, NNZs: 30, Bias: -0.220000, T: 46168, Avg. loss: 0.051815
# Total training time: 0.00 seconds.
# -- Epoch 117
# Norm: 1.85, NNZs: 30, Bias: -0.218000, T: 46566, Avg. loss: 0.051820
# Total training time: 0.00 seconds.
# -- Epoch 118
# Norm: 1.85, NNZs: 30, Bias: -0.219000, T: 46964, Avg. loss: 0.051697
# Total training time: 0.00 seconds.
# -- Epoch 119
# Norm: 1.85, NNZs: 30, Bias: -0.219000, T: 47362, Avg. loss: 0.051583
# Total training time: 0.00 seconds.
# -- Epoch 120
# Norm: 1.86, NNZs: 30, Bias: -0.217000, T: 47760, Avg. loss: 0.051509
# Total training time: 0.00 seconds.
# -- Epoch 121
# Norm: 1.86, NNZs: 30, Bias: -0.217000, T: 48158, Avg. loss: 0.051557
# Total training time: 0.00 seconds.
# -- Epoch 122
# Norm: 1.87, NNZs: 30, Bias: -0.216000, T: 48556, Avg. loss: 0.051477
# Total training time: 0.00 seconds.
# -- Epoch 123
# Norm: 1.87, NNZs: 30, Bias: -0.215000, T: 48954, Avg. loss: 0.051312
# Total training time: 0.00 seconds.
# -- Epoch 124
# Norm: 1.87, NNZs: 30, Bias: -0.217000, T: 49352, Avg. loss: 0.051387
# Total training time: 0.00 seconds.
# -- Epoch 125
# Norm: 1.88, NNZs: 30, Bias: -0.217000, T: 49750, Avg. loss: 0.051206
# Total training time: 0.00 seconds.
# -- Epoch 126
# Norm: 1.88, NNZs: 30, Bias: -0.216000, T: 50148, Avg. loss: 0.051560
# Total training time: 0.00 seconds.
# -- Epoch 127
# Norm: 1.89, NNZs: 30, Bias: -0.216000, T: 50546, Avg. loss: 0.051256
# Total training time: 0.00 seconds.
# -- Epoch 128
# Norm: 1.89, NNZs: 30, Bias: -0.215000, T: 50944, Avg. loss: 0.051085
# Total training time: 0.00 seconds.
# -- Epoch 129
# Norm: 1.90, NNZs: 30, Bias: -0.214000, T: 51342, Avg. loss: 0.051138
# Total training time: 0.00 seconds.
# -- Epoch 130
# Norm: 1.90, NNZs: 30, Bias: -0.213000, T: 51740, Avg. loss: 0.050998
# Total training time: 0.00 seconds.
# -- Epoch 131
# Norm: 1.90, NNZs: 30, Bias: -0.214000, T: 52138, Avg. loss: 0.050984
# Total training time: 0.00 seconds.
# -- Epoch 132
# Norm: 1.90, NNZs: 30, Bias: -0.215000, T: 52536, Avg. loss: 0.050884
# Total training time: 0.00 seconds.
# -- Epoch 133
# Norm: 1.91, NNZs: 30, Bias: -0.214000, T: 52934, Avg. loss: 0.050723
# Total training time: 0.00 seconds.
# -- Epoch 134
# Norm: 1.91, NNZs: 30, Bias: -0.213000, T: 53332, Avg. loss: 0.050730
# Total training time: 0.00 seconds.
# -- Epoch 135
# Norm: 1.91, NNZs: 30, Bias: -0.213000, T: 53730, Avg. loss: 0.050722
# Total training time: 0.00 seconds.
# -- Epoch 136
# Norm: 1.92, NNZs: 30, Bias: -0.213000, T: 54128, Avg. loss: 0.050813
# Total training time: 0.00 seconds.
# -- Epoch 137
# Norm: 1.92, NNZs: 30, Bias: -0.214000, T: 54526, Avg. loss: 0.050487
# Total training time: 0.00 seconds.
# -- Epoch 138
# Norm: 1.93, NNZs: 30, Bias: -0.211000, T: 54924, Avg. loss: 0.050515
# Total training time: 0.00 seconds.
# -- Epoch 139
# Norm: 1.93, NNZs: 30, Bias: -0.211000, T: 55322, Avg. loss: 0.050494
# Total training time: 0.00 seconds.
# -- Epoch 140
# Norm: 1.93, NNZs: 30, Bias: -0.212000, T: 55720, Avg. loss: 0.050344
# Total training time: 0.00 seconds.
# -- Epoch 141
# Norm: 1.94, NNZs: 30, Bias: -0.210000, T: 56118, Avg. loss: 0.050386
# Total training time: 0.00 seconds.
# -- Epoch 142
# Norm: 1.94, NNZs: 30, Bias: -0.210000, T: 56516, Avg. loss: 0.050242
# Total training time: 0.00 seconds.
# -- Epoch 143
# Norm: 1.94, NNZs: 30, Bias: -0.209000, T: 56914, Avg. loss: 0.050107
# Total training time: 0.00 seconds.
# -- Epoch 144
# Norm: 1.95, NNZs: 30, Bias: -0.209000, T: 57312, Avg. loss: 0.050193
# Total training time: 0.00 seconds.
# -- Epoch 145
# Norm: 1.95, NNZs: 30, Bias: -0.207000, T: 57710, Avg. loss: 0.050215
# Total training time: 0.00 seconds.
# -- Epoch 146
# Norm: 1.95, NNZs: 30, Bias: -0.208000, T: 58108, Avg. loss: 0.050042
# Total training time: 0.00 seconds.
# -- Epoch 147
# Norm: 1.96, NNZs: 30, Bias: -0.209000, T: 58506, Avg. loss: 0.049914
# Total training time: 0.00 seconds.
# -- Epoch 148
# Norm: 1.96, NNZs: 30, Bias: -0.208000, T: 58904, Avg. loss: 0.049842
# Total training time: 0.00 seconds.
# -- Epoch 149
# Norm: 1.96, NNZs: 30, Bias: -0.205000, T: 59302, Avg. loss: 0.049866
# Total training time: 0.00 seconds.
# -- Epoch 150
# Norm: 1.97, NNZs: 30, Bias: -0.205000, T: 59700, Avg. loss: 0.049559
# Total training time: 0.00 seconds.
# -- Epoch 151
# Norm: 1.97, NNZs: 30, Bias: -0.205000, T: 60098, Avg. loss: 0.050033
# Total training time: 0.00 seconds.
# -- Epoch 152
# Norm: 1.98, NNZs: 30, Bias: -0.205000, T: 60496, Avg. loss: 0.049756
# Total training time: 0.00 seconds.
# -- Epoch 153
# Norm: 1.98, NNZs: 30, Bias: -0.205000, T: 60894, Avg. loss: 0.049611
# Total training time: 0.00 seconds.
# -- Epoch 154
# Norm: 1.98, NNZs: 30, Bias: -0.205000, T: 61292, Avg. loss: 0.049579
# Total training time: 0.00 seconds.
# -- Epoch 155
# Norm: 1.99, NNZs: 30, Bias: -0.204000, T: 61690, Avg. loss: 0.049459
# Total training time: 0.00 seconds.
# -- Epoch 156
# Norm: 1.99, NNZs: 30, Bias: -0.205000, T: 62088, Avg. loss: 0.049356
# Total training time: 0.00 seconds.
# -- Epoch 157
# Norm: 1.99, NNZs: 30, Bias: -0.202000, T: 62486, Avg. loss: 0.049340
# Total training time: 0.00 seconds.
# -- Epoch 158
# Norm: 2.00, NNZs: 30, Bias: -0.202000, T: 62884, Avg. loss: 0.049289
# Total training time: 0.00 seconds.
# -- Epoch 159
# Norm: 2.00, NNZs: 30, Bias: -0.202000, T: 63282, Avg. loss: 0.049267
# Total training time: 0.00 seconds.
# -- Epoch 160
# Norm: 2.00, NNZs: 30, Bias: -0.201000, T: 63680, Avg. loss: 0.049178
# Total training time: 0.00 seconds.
# -- Epoch 161
# Norm: 2.01, NNZs: 30, Bias: -0.202000, T: 64078, Avg. loss: 0.048997
# Total training time: 0.00 seconds.
# -- Epoch 162
# Norm: 2.01, NNZs: 30, Bias: -0.200000, T: 64476, Avg. loss: 0.049201
# Total training time: 0.00 seconds.
# -- Epoch 163
# Norm: 2.01, NNZs: 30, Bias: -0.200000, T: 64874, Avg. loss: 0.049150
# Total training time: 0.00 seconds.
# -- Epoch 164
# Norm: 2.02, NNZs: 30, Bias: -0.198000, T: 65272, Avg. loss: 0.048961
# Total training time: 0.00 seconds.
# -- Epoch 165
# Norm: 2.02, NNZs: 30, Bias: -0.198000, T: 65670, Avg. loss: 0.048891
# Total training time: 0.00 seconds.
# -- Epoch 166
# Norm: 2.02, NNZs: 30, Bias: -0.198000, T: 66068, Avg. loss: 0.048809
# Total training time: 0.01 seconds.
# Convergence after 166 epochs took 0.01 seconds
# ✅ SGD SVM TRAINING COMPLETED!
#
# 📊 SGD SVM PERFORMANCE:
#    Accuracy: 0.9883
#    Sensitivity: 0.9841
#    Precision: 0.9841
#    F1-Score: 0.9841

# %%
# Create confusion matrix
cm_sgd = confusion_matrix(y_test, y_pred_sgd)

# Simple dark theme confusion matrix
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(8, 6), facecolor='black')

# Blue colormap for SVM
colors = ["#333333", "#45B7D1"]
cmap = LinearSegmentedColormap.from_list("blue_cmap", colors, N=100)

sns.heatmap(cm_sgd, annot=True, fmt='d', cmap=cmap,
            annot_kws={'size': 14, 'color': 'white', 'weight': 'bold'},
            linewidths=2, linecolor='white', ax=ax)

plt.title('SGD SVM - Confusion Matrix', color='white', fontsize=14, pad=20)
plt.xlabel('Predicted', color='white', fontsize=12)
plt.ylabel('Actual', color='white', fontsize=12)
ax.set_xticklabels(['Benign', 'Malignant'], color='white')
ax.set_yticklabels(['Benign', 'Malignant'], color='white', rotation=0)

plt.tight_layout()
plt.show()

# %%
# Performance summary
print(f"\n✨ SGD SVM Performance Metrics:")
print(f"   Accuracy:    {metrics_sgd['Accuracy']:.1%}")
print(f"   Sensitivity: {metrics_sgd['Sensitivity']:.1%}")
print(f"   Precision:   {metrics_sgd['Precision']:.1%}")
print(f"   F1-Score:    {metrics_sgd['F1-Score']:.1%}")
# Out:
# ✨ SGD SVM Performance Metrics:
#    Accuracy:    98.8%
#    Sensitivity: 98.4%
#    Precision:   98.4%
#    F1-Score:    98.4%

# %% [markdown]
# # Model Comparison and Evaluation

# %%
# Cell 1: 3 Confusion Matrices Side by Side
print("=" * 70)
print("CONFUSION MATRICES COMPARISON")
print("=" * 70)

# Create confusion matrices for all models
cm_logreg = confusion_matrix(y_test, y_pred)
cm_xgb = confusion_matrix(y_test, y_pred_enhanced)
cm_sgd = confusion_matrix(y_test, y_pred_sgd)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
plt.style.use('dark_background')

# Define colormaps for each model
cmaps = [
    LinearSegmentedColormap.from_list("logreg", ["#333333", "#4ECDC4"], N=100),
    LinearSegmentedColormap.from_list("xgb", ["#333333", "#FF6B9D"], N=100),
    LinearSegmentedColormap.from_list("svm", ["#333333", "#45B7D1"], N=100)
]

models = [
    ('Logistic Regression', cm_logreg, cmaps[0]),
    ('XGBoost', cm_xgb, cmaps[1]),
    ('SGD SVM', cm_sgd, cmaps[2])
]

for idx, (name, cm, cmap) in enumerate(models):
    sns.heatmap(cm, annot=True, fmt='d', cmap=cmap, 
                annot_kws={'size': 12, 'color': 'white', 'weight': 'bold'},
                linewidths=2, linecolor='white', ax=axes[idx], cbar=False)
    axes[idx].set_title(name, color='white', fontsize=14, pad=15)
    axes[idx].set_xlabel('Predicted', color='white', fontsize=11)
    axes[idx].set_ylabel('Actual', color='white', fontsize=11)
    axes[idx].set_xticklabels(['Benign', 'Malignant'], color='white')
    axes[idx].set_yticklabels(['Benign', 'Malignant'], color='white', rotation=0)

plt.tight_layout()
plt.show()
# Out:
# ======================================================================
# CONFUSION MATRICES COMPARISON
# ======================================================================

# %%
# Cell 2: Model Evaluation Table
print("=" * 70)
print("MODEL PERFORMANCE COMPARISON")
print("=" * 70)

# Calculate specificity for each model
def calculate_specificity(cm):
    tn, fp, fn, tp = cm.ravel()
    return tn / (tn + fp) if (tn + fp) > 0 else 0

specificity_logreg = calculate_specificity(cm_logreg)
specificity_xgb = calculate_specificity(cm_xgb)
specificity_sgd = calculate_specificity(cm_sgd)

# Gather all metrics
comparison_data = [
    ['Logistic Regression', accuracy, sensitivity, precision, f1_score(y_test, y_pred), specificity_logreg],
    ['XGBoost', metrics_enhanced['Accuracy'], metrics_enhanced['Sensitivity'], 
     metrics_enhanced['Precision'], metrics_enhanced['F1-Score'], specificity_xgb],
    ['SGD SVM', metrics_sgd['Accuracy'], metrics_sgd['Sensitivity'], 
     metrics_sgd['Precision'], metrics_sgd['F1-Score'], specificity_sgd]
]

comparison_df = pd.DataFrame(comparison_data, 
                           columns=['Model', 'Accuracy', 'Sensitivity', 'Precision', 'F1-Score', 'Specificity'])

print(tabulate(comparison_df, headers='keys', tablefmt='grid', showindex=False, floatfmt=".4f"))
# Out:
# ======================================================================
# MODEL PERFORMANCE COMPARISON
# ======================================================================
# +---------------------+------------+---------------+-------------+------------+---------------+
# | Model               |   Accuracy |   Sensitivity |   Precision |   F1-Score |   Specificity |
# +=====================+============+===============+=============+============+===============+
# | Logistic Regression |     0.9825 |        0.9841 |      0.9688 |     0.9764 |        0.9815 |
# +---------------------+------------+---------------+-------------+------------+---------------+
# | XGBoost             |     0.9649 |        0.9683 |      0.9385 |     0.9531 |        0.9630 |
# +---------------------+------------+---------------+-------------+------------+---------------+
# | SGD SVM             |     0.9883 |        0.9841 |      0.9841 |     0.9841 |        0.9907 |
# +---------------------+------------+---------------+-------------+------------+---------------+

# %%
# Cell 3: ROC Curve Comparison
print("\n" + "=" * 70)
print("ROC CURVE COMPARISON")
print("=" * 70)

# Get probabilities for all models (calibrate SGD SVM)
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import roc_curve, auc

# Calibrate SGD SVM for probabilities
sgd_svm_calibrated = CalibratedClassifierCV(sgd_svm, method='sigmoid', cv=3)
sgd_svm_calibrated.fit(X_train_scaled, y_train)
y_proba_sgd = sgd_svm_calibrated.predict_proba(X_test_scaled)[:, 1]

# Calculate ROC curves
fpr_logreg, tpr_logreg, _ = roc_curve(y_test, y_pred_proba)
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, y_proba_enhanced)
fpr_sgd, tpr_sgd, _ = roc_curve(y_test, y_proba_sgd)

# Calculate AUC scores
auc_logreg = auc(fpr_logreg, tpr_logreg)
auc_xgb = auc(fpr_xgb, tpr_xgb)
auc_sgd = auc(fpr_sgd, tpr_sgd)

# Plot ROC curves
plt.figure(figsize=(10, 8))
plt.plot(fpr_logreg, tpr_logreg, color='#4ECDC4', linewidth=3, label=f'Logistic Regression (AUC = {auc_logreg:.3f})')
plt.plot(fpr_xgb, tpr_xgb, color='#FF6B9D', linewidth=3, label=f'XGBoost (AUC = {auc_xgb:.3f})')
plt.plot(fpr_sgd, tpr_sgd, color='#45B7D1', linewidth=3, label=f'SGD SVM (AUC = {auc_sgd:.3f})')
plt.plot([0, 1], [0, 1], 'k--', linewidth=2, label='Random', alpha=0.5)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('ROC Curve Comparison - All Models')
plt.legend(loc='lower right')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ======================================================================
# ROC CURVE COMPARISON
# ======================================================================
# -- Epoch 1
# Norm: 0.40, NNZs: 30, Bias: -0.071000, T: 265, Avg. loss: 0.420008
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.50, NNZs: 30, Bias: -0.116000, T: 530, Avg. loss: 0.198409
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.57, NNZs: 30, Bias: -0.144000, T: 795, Avg. loss: 0.160888
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.61, NNZs: 30, Bias: -0.166000, T: 1060, Avg. loss: 0.142682
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.65, NNZs: 30, Bias: -0.183000, T: 1325, Avg. loss: 0.131628
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.69, NNZs: 30, Bias: -0.199000, T: 1590, Avg. loss: 0.123371
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.72, NNZs: 30, Bias: -0.213000, T: 1855, Avg. loss: 0.116804
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.75, NNZs: 30, Bias: -0.226000, T: 2120, Avg. loss: 0.111051
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.77, NNZs: 30, Bias: -0.235000, T: 2385, Avg. loss: 0.106541
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.80, NNZs: 30, Bias: -0.244000, T: 2650, Avg. loss: 0.102241
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.83, NNZs: 30, Bias: -0.254000, T: 2915, Avg. loss: 0.098389
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 0.85, NNZs: 30, Bias: -0.262000, T: 3180, Avg. loss: 0.095200
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 0.87, NNZs: 30, Bias: -0.270000, T: 3445, Avg. loss: 0.092239
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 0.89, NNZs: 30, Bias: -0.278000, T: 3710, Avg. loss: 0.089666
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 0.91, NNZs: 30, Bias: -0.285000, T: 3975, Avg. loss: 0.087601
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 0.93, NNZs: 30, Bias: -0.292000, T: 4240, Avg. loss: 0.085664
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 0.95, NNZs: 30, Bias: -0.299000, T: 4505, Avg. loss: 0.083728
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 0.97, NNZs: 30, Bias: -0.305000, T: 4770, Avg. loss: 0.081807
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 0.98, NNZs: 30, Bias: -0.311000, T: 5035, Avg. loss: 0.079972
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 1.00, NNZs: 30, Bias: -0.314000, T: 5300, Avg. loss: 0.078359
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 1.02, NNZs: 30, Bias: -0.318000, T: 5565, Avg. loss: 0.077082
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 1.03, NNZs: 30, Bias: -0.321000, T: 5830, Avg. loss: 0.075674
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 1.05, NNZs: 30, Bias: -0.323000, T: 6095, Avg. loss: 0.074364
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 1.06, NNZs: 30, Bias: -0.325000, T: 6360, Avg. loss: 0.072994
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 1.08, NNZs: 30, Bias: -0.328000, T: 6625, Avg. loss: 0.072138
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 1.09, NNZs: 30, Bias: -0.329000, T: 6890, Avg. loss: 0.070490
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 1.11, NNZs: 30, Bias: -0.328000, T: 7155, Avg. loss: 0.070093
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 1.12, NNZs: 30, Bias: -0.328000, T: 7420, Avg. loss: 0.069122
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 1.14, NNZs: 30, Bias: -0.329000, T: 7685, Avg. loss: 0.068014
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 1.15, NNZs: 30, Bias: -0.329000, T: 7950, Avg. loss: 0.066877
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 1.16, NNZs: 30, Bias: -0.330000, T: 8215, Avg. loss: 0.066205
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 1.17, NNZs: 30, Bias: -0.331000, T: 8480, Avg. loss: 0.065119
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 1.19, NNZs: 30, Bias: -0.330000, T: 8745, Avg. loss: 0.064605
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 1.20, NNZs: 30, Bias: -0.330000, T: 9010, Avg. loss: 0.063826
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 1.21, NNZs: 30, Bias: -0.332000, T: 9275, Avg. loss: 0.062844
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 1.22, NNZs: 30, Bias: -0.333000, T: 9540, Avg. loss: 0.062312
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 1.24, NNZs: 30, Bias: -0.331000, T: 9805, Avg. loss: 0.061367
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 1.25, NNZs: 30, Bias: -0.332000, T: 10070, Avg. loss: 0.060545
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 1.26, NNZs: 30, Bias: -0.333000, T: 10335, Avg. loss: 0.059975
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 1.27, NNZs: 30, Bias: -0.332000, T: 10600, Avg. loss: 0.058957
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 1.28, NNZs: 30, Bias: -0.333000, T: 10865, Avg. loss: 0.058374
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 1.30, NNZs: 30, Bias: -0.333000, T: 11130, Avg. loss: 0.057607
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 1.31, NNZs: 30, Bias: -0.334000, T: 11395, Avg. loss: 0.057105
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 1.32, NNZs: 30, Bias: -0.333000, T: 11660, Avg. loss: 0.056442
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 1.33, NNZs: 30, Bias: -0.332000, T: 11925, Avg. loss: 0.055939
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 1.34, NNZs: 30, Bias: -0.333000, T: 12190, Avg. loss: 0.055433
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 1.35, NNZs: 30, Bias: -0.332000, T: 12455, Avg. loss: 0.054743
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 1.36, NNZs: 30, Bias: -0.332000, T: 12720, Avg. loss: 0.054439
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 1.37, NNZs: 30, Bias: -0.332000, T: 12985, Avg. loss: 0.053689
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 1.38, NNZs: 30, Bias: -0.334000, T: 13250, Avg. loss: 0.053124
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 1.39, NNZs: 30, Bias: -0.332000, T: 13515, Avg. loss: 0.052732
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 1.40, NNZs: 30, Bias: -0.330000, T: 13780, Avg. loss: 0.052040
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 1.41, NNZs: 30, Bias: -0.327000, T: 14045, Avg. loss: 0.051676
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 1.42, NNZs: 30, Bias: -0.328000, T: 14310, Avg. loss: 0.051285
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 1.43, NNZs: 30, Bias: -0.327000, T: 14575, Avg. loss: 0.050706
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 1.44, NNZs: 30, Bias: -0.325000, T: 14840, Avg. loss: 0.050364
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 1.45, NNZs: 30, Bias: -0.324000, T: 15105, Avg. loss: 0.049966
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 1.46, NNZs: 30, Bias: -0.323000, T: 15370, Avg. loss: 0.049473
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 1.47, NNZs: 30, Bias: -0.323000, T: 15635, Avg. loss: 0.049033
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 1.48, NNZs: 30, Bias: -0.321000, T: 15900, Avg. loss: 0.048680
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 1.49, NNZs: 30, Bias: -0.320000, T: 16165, Avg. loss: 0.048288
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 1.50, NNZs: 30, Bias: -0.318000, T: 16430, Avg. loss: 0.047896
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 1.50, NNZs: 30, Bias: -0.316000, T: 16695, Avg. loss: 0.047616
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 1.51, NNZs: 30, Bias: -0.314000, T: 16960, Avg. loss: 0.047244
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 1.52, NNZs: 30, Bias: -0.312000, T: 17225, Avg. loss: 0.047042
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 1.53, NNZs: 30, Bias: -0.312000, T: 17490, Avg. loss: 0.046765
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 1.53, NNZs: 30, Bias: -0.312000, T: 17755, Avg. loss: 0.046539
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 1.54, NNZs: 30, Bias: -0.309000, T: 18020, Avg. loss: 0.046218
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 1.55, NNZs: 30, Bias: -0.307000, T: 18285, Avg. loss: 0.046075
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 1.55, NNZs: 30, Bias: -0.304000, T: 18550, Avg. loss: 0.045760
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 1.56, NNZs: 30, Bias: -0.302000, T: 18815, Avg. loss: 0.045550
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 1.57, NNZs: 30, Bias: -0.299000, T: 19080, Avg. loss: 0.045230
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 1.57, NNZs: 30, Bias: -0.298000, T: 19345, Avg. loss: 0.045197
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 1.58, NNZs: 30, Bias: -0.296000, T: 19610, Avg. loss: 0.044884
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 1.59, NNZs: 30, Bias: -0.294000, T: 19875, Avg. loss: 0.044602
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 1.59, NNZs: 30, Bias: -0.291000, T: 20140, Avg. loss: 0.044467
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 1.60, NNZs: 30, Bias: -0.286000, T: 20405, Avg. loss: 0.044156
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 1.60, NNZs: 30, Bias: -0.283000, T: 20670, Avg. loss: 0.043963
# Total training time: 0.00 seconds.
# -- Epoch 79
# Norm: 1.61, NNZs: 30, Bias: -0.279000, T: 20935, Avg. loss: 0.043615
# Total training time: 0.00 seconds.
# -- Epoch 80
# Norm: 1.62, NNZs: 30, Bias: -0.279000, T: 21200, Avg. loss: 0.043536
# Total training time: 0.00 seconds.
# -- Epoch 81
# Norm: 1.62, NNZs: 30, Bias: -0.277000, T: 21465, Avg. loss: 0.043300
# Total training time: 0.00 seconds.
# -- Epoch 82
# Norm: 1.63, NNZs: 30, Bias: -0.275000, T: 21730, Avg. loss: 0.043140
# Total training time: 0.00 seconds.
# -- Epoch 83
# Norm: 1.64, NNZs: 30, Bias: -0.272000, T: 21995, Avg. loss: 0.042850
# Total training time: 0.00 seconds.
# -- Epoch 84
# Norm: 1.64, NNZs: 30, Bias: -0.269000, T: 22260, Avg. loss: 0.042483
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 1.65, NNZs: 30, Bias: -0.267000, T: 22525, Avg. loss: 0.042459
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 1.66, NNZs: 30, Bias: -0.264000, T: 22790, Avg. loss: 0.042139
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 1.66, NNZs: 30, Bias: -0.263000, T: 23055, Avg. loss: 0.042004
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 1.67, NNZs: 30, Bias: -0.263000, T: 23320, Avg. loss: 0.041690
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 1.68, NNZs: 30, Bias: -0.260000, T: 23585, Avg. loss: 0.041477
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 1.68, NNZs: 30, Bias: -0.257000, T: 23850, Avg. loss: 0.041314
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 1.69, NNZs: 30, Bias: -0.257000, T: 24115, Avg. loss: 0.041093
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 1.69, NNZs: 30, Bias: -0.255000, T: 24380, Avg. loss: 0.040853
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 1.70, NNZs: 30, Bias: -0.252000, T: 24645, Avg. loss: 0.040657
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 1.71, NNZs: 30, Bias: -0.249000, T: 24910, Avg. loss: 0.040433
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 1.71, NNZs: 30, Bias: -0.249000, T: 25175, Avg. loss: 0.040297
# Total training time: 0.00 seconds.
# -- Epoch 96
# Norm: 1.72, NNZs: 30, Bias: -0.248000, T: 25440, Avg. loss: 0.040122
# Total training time: 0.00 seconds.
# -- Epoch 97
# Norm: 1.72, NNZs: 30, Bias: -0.247000, T: 25705, Avg. loss: 0.039792
# Total training time: 0.00 seconds.
# -- Epoch 98
# Norm: 1.73, NNZs: 30, Bias: -0.247000, T: 25970, Avg. loss: 0.039818
# Total training time: 0.00 seconds.
# -- Epoch 99
# Norm: 1.74, NNZs: 30, Bias: -0.245000, T: 26235, Avg. loss: 0.039514
# Total training time: 0.00 seconds.
# -- Epoch 100
# Norm: 1.74, NNZs: 30, Bias: -0.245000, T: 26500, Avg. loss: 0.039441
# Total training time: 0.00 seconds.
# -- Epoch 101
# Norm: 1.75, NNZs: 30, Bias: -0.243000, T: 26765, Avg. loss: 0.039274
# Total training time: 0.00 seconds.
# -- Epoch 102
# Norm: 1.75, NNZs: 30, Bias: -0.243000, T: 27030, Avg. loss: 0.038886
# Total training time: 0.00 seconds.
# -- Epoch 103
# Norm: 1.76, NNZs: 30, Bias: -0.241000, T: 27295, Avg. loss: 0.039044
# Total training time: 0.00 seconds.
# -- Epoch 104
# Norm: 1.76, NNZs: 30, Bias: -0.239000, T: 27560, Avg. loss: 0.038842
# Total training time: 0.00 seconds.
# -- Epoch 105
# Norm: 1.77, NNZs: 30, Bias: -0.240000, T: 27825, Avg. loss: 0.038718
# Total training time: 0.00 seconds.
# -- Epoch 106
# Norm: 1.77, NNZs: 30, Bias: -0.237000, T: 28090, Avg. loss: 0.038681
# Total training time: 0.00 seconds.
# -- Epoch 107
# Norm: 1.78, NNZs: 30, Bias: -0.237000, T: 28355, Avg. loss: 0.038508
# Total training time: 0.00 seconds.
# -- Epoch 108
# Norm: 1.78, NNZs: 30, Bias: -0.237000, T: 28620, Avg. loss: 0.038426
# Total training time: 0.00 seconds.
# -- Epoch 109
# Norm: 1.79, NNZs: 30, Bias: -0.237000, T: 28885, Avg. loss: 0.038156
# Total training time: 0.00 seconds.
# -- Epoch 110
# Norm: 1.79, NNZs: 30, Bias: -0.237000, T: 29150, Avg. loss: 0.038293
# Total training time: 0.00 seconds.
# -- Epoch 111
# Norm: 1.80, NNZs: 30, Bias: -0.235000, T: 29415, Avg. loss: 0.038012
# Total training time: 0.00 seconds.
# -- Epoch 112
# Norm: 1.80, NNZs: 30, Bias: -0.236000, T: 29680, Avg. loss: 0.037924
# Total training time: 0.00 seconds.
# -- Epoch 113
# Norm: 1.80, NNZs: 30, Bias: -0.237000, T: 29945, Avg. loss: 0.037791
# Total training time: 0.00 seconds.
# -- Epoch 114
# Norm: 1.81, NNZs: 30, Bias: -0.235000, T: 30210, Avg. loss: 0.037783
# Total training time: 0.00 seconds.
# -- Epoch 115
# Norm: 1.81, NNZs: 30, Bias: -0.236000, T: 30475, Avg. loss: 0.037622
# Total training time: 0.00 seconds.
# -- Epoch 116
# Norm: 1.82, NNZs: 30, Bias: -0.237000, T: 30740, Avg. loss: 0.037448
# Total training time: 0.00 seconds.
# -- Epoch 117
# Norm: 1.82, NNZs: 30, Bias: -0.235000, T: 31005, Avg. loss: 0.037383
# Total training time: 0.00 seconds.
# -- Epoch 118
# Norm: 1.83, NNZs: 30, Bias: -0.233000, T: 31270, Avg. loss: 0.037123
# Total training time: 0.00 seconds.
# -- Epoch 119
# Norm: 1.83, NNZs: 30, Bias: -0.233000, T: 31535, Avg. loss: 0.037294
# Total training time: 0.00 seconds.
# -- Epoch 120
# Norm: 1.84, NNZs: 30, Bias: -0.233000, T: 31800, Avg. loss: 0.037183
# Total training time: 0.00 seconds.
# -- Epoch 121
# Norm: 1.84, NNZs: 30, Bias: -0.234000, T: 32065, Avg. loss: 0.036996
# Total training time: 0.00 seconds.
# -- Epoch 122
# Norm: 1.84, NNZs: 30, Bias: -0.234000, T: 32330, Avg. loss: 0.036851
# Total training time: 0.00 seconds.
# -- Epoch 123
# Norm: 1.85, NNZs: 30, Bias: -0.233000, T: 32595, Avg. loss: 0.036785
# Total training time: 0.00 seconds.
# -- Epoch 124
# Norm: 1.85, NNZs: 30, Bias: -0.232000, T: 32860, Avg. loss: 0.036711
# Total training time: 0.00 seconds.
# -- Epoch 125
# Norm: 1.86, NNZs: 30, Bias: -0.232000, T: 33125, Avg. loss: 0.036504
# Total training time: 0.00 seconds.
# -- Epoch 126
# Norm: 1.86, NNZs: 30, Bias: -0.232000, T: 33390, Avg. loss: 0.036455
# Total training time: 0.00 seconds.
# -- Epoch 127
# Norm: 1.87, NNZs: 30, Bias: -0.232000, T: 33655, Avg. loss: 0.036450
# Total training time: 0.00 seconds.
# -- Epoch 128
# Norm: 1.87, NNZs: 30, Bias: -0.232000, T: 33920, Avg. loss: 0.036211
# Total training time: 0.00 seconds.
# -- Epoch 129
# Norm: 1.87, NNZs: 30, Bias: -0.231000, T: 34185, Avg. loss: 0.036140
# Total training time: 0.00 seconds.
# -- Epoch 130
# Norm: 1.88, NNZs: 30, Bias: -0.232000, T: 34450, Avg. loss: 0.035937
# Total training time: 0.00 seconds.
# -- Epoch 131
# Norm: 1.88, NNZs: 30, Bias: -0.232000, T: 34715, Avg. loss: 0.035891
# Total training time: 0.00 seconds.
# -- Epoch 132
# Norm: 1.89, NNZs: 30, Bias: -0.232000, T: 34980, Avg. loss: 0.035966
# Total training time: 0.00 seconds.
# -- Epoch 133
# Norm: 1.89, NNZs: 30, Bias: -0.232000, T: 35245, Avg. loss: 0.035743
# Total training time: 0.00 seconds.
# -- Epoch 134
# Norm: 1.90, NNZs: 30, Bias: -0.230000, T: 35510, Avg. loss: 0.035528
# Total training time: 0.00 seconds.
# -- Epoch 135
# Norm: 1.90, NNZs: 30, Bias: -0.230000, T: 35775, Avg. loss: 0.035555
# Total training time: 0.00 seconds.
# -- Epoch 136
# Norm: 1.91, NNZs: 30, Bias: -0.230000, T: 36040, Avg. loss: 0.035368
# Total training time: 0.00 seconds.
# -- Epoch 137
# Norm: 1.91, NNZs: 30, Bias: -0.230000, T: 36305, Avg. loss: 0.035467
# Total training time: 0.00 seconds.
# -- Epoch 138
# Norm: 1.91, NNZs: 30, Bias: -0.230000, T: 36570, Avg. loss: 0.035197
# Total training time: 0.00 seconds.
# -- Epoch 139
# Norm: 1.92, NNZs: 30, Bias: -0.229000, T: 36835, Avg. loss: 0.035054
# Total training time: 0.00 seconds.
# -- Epoch 140
# Norm: 1.92, NNZs: 30, Bias: -0.229000, T: 37100, Avg. loss: 0.034878
# Total training time: 0.00 seconds.
# -- Epoch 141
# Norm: 1.93, NNZs: 30, Bias: -0.228000, T: 37365, Avg. loss: 0.035012
# Total training time: 0.00 seconds.
# -- Epoch 142
# Norm: 1.93, NNZs: 30, Bias: -0.226000, T: 37630, Avg. loss: 0.034761
# Total training time: 0.00 seconds.
# -- Epoch 143
# Norm: 1.94, NNZs: 30, Bias: -0.226000, T: 37895, Avg. loss: 0.034679
# Total training time: 0.00 seconds.
# -- Epoch 144
# Norm: 1.94, NNZs: 30, Bias: -0.225000, T: 38160, Avg. loss: 0.034529
# Total training time: 0.00 seconds.
# -- Epoch 145
# Norm: 1.94, NNZs: 30, Bias: -0.226000, T: 38425, Avg. loss: 0.034387
# Total training time: 0.00 seconds.
# -- Epoch 146
# Norm: 1.95, NNZs: 30, Bias: -0.224000, T: 38690, Avg. loss: 0.034373
# Total training time: 0.00 seconds.
# -- Epoch 147
# Norm: 1.95, NNZs: 30, Bias: -0.225000, T: 38955, Avg. loss: 0.034346
# Total training time: 0.00 seconds.
# -- Epoch 148
# Norm: 1.96, NNZs: 30, Bias: -0.225000, T: 39220, Avg. loss: 0.034183
# Total training time: 0.00 seconds.
# -- Epoch 149
# Norm: 1.96, NNZs: 30, Bias: -0.226000, T: 39485, Avg. loss: 0.034051
# Total training time: 0.00 seconds.
# -- Epoch 150
# Norm: 1.97, NNZs: 30, Bias: -0.225000, T: 39750, Avg. loss: 0.033833
# Total training time: 0.00 seconds.
# -- Epoch 151
# Norm: 1.97, NNZs: 30, Bias: -0.225000, T: 40015, Avg. loss: 0.033965
# Total training time: 0.00 seconds.
# -- Epoch 152
# Norm: 1.98, NNZs: 30, Bias: -0.226000, T: 40280, Avg. loss: 0.033702
# Total training time: 0.00 seconds.
# -- Epoch 153
# Norm: 1.98, NNZs: 30, Bias: -0.226000, T: 40545, Avg. loss: 0.033622
# Total training time: 0.00 seconds.
# -- Epoch 154
# Norm: 1.98, NNZs: 30, Bias: -0.227000, T: 40810, Avg. loss: 0.033540
# Total training time: 0.00 seconds.
# -- Epoch 155
# Norm: 1.99, NNZs: 30, Bias: -0.226000, T: 41075, Avg. loss: 0.033427
# Total training time: 0.00 seconds.
# -- Epoch 156
# Norm: 1.99, NNZs: 30, Bias: -0.226000, T: 41340, Avg. loss: 0.033436
# Total training time: 0.00 seconds.
# -- Epoch 157
# Norm: 2.00, NNZs: 30, Bias: -0.225000, T: 41605, Avg. loss: 0.033233
# Total training time: 0.00 seconds.
# -- Epoch 158
# Norm: 2.00, NNZs: 30, Bias: -0.226000, T: 41870, Avg. loss: 0.033040
# Total training time: 0.00 seconds.
# -- Epoch 159
# Norm: 2.01, NNZs: 30, Bias: -0.224000, T: 42135, Avg. loss: 0.033033
# Total training time: 0.00 seconds.
# -- Epoch 160
# Norm: 2.01, NNZs: 30, Bias: -0.223000, T: 42400, Avg. loss: 0.032953
# Total training time: 0.00 seconds.
# -- Epoch 161
# Norm: 2.01, NNZs: 30, Bias: -0.223000, T: 42665, Avg. loss: 0.032665
# Total training time: 0.00 seconds.
# -- Epoch 162
# Norm: 2.02, NNZs: 30, Bias: -0.223000, T: 42930, Avg. loss: 0.032765
# Total training time: 0.00 seconds.
# -- Epoch 163
# Norm: 2.02, NNZs: 30, Bias: -0.222000, T: 43195, Avg. loss: 0.032708
# Total training time: 0.00 seconds.
# -- Epoch 164
# Norm: 2.03, NNZs: 30, Bias: -0.222000, T: 43460, Avg. loss: 0.032466
# Total training time: 0.00 seconds.
# -- Epoch 165
# Norm: 2.03, NNZs: 30, Bias: -0.222000, T: 43725, Avg. loss: 0.032457
# Total training time: 0.00 seconds.
# -- Epoch 166
# Norm: 2.04, NNZs: 30, Bias: -0.221000, T: 43990, Avg. loss: 0.032429
# Total training time: 0.00 seconds.
# -- Epoch 167
# Norm: 2.04, NNZs: 30, Bias: -0.222000, T: 44255, Avg. loss: 0.032165
# Total training time: 0.00 seconds.
# -- Epoch 168
# Norm: 2.04, NNZs: 30, Bias: -0.222000, T: 44520, Avg. loss: 0.032169
# Total training time: 0.00 seconds.
# -- Epoch 169
# Norm: 2.05, NNZs: 30, Bias: -0.220000, T: 44785, Avg. loss: 0.031888
# Total training time: 0.00 seconds.
# -- Epoch 170
# Norm: 2.05, NNZs: 30, Bias: -0.220000, T: 45050, Avg. loss: 0.031909
# Total training time: 0.00 seconds.
# -- Epoch 171
# Norm: 2.06, NNZs: 30, Bias: -0.220000, T: 45315, Avg. loss: 0.031997
# Total training time: 0.00 seconds.
# -- Epoch 172
# Norm: 2.06, NNZs: 30, Bias: -0.221000, T: 45580, Avg. loss: 0.031689
# Total training time: 0.01 seconds.
# -- Epoch 173
# Norm: 2.07, NNZs: 30, Bias: -0.219000, T: 45845, Avg. loss: 0.031601
# Total training time: 0.01 seconds.
# -- Epoch 174
# Norm: 2.07, NNZs: 30, Bias: -0.219000, T: 46110, Avg. loss: 0.031593
# Total training time: 0.01 seconds.
# -- Epoch 175
# Norm: 2.07, NNZs: 30, Bias: -0.219000, T: 46375, Avg. loss: 0.031420
# Total training time: 0.01 seconds.
# -- Epoch 176
# Norm: 2.08, NNZs: 30, Bias: -0.218000, T: 46640, Avg. loss: 0.031414
# Total training time: 0.01 seconds.
# -- Epoch 177
# Norm: 2.08, NNZs: 30, Bias: -0.217000, T: 46905, Avg. loss: 0.031313
# Total training time: 0.01 seconds.
# -- Epoch 178
# Norm: 2.09, NNZs: 30, Bias: -0.218000, T: 47170, Avg. loss: 0.031205
# Total training time: 0.01 seconds.
# -- Epoch 179
# Norm: 2.09, NNZs: 30, Bias: -0.217000, T: 47435, Avg. loss: 0.030998
# Total training time: 0.01 seconds.
# -- Epoch 180
# Norm: 2.10, NNZs: 30, Bias: -0.217000, T: 47700, Avg. loss: 0.031125
# Total training time: 0.01 seconds.
# -- Epoch 181
# Norm: 2.10, NNZs: 30, Bias: -0.216000, T: 47965, Avg. loss: 0.030918
# Total training time: 0.01 seconds.
# -- Epoch 182
# Norm: 2.10, NNZs: 30, Bias: -0.215000, T: 48230, Avg. loss: 0.030816
# Total training time: 0.01 seconds.
# -- Epoch 183
# Norm: 2.11, NNZs: 30, Bias: -0.215000, T: 48495, Avg. loss: 0.030617
# Total training time: 0.01 seconds.
# -- Epoch 184
# Norm: 2.11, NNZs: 30, Bias: -0.213000, T: 48760, Avg. loss: 0.030508
# Total training time: 0.01 seconds.
# -- Epoch 185
# Norm: 2.11, NNZs: 30, Bias: -0.210000, T: 49025, Avg. loss: 0.030442
# Total training time: 0.01 seconds.
# -- Epoch 186
# Norm: 2.12, NNZs: 30, Bias: -0.210000, T: 49290, Avg. loss: 0.030615
# Total training time: 0.01 seconds.
# -- Epoch 187
# Norm: 2.12, NNZs: 30, Bias: -0.209000, T: 49555, Avg. loss: 0.030361
# Total training time: 0.01 seconds.
# -- Epoch 188
# Norm: 2.12, NNZs: 30, Bias: -0.209000, T: 49820, Avg. loss: 0.030337
# Total training time: 0.01 seconds.
# -- Epoch 189
# Norm: 2.12, NNZs: 30, Bias: -0.210000, T: 50085, Avg. loss: 0.030286
# Total training time: 0.01 seconds.
# Convergence after 189 epochs took 0.01 seconds
# -- Epoch 1
# Norm: 0.39, NNZs: 30, Bias: -0.066000, T: 265, Avg. loss: 0.440888
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.50, NNZs: 30, Bias: -0.099000, T: 530, Avg. loss: 0.213285
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.57, NNZs: 30, Bias: -0.118000, T: 795, Avg. loss: 0.180915
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.62, NNZs: 30, Bias: -0.134000, T: 1060, Avg. loss: 0.161664
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.66, NNZs: 30, Bias: -0.145000, T: 1325, Avg. loss: 0.150918
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.69, NNZs: 30, Bias: -0.155000, T: 1590, Avg. loss: 0.142299
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.73, NNZs: 30, Bias: -0.163000, T: 1855, Avg. loss: 0.134304
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.76, NNZs: 30, Bias: -0.171000, T: 2120, Avg. loss: 0.129702
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.79, NNZs: 30, Bias: -0.177000, T: 2385, Avg. loss: 0.125358
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.81, NNZs: 30, Bias: -0.183000, T: 2650, Avg. loss: 0.121293
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.84, NNZs: 30, Bias: -0.192000, T: 2915, Avg. loss: 0.118329
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 0.86, NNZs: 30, Bias: -0.199000, T: 3180, Avg. loss: 0.115284
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 0.88, NNZs: 30, Bias: -0.205000, T: 3445, Avg. loss: 0.112881
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 0.89, NNZs: 30, Bias: -0.210000, T: 3710, Avg. loss: 0.110680
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 0.91, NNZs: 30, Bias: -0.215000, T: 3975, Avg. loss: 0.108624
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 0.93, NNZs: 30, Bias: -0.222000, T: 4240, Avg. loss: 0.106622
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 0.95, NNZs: 30, Bias: -0.227000, T: 4505, Avg. loss: 0.104875
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 0.97, NNZs: 30, Bias: -0.232000, T: 4770, Avg. loss: 0.103225
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 0.98, NNZs: 30, Bias: -0.238000, T: 5035, Avg. loss: 0.101630
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 1.00, NNZs: 30, Bias: -0.243000, T: 5300, Avg. loss: 0.100017
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 1.02, NNZs: 30, Bias: -0.249000, T: 5565, Avg. loss: 0.098533
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 1.03, NNZs: 30, Bias: -0.254000, T: 5830, Avg. loss: 0.097008
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 1.05, NNZs: 30, Bias: -0.260000, T: 6095, Avg. loss: 0.095523
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 1.07, NNZs: 30, Bias: -0.266000, T: 6360, Avg. loss: 0.093985
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 1.08, NNZs: 30, Bias: -0.271000, T: 6625, Avg. loss: 0.092579
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 1.10, NNZs: 30, Bias: -0.273000, T: 6890, Avg. loss: 0.091359
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 1.11, NNZs: 30, Bias: -0.279000, T: 7155, Avg. loss: 0.090327
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 1.12, NNZs: 30, Bias: -0.283000, T: 7420, Avg. loss: 0.089386
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 1.13, NNZs: 30, Bias: -0.285000, T: 7685, Avg. loss: 0.088310
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 1.15, NNZs: 30, Bias: -0.291000, T: 7950, Avg. loss: 0.087481
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 1.16, NNZs: 30, Bias: -0.297000, T: 8215, Avg. loss: 0.086461
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 1.17, NNZs: 30, Bias: -0.301000, T: 8480, Avg. loss: 0.085703
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 1.18, NNZs: 30, Bias: -0.306000, T: 8745, Avg. loss: 0.085028
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 1.19, NNZs: 30, Bias: -0.310000, T: 9010, Avg. loss: 0.084514
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 1.20, NNZs: 30, Bias: -0.314000, T: 9275, Avg. loss: 0.083954
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 1.20, NNZs: 30, Bias: -0.315000, T: 9540, Avg. loss: 0.083466
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 1.21, NNZs: 30, Bias: -0.319000, T: 9805, Avg. loss: 0.082917
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 1.22, NNZs: 30, Bias: -0.320000, T: 10070, Avg. loss: 0.082636
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 1.22, NNZs: 30, Bias: -0.321000, T: 10335, Avg. loss: 0.081943
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 1.23, NNZs: 30, Bias: -0.320000, T: 10600, Avg. loss: 0.081903
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 1.24, NNZs: 30, Bias: -0.321000, T: 10865, Avg. loss: 0.081167
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 1.25, NNZs: 30, Bias: -0.322000, T: 11130, Avg. loss: 0.081097
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 1.25, NNZs: 30, Bias: -0.323000, T: 11395, Avg. loss: 0.080507
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 1.26, NNZs: 30, Bias: -0.324000, T: 11660, Avg. loss: 0.080196
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 1.27, NNZs: 30, Bias: -0.323000, T: 11925, Avg. loss: 0.080049
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 1.28, NNZs: 30, Bias: -0.323000, T: 12190, Avg. loss: 0.079563
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 1.28, NNZs: 30, Bias: -0.324000, T: 12455, Avg. loss: 0.079400
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 1.29, NNZs: 30, Bias: -0.322000, T: 12720, Avg. loss: 0.078868
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 1.30, NNZs: 30, Bias: -0.320000, T: 12985, Avg. loss: 0.078771
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 1.30, NNZs: 30, Bias: -0.319000, T: 13250, Avg. loss: 0.078329
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 1.31, NNZs: 30, Bias: -0.318000, T: 13515, Avg. loss: 0.078163
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 1.32, NNZs: 30, Bias: -0.317000, T: 13780, Avg. loss: 0.077848
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 1.33, NNZs: 30, Bias: -0.317000, T: 14045, Avg. loss: 0.077443
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 1.33, NNZs: 30, Bias: -0.316000, T: 14310, Avg. loss: 0.077309
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 1.34, NNZs: 30, Bias: -0.316000, T: 14575, Avg. loss: 0.076951
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 1.35, NNZs: 30, Bias: -0.315000, T: 14840, Avg. loss: 0.076574
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 1.35, NNZs: 30, Bias: -0.316000, T: 15105, Avg. loss: 0.076431
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 1.36, NNZs: 30, Bias: -0.313000, T: 15370, Avg. loss: 0.076060
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 1.36, NNZs: 30, Bias: -0.312000, T: 15635, Avg. loss: 0.075903
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 1.37, NNZs: 30, Bias: -0.311000, T: 15900, Avg. loss: 0.075417
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 1.38, NNZs: 30, Bias: -0.310000, T: 16165, Avg. loss: 0.075276
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 1.39, NNZs: 30, Bias: -0.309000, T: 16430, Avg. loss: 0.074990
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 1.39, NNZs: 30, Bias: -0.306000, T: 16695, Avg. loss: 0.074759
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 1.40, NNZs: 30, Bias: -0.303000, T: 16960, Avg. loss: 0.074446
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 1.40, NNZs: 30, Bias: -0.301000, T: 17225, Avg. loss: 0.074175
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 1.41, NNZs: 30, Bias: -0.298000, T: 17490, Avg. loss: 0.074034
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 1.42, NNZs: 30, Bias: -0.296000, T: 17755, Avg. loss: 0.073648
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 1.42, NNZs: 30, Bias: -0.293000, T: 18020, Avg. loss: 0.073442
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 1.43, NNZs: 30, Bias: -0.294000, T: 18285, Avg. loss: 0.073136
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 1.43, NNZs: 30, Bias: -0.292000, T: 18550, Avg. loss: 0.072945
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 1.44, NNZs: 30, Bias: -0.292000, T: 18815, Avg. loss: 0.072731
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 1.45, NNZs: 30, Bias: -0.291000, T: 19080, Avg. loss: 0.072452
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 1.45, NNZs: 30, Bias: -0.290000, T: 19345, Avg. loss: 0.072277
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 1.46, NNZs: 30, Bias: -0.290000, T: 19610, Avg. loss: 0.071995
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 1.46, NNZs: 30, Bias: -0.287000, T: 19875, Avg. loss: 0.071922
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 1.47, NNZs: 30, Bias: -0.284000, T: 20140, Avg. loss: 0.071675
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 1.47, NNZs: 30, Bias: -0.285000, T: 20405, Avg. loss: 0.071387
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 1.48, NNZs: 30, Bias: -0.285000, T: 20670, Avg. loss: 0.071339
# Total training time: 0.00 seconds.
# -- Epoch 79
# Norm: 1.48, NNZs: 30, Bias: -0.285000, T: 20935, Avg. loss: 0.071051
# Total training time: 0.00 seconds.
# -- Epoch 80
# Norm: 1.49, NNZs: 30, Bias: -0.282000, T: 21200, Avg. loss: 0.070865
# Total training time: 0.00 seconds.
# -- Epoch 81
# Norm: 1.49, NNZs: 30, Bias: -0.280000, T: 21465, Avg. loss: 0.070787
# Total training time: 0.00 seconds.
# -- Epoch 82
# Norm: 1.50, NNZs: 30, Bias: -0.280000, T: 21730, Avg. loss: 0.070509
# Total training time: 0.00 seconds.
# -- Epoch 83
# Norm: 1.50, NNZs: 30, Bias: -0.280000, T: 21995, Avg. loss: 0.070242
# Total training time: 0.00 seconds.
# -- Epoch 84
# Norm: 1.51, NNZs: 30, Bias: -0.279000, T: 22260, Avg. loss: 0.070183
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 1.51, NNZs: 30, Bias: -0.278000, T: 22525, Avg. loss: 0.069949
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 1.52, NNZs: 30, Bias: -0.279000, T: 22790, Avg. loss: 0.069830
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 1.52, NNZs: 30, Bias: -0.278000, T: 23055, Avg. loss: 0.069572
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 1.53, NNZs: 30, Bias: -0.277000, T: 23320, Avg. loss: 0.069467
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 1.53, NNZs: 30, Bias: -0.276000, T: 23585, Avg. loss: 0.069167
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 1.54, NNZs: 30, Bias: -0.273000, T: 23850, Avg. loss: 0.069111
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 1.54, NNZs: 30, Bias: -0.272000, T: 24115, Avg. loss: 0.068952
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 1.55, NNZs: 30, Bias: -0.272000, T: 24380, Avg. loss: 0.068627
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 1.55, NNZs: 30, Bias: -0.274000, T: 24645, Avg. loss: 0.068392
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 1.56, NNZs: 30, Bias: -0.272000, T: 24910, Avg. loss: 0.068359
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 1.56, NNZs: 30, Bias: -0.272000, T: 25175, Avg. loss: 0.068131
# Total training time: 0.00 seconds.
# -- Epoch 96
# Norm: 1.57, NNZs: 30, Bias: -0.270000, T: 25440, Avg. loss: 0.068021
# Total training time: 0.00 seconds.
# -- Epoch 97
# Norm: 1.57, NNZs: 30, Bias: -0.271000, T: 25705, Avg. loss: 0.067595
# Total training time: 0.00 seconds.
# -- Epoch 98
# Norm: 1.58, NNZs: 30, Bias: -0.271000, T: 25970, Avg. loss: 0.067821
# Total training time: 0.00 seconds.
# -- Epoch 99
# Norm: 1.58, NNZs: 30, Bias: -0.271000, T: 26235, Avg. loss: 0.067544
# Total training time: 0.00 seconds.
# -- Epoch 100
# Norm: 1.59, NNZs: 30, Bias: -0.270000, T: 26500, Avg. loss: 0.067427
# Total training time: 0.00 seconds.
# -- Epoch 101
# Norm: 1.59, NNZs: 30, Bias: -0.270000, T: 26765, Avg. loss: 0.067233
# Total training time: 0.00 seconds.
# -- Epoch 102
# Norm: 1.60, NNZs: 30, Bias: -0.270000, T: 27030, Avg. loss: 0.067068
# Total training time: 0.00 seconds.
# -- Epoch 103
# Norm: 1.60, NNZs: 30, Bias: -0.269000, T: 27295, Avg. loss: 0.066834
# Total training time: 0.00 seconds.
# -- Epoch 104
# Norm: 1.61, NNZs: 30, Bias: -0.269000, T: 27560, Avg. loss: 0.066730
# Total training time: 0.00 seconds.
# -- Epoch 105
# Norm: 1.61, NNZs: 30, Bias: -0.269000, T: 27825, Avg. loss: 0.066777
# Total training time: 0.00 seconds.
# -- Epoch 106
# Norm: 1.62, NNZs: 30, Bias: -0.269000, T: 28090, Avg. loss: 0.066332
# Total training time: 0.00 seconds.
# -- Epoch 107
# Norm: 1.62, NNZs: 30, Bias: -0.268000, T: 28355, Avg. loss: 0.066571
# Total training time: 0.00 seconds.
# -- Epoch 108
# Norm: 1.63, NNZs: 30, Bias: -0.267000, T: 28620, Avg. loss: 0.066107
# Total training time: 0.00 seconds.
# -- Epoch 109
# Norm: 1.63, NNZs: 30, Bias: -0.265000, T: 28885, Avg. loss: 0.066296
# Total training time: 0.00 seconds.
# -- Epoch 110
# Norm: 1.64, NNZs: 30, Bias: -0.264000, T: 29150, Avg. loss: 0.065975
# Total training time: 0.00 seconds.
# -- Epoch 111
# Norm: 1.64, NNZs: 30, Bias: -0.264000, T: 29415, Avg. loss: 0.065904
# Total training time: 0.00 seconds.
# -- Epoch 112
# Norm: 1.64, NNZs: 30, Bias: -0.265000, T: 29680, Avg. loss: 0.065404
# Total training time: 0.00 seconds.
# -- Epoch 113
# Norm: 1.65, NNZs: 30, Bias: -0.264000, T: 29945, Avg. loss: 0.065811
# Total training time: 0.00 seconds.
# -- Epoch 114
# Norm: 1.65, NNZs: 30, Bias: -0.264000, T: 30210, Avg. loss: 0.065293
# Total training time: 0.00 seconds.
# -- Epoch 115
# Norm: 1.66, NNZs: 30, Bias: -0.264000, T: 30475, Avg. loss: 0.065321
# Total training time: 0.00 seconds.
# -- Epoch 116
# Norm: 1.66, NNZs: 30, Bias: -0.262000, T: 30740, Avg. loss: 0.065259
# Total training time: 0.00 seconds.
# -- Epoch 117
# Norm: 1.67, NNZs: 30, Bias: -0.261000, T: 31005, Avg. loss: 0.064931
# Total training time: 0.00 seconds.
# -- Epoch 118
# Norm: 1.67, NNZs: 30, Bias: -0.261000, T: 31270, Avg. loss: 0.064732
# Total training time: 0.00 seconds.
# -- Epoch 119
# Norm: 1.68, NNZs: 30, Bias: -0.259000, T: 31535, Avg. loss: 0.064913
# Total training time: 0.00 seconds.
# -- Epoch 120
# Norm: 1.68, NNZs: 30, Bias: -0.258000, T: 31800, Avg. loss: 0.064608
# Total training time: 0.00 seconds.
# -- Epoch 121
# Norm: 1.69, NNZs: 30, Bias: -0.257000, T: 32065, Avg. loss: 0.064625
# Total training time: 0.00 seconds.
# -- Epoch 122
# Norm: 1.69, NNZs: 30, Bias: -0.258000, T: 32330, Avg. loss: 0.064370
# Total training time: 0.00 seconds.
# -- Epoch 123
# Norm: 1.69, NNZs: 30, Bias: -0.258000, T: 32595, Avg. loss: 0.064452
# Total training time: 0.00 seconds.
# -- Epoch 124
# Norm: 1.70, NNZs: 30, Bias: -0.258000, T: 32860, Avg. loss: 0.064228
# Total training time: 0.00 seconds.
# -- Epoch 125
# Norm: 1.70, NNZs: 30, Bias: -0.258000, T: 33125, Avg. loss: 0.064138
# Total training time: 0.00 seconds.
# -- Epoch 126
# Norm: 1.70, NNZs: 30, Bias: -0.258000, T: 33390, Avg. loss: 0.064052
# Total training time: 0.00 seconds.
# -- Epoch 127
# Norm: 1.71, NNZs: 30, Bias: -0.259000, T: 33655, Avg. loss: 0.063962
# Total training time: 0.00 seconds.
# -- Epoch 128
# Norm: 1.71, NNZs: 30, Bias: -0.258000, T: 33920, Avg. loss: 0.063765
# Total training time: 0.00 seconds.
# -- Epoch 129
# Norm: 1.72, NNZs: 30, Bias: -0.258000, T: 34185, Avg. loss: 0.063853
# Total training time: 0.00 seconds.
# -- Epoch 130
# Norm: 1.72, NNZs: 30, Bias: -0.259000, T: 34450, Avg. loss: 0.063587
# Total training time: 0.00 seconds.
# -- Epoch 131
# Norm: 1.72, NNZs: 30, Bias: -0.259000, T: 34715, Avg. loss: 0.063453
# Total training time: 0.00 seconds.
# -- Epoch 132
# Norm: 1.73, NNZs: 30, Bias: -0.259000, T: 34980, Avg. loss: 0.063649
# Total training time: 0.00 seconds.
# -- Epoch 133
# Norm: 1.73, NNZs: 30, Bias: -0.258000, T: 35245, Avg. loss: 0.063306
# Total training time: 0.00 seconds.
# -- Epoch 134
# Norm: 1.74, NNZs: 30, Bias: -0.259000, T: 35510, Avg. loss: 0.063348
# Total training time: 0.00 seconds.
# -- Epoch 135
# Norm: 1.74, NNZs: 30, Bias: -0.260000, T: 35775, Avg. loss: 0.063071
# Total training time: 0.00 seconds.
# -- Epoch 136
# Norm: 1.74, NNZs: 30, Bias: -0.260000, T: 36040, Avg. loss: 0.063222
# Total training time: 0.00 seconds.
# -- Epoch 137
# Norm: 1.75, NNZs: 30, Bias: -0.260000, T: 36305, Avg. loss: 0.062998
# Total training time: 0.00 seconds.
# -- Epoch 138
# Norm: 1.75, NNZs: 30, Bias: -0.261000, T: 36570, Avg. loss: 0.062879
# Total training time: 0.00 seconds.
# -- Epoch 139
# Norm: 1.75, NNZs: 30, Bias: -0.261000, T: 36835, Avg. loss: 0.062598
# Total training time: 0.00 seconds.
# -- Epoch 140
# Norm: 1.76, NNZs: 30, Bias: -0.260000, T: 37100, Avg. loss: 0.062829
# Total training time: 0.00 seconds.
# -- Epoch 141
# Norm: 1.76, NNZs: 30, Bias: -0.261000, T: 37365, Avg. loss: 0.062408
# Total training time: 0.00 seconds.
# -- Epoch 142
# Norm: 1.76, NNZs: 30, Bias: -0.260000, T: 37630, Avg. loss: 0.062382
# Total training time: 0.00 seconds.
# -- Epoch 143
# Norm: 1.77, NNZs: 30, Bias: -0.259000, T: 37895, Avg. loss: 0.062555
# Total training time: 0.00 seconds.
# -- Epoch 144
# Norm: 1.77, NNZs: 30, Bias: -0.260000, T: 38160, Avg. loss: 0.062206
# Total training time: 0.00 seconds.
# -- Epoch 145
# Norm: 1.78, NNZs: 30, Bias: -0.260000, T: 38425, Avg. loss: 0.062360
# Total training time: 0.00 seconds.
# -- Epoch 146
# Norm: 1.78, NNZs: 30, Bias: -0.261000, T: 38690, Avg. loss: 0.061971
# Total training time: 0.00 seconds.
# -- Epoch 147
# Norm: 1.78, NNZs: 30, Bias: -0.262000, T: 38955, Avg. loss: 0.062061
# Total training time: 0.00 seconds.
# -- Epoch 148
# Norm: 1.79, NNZs: 30, Bias: -0.263000, T: 39220, Avg. loss: 0.061885
# Total training time: 0.00 seconds.
# -- Epoch 149
# Norm: 1.79, NNZs: 30, Bias: -0.264000, T: 39485, Avg. loss: 0.061593
# Total training time: 0.00 seconds.
# -- Epoch 150
# Norm: 1.80, NNZs: 30, Bias: -0.264000, T: 39750, Avg. loss: 0.062012
# Total training time: 0.00 seconds.
# -- Epoch 151
# Norm: 1.80, NNZs: 30, Bias: -0.264000, T: 40015, Avg. loss: 0.061788
# Total training time: 0.00 seconds.
# -- Epoch 152
# Norm: 1.80, NNZs: 30, Bias: -0.265000, T: 40280, Avg. loss: 0.061442
# Total training time: 0.00 seconds.
# -- Epoch 153
# Norm: 1.81, NNZs: 30, Bias: -0.265000, T: 40545, Avg. loss: 0.061591
# Total training time: 0.00 seconds.
# -- Epoch 154
# Norm: 1.81, NNZs: 30, Bias: -0.266000, T: 40810, Avg. loss: 0.061355
# Total training time: 0.00 seconds.
# -- Epoch 155
# Norm: 1.81, NNZs: 30, Bias: -0.266000, T: 41075, Avg. loss: 0.061399
# Total training time: 0.00 seconds.
# -- Epoch 156
# Norm: 1.82, NNZs: 30, Bias: -0.267000, T: 41340, Avg. loss: 0.061325
# Total training time: 0.00 seconds.
# -- Epoch 157
# Norm: 1.82, NNZs: 30, Bias: -0.268000, T: 41605, Avg. loss: 0.061150
# Total training time: 0.00 seconds.
# -- Epoch 158
# Norm: 1.82, NNZs: 30, Bias: -0.268000, T: 41870, Avg. loss: 0.061056
# Total training time: 0.00 seconds.
# -- Epoch 159
# Norm: 1.82, NNZs: 30, Bias: -0.268000, T: 42135, Avg. loss: 0.061136
# Total training time: 0.00 seconds.
# -- Epoch 160
# Norm: 1.83, NNZs: 30, Bias: -0.269000, T: 42400, Avg. loss: 0.060983
# Total training time: 0.00 seconds.
# -- Epoch 161
# Norm: 1.83, NNZs: 30, Bias: -0.269000, T: 42665, Avg. loss: 0.061119
# Total training time: 0.00 seconds.
# -- Epoch 162
# Norm: 1.83, NNZs: 30, Bias: -0.270000, T: 42930, Avg. loss: 0.060911
# Total training time: 0.00 seconds.
# Convergence after 162 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 0.39, NNZs: 30, Bias: -0.064000, T: 266, Avg. loss: 0.444518
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.50, NNZs: 30, Bias: -0.106000, T: 532, Avg. loss: 0.215170
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.58, NNZs: 30, Bias: -0.131000, T: 798, Avg. loss: 0.173636
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.63, NNZs: 30, Bias: -0.150000, T: 1064, Avg. loss: 0.150778
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.68, NNZs: 30, Bias: -0.167000, T: 1330, Avg. loss: 0.136856
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.72, NNZs: 30, Bias: -0.182000, T: 1596, Avg. loss: 0.125736
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.76, NNZs: 30, Bias: -0.197000, T: 1862, Avg. loss: 0.116686
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.79, NNZs: 30, Bias: -0.207000, T: 2128, Avg. loss: 0.109477
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.83, NNZs: 30, Bias: -0.216000, T: 2394, Avg. loss: 0.104664
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.85, NNZs: 30, Bias: -0.222000, T: 2660, Avg. loss: 0.100410
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.88, NNZs: 30, Bias: -0.226000, T: 2926, Avg. loss: 0.097031
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 0.90, NNZs: 30, Bias: -0.230000, T: 3192, Avg. loss: 0.094531
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 0.92, NNZs: 30, Bias: -0.233000, T: 3458, Avg. loss: 0.091975
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 0.94, NNZs: 30, Bias: -0.233000, T: 3724, Avg. loss: 0.089560
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 0.96, NNZs: 30, Bias: -0.235000, T: 3990, Avg. loss: 0.087945
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 0.98, NNZs: 30, Bias: -0.237000, T: 4256, Avg. loss: 0.086053
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 1.00, NNZs: 30, Bias: -0.237000, T: 4522, Avg. loss: 0.084366
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 1.01, NNZs: 30, Bias: -0.238000, T: 4788, Avg. loss: 0.082833
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 1.03, NNZs: 30, Bias: -0.239000, T: 5054, Avg. loss: 0.081405
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 1.05, NNZs: 30, Bias: -0.242000, T: 5320, Avg. loss: 0.080020
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 1.07, NNZs: 30, Bias: -0.244000, T: 5586, Avg. loss: 0.078606
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 1.08, NNZs: 30, Bias: -0.245000, T: 5852, Avg. loss: 0.077359
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 1.09, NNZs: 30, Bias: -0.246000, T: 6118, Avg. loss: 0.076440
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 1.11, NNZs: 30, Bias: -0.248000, T: 6384, Avg. loss: 0.075442
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 1.12, NNZs: 30, Bias: -0.250000, T: 6650, Avg. loss: 0.074495
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 1.13, NNZs: 30, Bias: -0.251000, T: 6916, Avg. loss: 0.073301
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 1.15, NNZs: 30, Bias: -0.252000, T: 7182, Avg. loss: 0.072559
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 1.16, NNZs: 30, Bias: -0.254000, T: 7448, Avg. loss: 0.071583
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 1.18, NNZs: 30, Bias: -0.257000, T: 7714, Avg. loss: 0.070415
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 1.19, NNZs: 30, Bias: -0.259000, T: 7980, Avg. loss: 0.069646
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 1.20, NNZs: 30, Bias: -0.262000, T: 8246, Avg. loss: 0.068828
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 1.21, NNZs: 30, Bias: -0.264000, T: 8512, Avg. loss: 0.068375
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 1.22, NNZs: 30, Bias: -0.266000, T: 8778, Avg. loss: 0.067612
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 1.23, NNZs: 30, Bias: -0.268000, T: 9044, Avg. loss: 0.066641
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 1.25, NNZs: 30, Bias: -0.269000, T: 9310, Avg. loss: 0.066298
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 1.26, NNZs: 30, Bias: -0.269000, T: 9576, Avg. loss: 0.065629
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 1.27, NNZs: 30, Bias: -0.272000, T: 9842, Avg. loss: 0.064992
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 1.27, NNZs: 30, Bias: -0.274000, T: 10108, Avg. loss: 0.064327
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 1.28, NNZs: 30, Bias: -0.274000, T: 10374, Avg. loss: 0.064215
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 1.29, NNZs: 30, Bias: -0.274000, T: 10640, Avg. loss: 0.063623
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 1.30, NNZs: 30, Bias: -0.273000, T: 10906, Avg. loss: 0.063073
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 1.31, NNZs: 30, Bias: -0.275000, T: 11172, Avg. loss: 0.062770
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 1.32, NNZs: 30, Bias: -0.278000, T: 11438, Avg. loss: 0.062222
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 1.32, NNZs: 30, Bias: -0.279000, T: 11704, Avg. loss: 0.062047
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 1.33, NNZs: 30, Bias: -0.280000, T: 11970, Avg. loss: 0.061410
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 1.34, NNZs: 30, Bias: -0.279000, T: 12236, Avg. loss: 0.061428
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 1.35, NNZs: 30, Bias: -0.278000, T: 12502, Avg. loss: 0.061080
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 1.35, NNZs: 30, Bias: -0.278000, T: 12768, Avg. loss: 0.060726
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 1.36, NNZs: 30, Bias: -0.279000, T: 13034, Avg. loss: 0.060244
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 1.37, NNZs: 30, Bias: -0.277000, T: 13300, Avg. loss: 0.060061
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 1.37, NNZs: 30, Bias: -0.276000, T: 13566, Avg. loss: 0.059770
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 1.38, NNZs: 30, Bias: -0.277000, T: 13832, Avg. loss: 0.059304
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 1.39, NNZs: 30, Bias: -0.276000, T: 14098, Avg. loss: 0.059197
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 1.39, NNZs: 30, Bias: -0.275000, T: 14364, Avg. loss: 0.058780
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 1.40, NNZs: 30, Bias: -0.276000, T: 14630, Avg. loss: 0.058392
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 1.41, NNZs: 30, Bias: -0.277000, T: 14896, Avg. loss: 0.057792
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 1.41, NNZs: 30, Bias: -0.276000, T: 15162, Avg. loss: 0.058052
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 1.42, NNZs: 30, Bias: -0.276000, T: 15428, Avg. loss: 0.057711
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 1.43, NNZs: 30, Bias: -0.274000, T: 15694, Avg. loss: 0.057297
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 1.44, NNZs: 30, Bias: -0.273000, T: 15960, Avg. loss: 0.056999
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 1.44, NNZs: 30, Bias: -0.274000, T: 16226, Avg. loss: 0.056420
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 1.45, NNZs: 30, Bias: -0.272000, T: 16492, Avg. loss: 0.056460
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 1.46, NNZs: 30, Bias: -0.271000, T: 16758, Avg. loss: 0.056078
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 1.46, NNZs: 30, Bias: -0.270000, T: 17024, Avg. loss: 0.055499
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 1.47, NNZs: 30, Bias: -0.270000, T: 17290, Avg. loss: 0.055565
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 1.48, NNZs: 30, Bias: -0.268000, T: 17556, Avg. loss: 0.055252
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 1.48, NNZs: 30, Bias: -0.267000, T: 17822, Avg. loss: 0.054886
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 1.49, NNZs: 30, Bias: -0.264000, T: 18088, Avg. loss: 0.054476
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 1.50, NNZs: 30, Bias: -0.263000, T: 18354, Avg. loss: 0.054357
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 1.50, NNZs: 30, Bias: -0.260000, T: 18620, Avg. loss: 0.053957
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 1.51, NNZs: 30, Bias: -0.260000, T: 18886, Avg. loss: 0.053793
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 1.52, NNZs: 30, Bias: -0.259000, T: 19152, Avg. loss: 0.053532
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 1.52, NNZs: 30, Bias: -0.257000, T: 19418, Avg. loss: 0.053194
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 1.53, NNZs: 30, Bias: -0.255000, T: 19684, Avg. loss: 0.053001
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 1.53, NNZs: 30, Bias: -0.255000, T: 19950, Avg. loss: 0.052690
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 1.54, NNZs: 30, Bias: -0.253000, T: 20216, Avg. loss: 0.052436
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 1.54, NNZs: 30, Bias: -0.253000, T: 20482, Avg. loss: 0.052288
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 1.55, NNZs: 30, Bias: -0.251000, T: 20748, Avg. loss: 0.052063
# Total training time: 0.00 seconds.
# -- Epoch 79
# Norm: 1.56, NNZs: 30, Bias: -0.252000, T: 21014, Avg. loss: 0.051637
# Total training time: 0.00 seconds.
# -- Epoch 80
# Norm: 1.56, NNZs: 30, Bias: -0.251000, T: 21280, Avg. loss: 0.051485
# Total training time: 0.00 seconds.
# -- Epoch 81
# Norm: 1.57, NNZs: 30, Bias: -0.251000, T: 21546, Avg. loss: 0.051138
# Total training time: 0.00 seconds.
# -- Epoch 82
# Norm: 1.57, NNZs: 30, Bias: -0.249000, T: 21812, Avg. loss: 0.051078
# Total training time: 0.00 seconds.
# -- Epoch 83
# Norm: 1.58, NNZs: 30, Bias: -0.248000, T: 22078, Avg. loss: 0.050804
# Total training time: 0.00 seconds.
# -- Epoch 84
# Norm: 1.58, NNZs: 30, Bias: -0.247000, T: 22344, Avg. loss: 0.050551
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 1.59, NNZs: 30, Bias: -0.245000, T: 22610, Avg. loss: 0.050306
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 1.60, NNZs: 30, Bias: -0.243000, T: 22876, Avg. loss: 0.050090
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 1.60, NNZs: 30, Bias: -0.241000, T: 23142, Avg. loss: 0.049810
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 1.61, NNZs: 30, Bias: -0.239000, T: 23408, Avg. loss: 0.049552
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 1.61, NNZs: 30, Bias: -0.238000, T: 23674, Avg. loss: 0.049460
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 1.61, NNZs: 30, Bias: -0.239000, T: 23940, Avg. loss: 0.048960
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 1.62, NNZs: 30, Bias: -0.238000, T: 24206, Avg. loss: 0.048832
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 1.62, NNZs: 30, Bias: -0.236000, T: 24472, Avg. loss: 0.048644
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 1.63, NNZs: 30, Bias: -0.234000, T: 24738, Avg. loss: 0.048527
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 1.63, NNZs: 30, Bias: -0.233000, T: 25004, Avg. loss: 0.048388
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 1.64, NNZs: 30, Bias: -0.232000, T: 25270, Avg. loss: 0.047983
# Total training time: 0.00 seconds.
# -- Epoch 96
# Norm: 1.64, NNZs: 30, Bias: -0.232000, T: 25536, Avg. loss: 0.047796
# Total training time: 0.00 seconds.
# -- Epoch 97
# Norm: 1.65, NNZs: 30, Bias: -0.231000, T: 25802, Avg. loss: 0.047584
# Total training time: 0.00 seconds.
# -- Epoch 98
# Norm: 1.66, NNZs: 30, Bias: -0.231000, T: 26068, Avg. loss: 0.047433
# Total training time: 0.00 seconds.
# -- Epoch 99
# Norm: 1.66, NNZs: 30, Bias: -0.228000, T: 26334, Avg. loss: 0.047272
# Total training time: 0.00 seconds.
# -- Epoch 100
# Norm: 1.67, NNZs: 30, Bias: -0.227000, T: 26600, Avg. loss: 0.047265
# Total training time: 0.00 seconds.
# -- Epoch 101
# Norm: 1.67, NNZs: 30, Bias: -0.226000, T: 26866, Avg. loss: 0.047190
# Total training time: 0.00 seconds.
# -- Epoch 102
# Norm: 1.68, NNZs: 30, Bias: -0.225000, T: 27132, Avg. loss: 0.046686
# Total training time: 0.00 seconds.
# -- Epoch 103
# Norm: 1.68, NNZs: 30, Bias: -0.225000, T: 27398, Avg. loss: 0.046719
# Total training time: 0.00 seconds.
# -- Epoch 104
# Norm: 1.69, NNZs: 30, Bias: -0.224000, T: 27664, Avg. loss: 0.046338
# Total training time: 0.00 seconds.
# -- Epoch 105
# Norm: 1.69, NNZs: 30, Bias: -0.224000, T: 27930, Avg. loss: 0.046405
# Total training time: 0.00 seconds.
# -- Epoch 106
# Norm: 1.70, NNZs: 30, Bias: -0.224000, T: 28196, Avg. loss: 0.045763
# Total training time: 0.00 seconds.
# -- Epoch 107
# Norm: 1.70, NNZs: 30, Bias: -0.222000, T: 28462, Avg. loss: 0.046038
# Total training time: 0.00 seconds.
# -- Epoch 108
# Norm: 1.71, NNZs: 30, Bias: -0.223000, T: 28728, Avg. loss: 0.046014
# Total training time: 0.00 seconds.
# -- Epoch 109
# Norm: 1.71, NNZs: 30, Bias: -0.222000, T: 28994, Avg. loss: 0.046076
# Total training time: 0.00 seconds.
# -- Epoch 110
# Norm: 1.72, NNZs: 30, Bias: -0.220000, T: 29260, Avg. loss: 0.045558
# Total training time: 0.00 seconds.
# -- Epoch 111
# Norm: 1.72, NNZs: 30, Bias: -0.220000, T: 29526, Avg. loss: 0.045466
# Total training time: 0.00 seconds.
# -- Epoch 112
# Norm: 1.72, NNZs: 30, Bias: -0.221000, T: 29792, Avg. loss: 0.045201
# Total training time: 0.00 seconds.
# -- Epoch 113
# Norm: 1.73, NNZs: 30, Bias: -0.220000, T: 30058, Avg. loss: 0.045047
# Total training time: 0.00 seconds.
# -- Epoch 114
# Norm: 1.73, NNZs: 30, Bias: -0.221000, T: 30324, Avg. loss: 0.045160
# Total training time: 0.00 seconds.
# -- Epoch 115
# Norm: 1.73, NNZs: 30, Bias: -0.222000, T: 30590, Avg. loss: 0.045592
# Total training time: 0.00 seconds.
# -- Epoch 116
# Norm: 1.74, NNZs: 30, Bias: -0.221000, T: 30856, Avg. loss: 0.044833
# Total training time: 0.00 seconds.
# -- Epoch 117
# Norm: 1.74, NNZs: 30, Bias: -0.220000, T: 31122, Avg. loss: 0.044908
# Total training time: 0.00 seconds.
# -- Epoch 118
# Norm: 1.75, NNZs: 30, Bias: -0.220000, T: 31388, Avg. loss: 0.045227
# Total training time: 0.00 seconds.
# -- Epoch 119
# Norm: 1.75, NNZs: 30, Bias: -0.220000, T: 31654, Avg. loss: 0.044536
# Total training time: 0.00 seconds.
# -- Epoch 120
# Norm: 1.76, NNZs: 30, Bias: -0.219000, T: 31920, Avg. loss: 0.044477
# Total training time: 0.00 seconds.
# -- Epoch 121
# Norm: 1.76, NNZs: 30, Bias: -0.220000, T: 32186, Avg. loss: 0.044202
# Total training time: 0.00 seconds.
# -- Epoch 122
# Norm: 1.76, NNZs: 30, Bias: -0.220000, T: 32452, Avg. loss: 0.044288
# Total training time: 0.00 seconds.
# -- Epoch 123
# Norm: 1.77, NNZs: 30, Bias: -0.220000, T: 32718, Avg. loss: 0.044101
# Total training time: 0.00 seconds.
# -- Epoch 124
# Norm: 1.77, NNZs: 30, Bias: -0.221000, T: 32984, Avg. loss: 0.043851
# Total training time: 0.00 seconds.
# -- Epoch 125
# Norm: 1.78, NNZs: 30, Bias: -0.219000, T: 33250, Avg. loss: 0.044158
# Total training time: 0.00 seconds.
# -- Epoch 126
# Norm: 1.78, NNZs: 30, Bias: -0.219000, T: 33516, Avg. loss: 0.044259
# Total training time: 0.00 seconds.
# -- Epoch 127
# Norm: 1.78, NNZs: 30, Bias: -0.218000, T: 33782, Avg. loss: 0.043647
# Total training time: 0.00 seconds.
# -- Epoch 128
# Norm: 1.79, NNZs: 30, Bias: -0.217000, T: 34048, Avg. loss: 0.043674
# Total training time: 0.00 seconds.
# -- Epoch 129
# Norm: 1.79, NNZs: 30, Bias: -0.218000, T: 34314, Avg. loss: 0.043387
# Total training time: 0.00 seconds.
# -- Epoch 130
# Norm: 1.79, NNZs: 30, Bias: -0.218000, T: 34580, Avg. loss: 0.043447
# Total training time: 0.00 seconds.
# -- Epoch 131
# Norm: 1.80, NNZs: 30, Bias: -0.220000, T: 34846, Avg. loss: 0.043125
# Total training time: 0.00 seconds.
# -- Epoch 132
# Norm: 1.80, NNZs: 30, Bias: -0.220000, T: 35112, Avg. loss: 0.043290
# Total training time: 0.00 seconds.
# -- Epoch 133
# Norm: 1.80, NNZs: 30, Bias: -0.220000, T: 35378, Avg. loss: 0.043808
# Total training time: 0.00 seconds.
# -- Epoch 134
# Norm: 1.81, NNZs: 30, Bias: -0.217000, T: 35644, Avg. loss: 0.043314
# Total training time: 0.00 seconds.
# -- Epoch 135
# Norm: 1.81, NNZs: 30, Bias: -0.216000, T: 35910, Avg. loss: 0.042948
# Total training time: 0.00 seconds.
# -- Epoch 136
# Norm: 1.82, NNZs: 30, Bias: -0.217000, T: 36176, Avg. loss: 0.043188
# Total training time: 0.00 seconds.
# -- Epoch 137
# Norm: 1.82, NNZs: 30, Bias: -0.216000, T: 36442, Avg. loss: 0.043123
# Total training time: 0.00 seconds.
# -- Epoch 138
# Norm: 1.82, NNZs: 30, Bias: -0.216000, T: 36708, Avg. loss: 0.042651
# Total training time: 0.00 seconds.
# -- Epoch 139
# Norm: 1.83, NNZs: 30, Bias: -0.216000, T: 36974, Avg. loss: 0.042706
# Total training time: 0.00 seconds.
# -- Epoch 140
# Norm: 1.83, NNZs: 30, Bias: -0.219000, T: 37240, Avg. loss: 0.042423
# Total training time: 0.00 seconds.
# -- Epoch 141
# Norm: 1.83, NNZs: 30, Bias: -0.218000, T: 37506, Avg. loss: 0.042550
# Total training time: 0.00 seconds.
# -- Epoch 142
# Norm: 1.84, NNZs: 30, Bias: -0.217000, T: 37772, Avg. loss: 0.042339
# Total training time: 0.00 seconds.
# -- Epoch 143
# Norm: 1.84, NNZs: 30, Bias: -0.216000, T: 38038, Avg. loss: 0.042200
# Total training time: 0.00 seconds.
# -- Epoch 144
# Norm: 1.84, NNZs: 30, Bias: -0.216000, T: 38304, Avg. loss: 0.042191
# Total training time: 0.00 seconds.
# -- Epoch 145
# Norm: 1.85, NNZs: 30, Bias: -0.217000, T: 38570, Avg. loss: 0.041688
# Total training time: 0.00 seconds.
# -- Epoch 146
# Norm: 1.85, NNZs: 30, Bias: -0.217000, T: 38836, Avg. loss: 0.042534
# Total training time: 0.00 seconds.
# -- Epoch 147
# Norm: 1.86, NNZs: 30, Bias: -0.217000, T: 39102, Avg. loss: 0.042047
# Total training time: 0.00 seconds.
# -- Epoch 148
# Norm: 1.86, NNZs: 30, Bias: -0.217000, T: 39368, Avg. loss: 0.041813
# Total training time: 0.00 seconds.
# -- Epoch 149
# Norm: 1.86, NNZs: 30, Bias: -0.217000, T: 39634, Avg. loss: 0.041675
# Total training time: 0.00 seconds.
# -- Epoch 150
# Norm: 1.87, NNZs: 30, Bias: -0.216000, T: 39900, Avg. loss: 0.041914
# Total training time: 0.00 seconds.
# Convergence after 150 epochs took 0.00 seconds

# %%
# Cell 4: Final Decision
print("=" * 70)
print("FINAL MODEL SELECTION DECISION")
print("=" * 70)

# Find best model based on sensitivity (most important for medical context)
best_sensitivity_model = comparison_df.loc[comparison_df['Sensitivity'].idxmax()]
best_accuracy_model = comparison_df.loc[comparison_df['Accuracy'].idxmax()]

print("🎯 DECISION BASIS:")
print(f"   • Primary Metric: Sensitivity (Critical for cancer detection)")
print(f"   • Secondary Metric: Accuracy")
print(f"\n🏆 BEST MODELS:")
print(f"   • Highest Sensitivity: {best_sensitivity_model['Model']} ({best_sensitivity_model['Sensitivity']:.4f})")
print(f"   • Highest Accuracy: {best_accuracy_model['Model']} ({best_accuracy_model['Accuracy']:.4f})")

print(f"\n✅ FINAL SELECTION: SVM with SGD")
print(f"   • Excellent Sensitivity: {metrics_sgd['Sensitivity']:.4f}")
print(f"   • High Accuracy: {metrics_sgd['Accuracy']:.4f}")
print(f"   • Good Precision: {metrics_sgd['Precision']:.4f}")
print(f"   • Medical Priority: Maximizing cancer detection (sensitivity)")

print(f"\n🚀 NEXT STEPS:")
print(f"   • Proceed with SVM with SGD for calibration and deployment")
print(f"   • Focus on reliable probability outputs for clinical use")
# Out:
# ======================================================================
# FINAL MODEL SELECTION DECISION
# ======================================================================
# 🎯 DECISION BASIS:
#    • Primary Metric: Sensitivity (Critical for cancer detection)
#    • Secondary Metric: Accuracy
#
# 🏆 BEST MODELS:
#    • Highest Sensitivity: Logistic Regression (0.9841)
#    • Highest Accuracy: SGD SVM (0.9883)
#
# ✅ FINAL SELECTION: SVM with SGD
#    • Excellent Sensitivity: 0.9841
#    • High Accuracy: 0.9883
#    • Good Precision: 0.9841
#    • Medical Priority: Maximizing cancer detection (sensitivity)
#
# 🚀 NEXT STEPS:
#    • Proceed with SVM with SGD for calibration and deployment
#    • Focus on reliable probability outputs for clinical use

# %% [markdown]
# ## Probability Calibration for the SVM-SGD model :

# %%
# === CALIBRATION DU MODÈLE SGD SVM ===

from sklearn.calibration import calibration_curve, CalibratedClassifierCV
import numpy as np
import matplotlib.pyplot as plt

# 1. Calibration du modèle SGD SVM
sgd_svm_calibrated = CalibratedClassifierCV(sgd_svm, method='sigmoid', cv=5)
sgd_svm_calibrated.fit(X_train_scaled, y_train)

# Probabilités calibrées
y_proba_calibrated = sgd_svm_calibrated.predict_proba(X_test_scaled)[:, 1]

# 2. Diagramme de fiabilité
fraction_of_positives, mean_predicted_value = calibration_curve(
    y_test, y_proba_calibrated, n_bins=10, strategy='quantile'
)

plt.figure(figsize=(8, 6))
plt.plot(mean_predicted_value, fraction_of_positives, "s-", label="SGD SVM Calibré", color='red', linewidth=2)
plt.plot([0, 1], [0, 1], "k:", label="Calibration Parfaite")
plt.xlabel('Probabilité Prédite Moyenne')
plt.ylabel('Fraction de Positifs Réels')
plt.title('Diagramme de Fiabilité - SGD SVM')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# 3. Métriques de calibration
def expected_calibration_error(y_true, y_proba, n_bins=10):
    bin_edges = np.linspace(0, 1, n_bins + 1)
    bin_indices = np.digitize(y_proba, bin_edges) - 1
    ece = 0.0
    for bin_idx in range(n_bins):
        mask = bin_indices == bin_idx
        if np.sum(mask) > 0:
            bin_acc = np.mean(y_true[mask])
            bin_conf = np.mean(y_proba[mask])
            ece += (np.sum(mask) / len(y_true)) * np.abs(bin_acc - bin_conf)
    return ece

ece = expected_calibration_error(y_test, y_proba_calibrated)
brier_score = np.mean((y_proba_calibrated - y_test) ** 2)

print(f"📊 MÉTRIQUES DE CALIBRATION:")
print(f"ECE: {ece:.4f} | Brier Score: {brier_score:.4f}")

# 4. Sauvegarde du modèle calibré
import joblib
joblib.dump(sgd_svm_calibrated, 'sgd_svm_calibre.pkl')
print("✅ Modèle calibré sauvegardé: 'sgd_svm_calibre.pkl'")
# Out:
# -- Epoch 1
# Norm: 0.41, NNZs: 30, Bias: -0.080000, T: 318, Avg. loss: 0.413802
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.53, NNZs: 30, Bias: -0.126000, T: 636, Avg. loss: 0.200294
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.60, NNZs: 30, Bias: -0.154000, T: 954, Avg. loss: 0.162139
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.65, NNZs: 30, Bias: -0.171000, T: 1272, Avg. loss: 0.146118
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.69, NNZs: 30, Bias: -0.187000, T: 1590, Avg. loss: 0.136455
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.73, NNZs: 30, Bias: -0.199000, T: 1908, Avg. loss: 0.129175
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.77, NNZs: 30, Bias: -0.211000, T: 2226, Avg. loss: 0.122692
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.80, NNZs: 30, Bias: -0.223000, T: 2544, Avg. loss: 0.117293
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.83, NNZs: 30, Bias: -0.233000, T: 2862, Avg. loss: 0.112482
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.86, NNZs: 30, Bias: -0.244000, T: 3180, Avg. loss: 0.108138
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.89, NNZs: 30, Bias: -0.249000, T: 3498, Avg. loss: 0.104802
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 0.91, NNZs: 30, Bias: -0.255000, T: 3816, Avg. loss: 0.101434
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 0.94, NNZs: 30, Bias: -0.261000, T: 4134, Avg. loss: 0.098569
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 0.96, NNZs: 30, Bias: -0.264000, T: 4452, Avg. loss: 0.096231
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 0.98, NNZs: 30, Bias: -0.268000, T: 4770, Avg. loss: 0.094249
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 1.00, NNZs: 30, Bias: -0.271000, T: 5088, Avg. loss: 0.092472
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 1.02, NNZs: 30, Bias: -0.272000, T: 5406, Avg. loss: 0.090583
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 1.04, NNZs: 30, Bias: -0.274000, T: 5724, Avg. loss: 0.088906
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 1.06, NNZs: 30, Bias: -0.277000, T: 6042, Avg. loss: 0.087165
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 1.08, NNZs: 30, Bias: -0.279000, T: 6360, Avg. loss: 0.085270
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 1.10, NNZs: 30, Bias: -0.280000, T: 6678, Avg. loss: 0.084557
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 1.11, NNZs: 30, Bias: -0.281000, T: 6996, Avg. loss: 0.083352
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 1.13, NNZs: 30, Bias: -0.280000, T: 7314, Avg. loss: 0.081962
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 1.14, NNZs: 30, Bias: -0.279000, T: 7632, Avg. loss: 0.081269
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 1.16, NNZs: 30, Bias: -0.281000, T: 7950, Avg. loss: 0.080062
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 1.17, NNZs: 30, Bias: -0.280000, T: 8268, Avg. loss: 0.079240
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 1.18, NNZs: 30, Bias: -0.278000, T: 8586, Avg. loss: 0.078640
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 1.20, NNZs: 30, Bias: -0.279000, T: 8904, Avg. loss: 0.077882
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 1.21, NNZs: 30, Bias: -0.278000, T: 9222, Avg. loss: 0.077216
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 1.22, NNZs: 30, Bias: -0.276000, T: 9540, Avg. loss: 0.076386
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 1.23, NNZs: 30, Bias: -0.274000, T: 9858, Avg. loss: 0.075828
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 1.25, NNZs: 30, Bias: -0.275000, T: 10176, Avg. loss: 0.074924
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 1.26, NNZs: 30, Bias: -0.273000, T: 10494, Avg. loss: 0.074507
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 1.27, NNZs: 30, Bias: -0.271000, T: 10812, Avg. loss: 0.073715
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 1.28, NNZs: 30, Bias: -0.272000, T: 11130, Avg. loss: 0.073125
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 1.29, NNZs: 30, Bias: -0.271000, T: 11448, Avg. loss: 0.072495
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 1.30, NNZs: 30, Bias: -0.271000, T: 11766, Avg. loss: 0.071996
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 1.31, NNZs: 30, Bias: -0.271000, T: 12084, Avg. loss: 0.071421
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 1.32, NNZs: 30, Bias: -0.272000, T: 12402, Avg. loss: 0.071092
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 1.33, NNZs: 30, Bias: -0.272000, T: 12720, Avg. loss: 0.070573
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 1.34, NNZs: 30, Bias: -0.271000, T: 13038, Avg. loss: 0.070256
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 1.35, NNZs: 30, Bias: -0.269000, T: 13356, Avg. loss: 0.069775
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 1.35, NNZs: 30, Bias: -0.268000, T: 13674, Avg. loss: 0.069463
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 1.36, NNZs: 30, Bias: -0.268000, T: 13992, Avg. loss: 0.069228
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 1.37, NNZs: 30, Bias: -0.268000, T: 14310, Avg. loss: 0.068852
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 1.38, NNZs: 30, Bias: -0.268000, T: 14628, Avg. loss: 0.068393
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 1.39, NNZs: 30, Bias: -0.267000, T: 14946, Avg. loss: 0.068129
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 1.39, NNZs: 30, Bias: -0.266000, T: 15264, Avg. loss: 0.067831
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 1.40, NNZs: 30, Bias: -0.265000, T: 15582, Avg. loss: 0.067477
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 1.41, NNZs: 30, Bias: -0.263000, T: 15900, Avg. loss: 0.067242
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 1.42, NNZs: 30, Bias: -0.264000, T: 16218, Avg. loss: 0.066963
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 1.42, NNZs: 30, Bias: -0.263000, T: 16536, Avg. loss: 0.066675
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 1.43, NNZs: 30, Bias: -0.263000, T: 16854, Avg. loss: 0.066407
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 1.44, NNZs: 30, Bias: -0.260000, T: 17172, Avg. loss: 0.066124
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 1.44, NNZs: 30, Bias: -0.260000, T: 17490, Avg. loss: 0.065951
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 1.45, NNZs: 30, Bias: -0.259000, T: 17808, Avg. loss: 0.065667
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 1.46, NNZs: 30, Bias: -0.257000, T: 18126, Avg. loss: 0.065316
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 1.46, NNZs: 30, Bias: -0.256000, T: 18444, Avg. loss: 0.065170
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 1.47, NNZs: 30, Bias: -0.255000, T: 18762, Avg. loss: 0.064944
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 1.48, NNZs: 30, Bias: -0.254000, T: 19080, Avg. loss: 0.064624
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 1.48, NNZs: 30, Bias: -0.253000, T: 19398, Avg. loss: 0.064385
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 1.49, NNZs: 30, Bias: -0.251000, T: 19716, Avg. loss: 0.064099
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 1.50, NNZs: 30, Bias: -0.250000, T: 20034, Avg. loss: 0.063968
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 1.50, NNZs: 30, Bias: -0.247000, T: 20352, Avg. loss: 0.063601
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 1.51, NNZs: 30, Bias: -0.246000, T: 20670, Avg. loss: 0.063461
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 1.52, NNZs: 30, Bias: -0.244000, T: 20988, Avg. loss: 0.063194
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 1.52, NNZs: 30, Bias: -0.243000, T: 21306, Avg. loss: 0.063011
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 1.53, NNZs: 30, Bias: -0.241000, T: 21624, Avg. loss: 0.062779
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 1.53, NNZs: 30, Bias: -0.241000, T: 21942, Avg. loss: 0.062496
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 1.54, NNZs: 30, Bias: -0.239000, T: 22260, Avg. loss: 0.062389
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 1.54, NNZs: 30, Bias: -0.238000, T: 22578, Avg. loss: 0.062170
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 1.55, NNZs: 30, Bias: -0.236000, T: 22896, Avg. loss: 0.061931
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 1.55, NNZs: 30, Bias: -0.234000, T: 23214, Avg. loss: 0.061870
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 1.56, NNZs: 30, Bias: -0.233000, T: 23532, Avg. loss: 0.061622
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 1.56, NNZs: 30, Bias: -0.231000, T: 23850, Avg. loss: 0.061419
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 1.57, NNZs: 30, Bias: -0.229000, T: 24168, Avg. loss: 0.061331
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 1.57, NNZs: 30, Bias: -0.228000, T: 24486, Avg. loss: 0.061087
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 1.58, NNZs: 30, Bias: -0.226000, T: 24804, Avg. loss: 0.060816
# Total training time: 0.00 seconds.
# -- Epoch 79
# Norm: 1.58, NNZs: 30, Bias: -0.224000, T: 25122, Avg. loss: 0.060801
# Total training time: 0.00 seconds.
# -- Epoch 80
# Norm: 1.59, NNZs: 30, Bias: -0.222000, T: 25440, Avg. loss: 0.060559
# Total training time: 0.00 seconds.
# -- Epoch 81
# Norm: 1.59, NNZs: 30, Bias: -0.220000, T: 25758, Avg. loss: 0.060318
# Total training time: 0.00 seconds.
# -- Epoch 82
# Norm: 1.60, NNZs: 30, Bias: -0.219000, T: 26076, Avg. loss: 0.060340
# Total training time: 0.00 seconds.
# -- Epoch 83
# Norm: 1.60, NNZs: 30, Bias: -0.218000, T: 26394, Avg. loss: 0.060005
# Total training time: 0.00 seconds.
# -- Epoch 84
# Norm: 1.61, NNZs: 30, Bias: -0.216000, T: 26712, Avg. loss: 0.059937
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 1.62, NNZs: 30, Bias: -0.215000, T: 27030, Avg. loss: 0.059684
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 1.62, NNZs: 30, Bias: -0.214000, T: 27348, Avg. loss: 0.059542
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 1.62, NNZs: 30, Bias: -0.212000, T: 27666, Avg. loss: 0.059442
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 1.63, NNZs: 30, Bias: -0.210000, T: 27984, Avg. loss: 0.059267
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 1.63, NNZs: 30, Bias: -0.209000, T: 28302, Avg. loss: 0.059189
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 1.64, NNZs: 30, Bias: -0.209000, T: 28620, Avg. loss: 0.058986
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 1.64, NNZs: 30, Bias: -0.208000, T: 28938, Avg. loss: 0.058887
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 1.65, NNZs: 30, Bias: -0.208000, T: 29256, Avg. loss: 0.058669
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 1.65, NNZs: 30, Bias: -0.206000, T: 29574, Avg. loss: 0.058669
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 1.65, NNZs: 30, Bias: -0.205000, T: 29892, Avg. loss: 0.058500
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 1.66, NNZs: 30, Bias: -0.205000, T: 30210, Avg. loss: 0.058279
# Total training time: 0.00 seconds.
# -- Epoch 96
# Norm: 1.66, NNZs: 30, Bias: -0.204000, T: 30528, Avg. loss: 0.058264
# Total training time: 0.00 seconds.
# -- Epoch 97
# Norm: 1.67, NNZs: 30, Bias: -0.203000, T: 30846, Avg. loss: 0.058125
# Total training time: 0.00 seconds.
# -- Epoch 98
# Norm: 1.67, NNZs: 30, Bias: -0.202000, T: 31164, Avg. loss: 0.057963
# Total training time: 0.00 seconds.
# -- Epoch 99
# Norm: 1.68, NNZs: 30, Bias: -0.201000, T: 31482, Avg. loss: 0.057799
# Total training time: 0.00 seconds.
# -- Epoch 100
# Norm: 1.68, NNZs: 30, Bias: -0.200000, T: 31800, Avg. loss: 0.057615
# Total training time: 0.00 seconds.
# -- Epoch 101
# Norm: 1.68, NNZs: 30, Bias: -0.199000, T: 32118, Avg. loss: 0.057615
# Total training time: 0.00 seconds.
# -- Epoch 102
# Norm: 1.69, NNZs: 30, Bias: -0.199000, T: 32436, Avg. loss: 0.057507
# Total training time: 0.00 seconds.
# -- Epoch 103
# Norm: 1.69, NNZs: 30, Bias: -0.198000, T: 32754, Avg. loss: 0.057451
# Total training time: 0.00 seconds.
# -- Epoch 104
# Norm: 1.70, NNZs: 30, Bias: -0.196000, T: 33072, Avg. loss: 0.057265
# Total training time: 0.00 seconds.
# -- Epoch 105
# Norm: 1.70, NNZs: 30, Bias: -0.196000, T: 33390, Avg. loss: 0.057238
# Total training time: 0.00 seconds.
# -- Epoch 106
# Norm: 1.70, NNZs: 30, Bias: -0.197000, T: 33708, Avg. loss: 0.056861
# Total training time: 0.00 seconds.
# -- Epoch 107
# Norm: 1.71, NNZs: 30, Bias: -0.197000, T: 34026, Avg. loss: 0.057101
# Total training time: 0.00 seconds.
# -- Epoch 108
# Norm: 1.71, NNZs: 30, Bias: -0.196000, T: 34344, Avg. loss: 0.056975
# Total training time: 0.00 seconds.
# -- Epoch 109
# Norm: 1.72, NNZs: 30, Bias: -0.195000, T: 34662, Avg. loss: 0.056694
# Total training time: 0.00 seconds.
# -- Epoch 110
# Norm: 1.72, NNZs: 30, Bias: -0.196000, T: 34980, Avg. loss: 0.056766
# Total training time: 0.00 seconds.
# -- Epoch 111
# Norm: 1.72, NNZs: 30, Bias: -0.196000, T: 35298, Avg. loss: 0.056664
# Total training time: 0.00 seconds.
# -- Epoch 112
# Norm: 1.73, NNZs: 30, Bias: -0.195000, T: 35616, Avg. loss: 0.056584
# Total training time: 0.00 seconds.
# -- Epoch 113
# Norm: 1.73, NNZs: 30, Bias: -0.196000, T: 35934, Avg. loss: 0.056530
# Total training time: 0.00 seconds.
# -- Epoch 114
# Norm: 1.73, NNZs: 30, Bias: -0.195000, T: 36252, Avg. loss: 0.056313
# Total training time: 0.00 seconds.
# -- Epoch 115
# Norm: 1.74, NNZs: 30, Bias: -0.195000, T: 36570, Avg. loss: 0.056471
# Total training time: 0.00 seconds.
# -- Epoch 116
# Norm: 1.74, NNZs: 30, Bias: -0.195000, T: 36888, Avg. loss: 0.056357
# Total training time: 0.00 seconds.
# -- Epoch 117
# Norm: 1.74, NNZs: 30, Bias: -0.196000, T: 37206, Avg. loss: 0.056213
# Total training time: 0.00 seconds.
# -- Epoch 118
# Norm: 1.75, NNZs: 30, Bias: -0.196000, T: 37524, Avg. loss: 0.056131
# Total training time: 0.00 seconds.
# -- Epoch 119
# Norm: 1.75, NNZs: 30, Bias: -0.196000, T: 37842, Avg. loss: 0.056016
# Total training time: 0.00 seconds.
# -- Epoch 120
# Norm: 1.75, NNZs: 30, Bias: -0.196000, T: 38160, Avg. loss: 0.055869
# Total training time: 0.00 seconds.
# -- Epoch 121
# Norm: 1.76, NNZs: 30, Bias: -0.197000, T: 38478, Avg. loss: 0.056060
# Total training time: 0.00 seconds.
# -- Epoch 122
# Norm: 1.76, NNZs: 30, Bias: -0.196000, T: 38796, Avg. loss: 0.055905
# Total training time: 0.00 seconds.
# -- Epoch 123
# Norm: 1.77, NNZs: 30, Bias: -0.197000, T: 39114, Avg. loss: 0.055774
# Total training time: 0.00 seconds.
# -- Epoch 124
# Norm: 1.77, NNZs: 30, Bias: -0.198000, T: 39432, Avg. loss: 0.055623
# Total training time: 0.00 seconds.
# -- Epoch 125
# Norm: 1.77, NNZs: 30, Bias: -0.197000, T: 39750, Avg. loss: 0.055422
# Total training time: 0.00 seconds.
# -- Epoch 126
# Norm: 1.78, NNZs: 30, Bias: -0.196000, T: 40068, Avg. loss: 0.055600
# Total training time: 0.00 seconds.
# -- Epoch 127
# Norm: 1.78, NNZs: 30, Bias: -0.197000, T: 40386, Avg. loss: 0.055460
# Total training time: 0.00 seconds.
# -- Epoch 128
# Norm: 1.79, NNZs: 30, Bias: -0.197000, T: 40704, Avg. loss: 0.055249
# Total training time: 0.00 seconds.
# -- Epoch 129
# Norm: 1.79, NNZs: 30, Bias: -0.198000, T: 41022, Avg. loss: 0.055387
# Total training time: 0.00 seconds.
# -- Epoch 130
# Norm: 1.79, NNZs: 30, Bias: -0.197000, T: 41340, Avg. loss: 0.055331
# Total training time: 0.00 seconds.
# -- Epoch 131
# Norm: 1.80, NNZs: 30, Bias: -0.196000, T: 41658, Avg. loss: 0.055155
# Total training time: 0.00 seconds.
# -- Epoch 132
# Norm: 1.80, NNZs: 30, Bias: -0.197000, T: 41976, Avg. loss: 0.055063
# Total training time: 0.00 seconds.
# -- Epoch 133
# Norm: 1.80, NNZs: 30, Bias: -0.197000, T: 42294, Avg. loss: 0.054995
# Total training time: 0.00 seconds.
# Convergence after 133 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 0.43, NNZs: 30, Bias: -0.081000, T: 318, Avg. loss: 0.387753
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.52, NNZs: 30, Bias: -0.114000, T: 636, Avg. loss: 0.190031
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.59, NNZs: 30, Bias: -0.138000, T: 954, Avg. loss: 0.158732
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.64, NNZs: 30, Bias: -0.156000, T: 1272, Avg. loss: 0.142550
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.69, NNZs: 30, Bias: -0.173000, T: 1590, Avg. loss: 0.130166
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.74, NNZs: 30, Bias: -0.186000, T: 1908, Avg. loss: 0.120574
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.78, NNZs: 30, Bias: -0.197000, T: 2226, Avg. loss: 0.112548
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.82, NNZs: 30, Bias: -0.206000, T: 2544, Avg. loss: 0.105688
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.85, NNZs: 30, Bias: -0.216000, T: 2862, Avg. loss: 0.099620
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.88, NNZs: 30, Bias: -0.227000, T: 3180, Avg. loss: 0.095023
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.91, NNZs: 30, Bias: -0.235000, T: 3498, Avg. loss: 0.091058
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 0.94, NNZs: 30, Bias: -0.242000, T: 3816, Avg. loss: 0.087437
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 0.97, NNZs: 30, Bias: -0.249000, T: 4134, Avg. loss: 0.084487
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 0.99, NNZs: 30, Bias: -0.255000, T: 4452, Avg. loss: 0.081872
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 1.01, NNZs: 30, Bias: -0.259000, T: 4770, Avg. loss: 0.079575
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 1.03, NNZs: 30, Bias: -0.263000, T: 5088, Avg. loss: 0.077763
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 1.05, NNZs: 30, Bias: -0.266000, T: 5406, Avg. loss: 0.076114
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 1.07, NNZs: 30, Bias: -0.269000, T: 5724, Avg. loss: 0.074491
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 1.09, NNZs: 30, Bias: -0.271000, T: 6042, Avg. loss: 0.072869
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 1.11, NNZs: 30, Bias: -0.273000, T: 6360, Avg. loss: 0.071215
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 1.12, NNZs: 30, Bias: -0.275000, T: 6678, Avg. loss: 0.070096
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 1.14, NNZs: 30, Bias: -0.275000, T: 6996, Avg. loss: 0.068879
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 1.16, NNZs: 30, Bias: -0.277000, T: 7314, Avg. loss: 0.067426
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 1.17, NNZs: 30, Bias: -0.278000, T: 7632, Avg. loss: 0.066702
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 1.19, NNZs: 30, Bias: -0.280000, T: 7950, Avg. loss: 0.065558
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 1.21, NNZs: 30, Bias: -0.280000, T: 8268, Avg. loss: 0.064480
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 1.22, NNZs: 30, Bias: -0.280000, T: 8586, Avg. loss: 0.063442
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 1.24, NNZs: 30, Bias: -0.282000, T: 8904, Avg. loss: 0.062344
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 1.25, NNZs: 30, Bias: -0.283000, T: 9222, Avg. loss: 0.061554
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 1.27, NNZs: 30, Bias: -0.285000, T: 9540, Avg. loss: 0.060548
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 1.28, NNZs: 30, Bias: -0.287000, T: 9858, Avg. loss: 0.059640
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 1.30, NNZs: 30, Bias: -0.289000, T: 10176, Avg. loss: 0.058891
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 1.31, NNZs: 30, Bias: -0.290000, T: 10494, Avg. loss: 0.057985
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 1.33, NNZs: 30, Bias: -0.293000, T: 10812, Avg. loss: 0.057235
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 1.34, NNZs: 30, Bias: -0.294000, T: 11130, Avg. loss: 0.056349
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 1.35, NNZs: 30, Bias: -0.296000, T: 11448, Avg. loss: 0.055680
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 1.37, NNZs: 30, Bias: -0.297000, T: 11766, Avg. loss: 0.054874
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 1.38, NNZs: 30, Bias: -0.298000, T: 12084, Avg. loss: 0.054344
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 1.39, NNZs: 30, Bias: -0.298000, T: 12402, Avg. loss: 0.053539
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 1.40, NNZs: 30, Bias: -0.297000, T: 12720, Avg. loss: 0.053061
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 1.41, NNZs: 30, Bias: -0.295000, T: 13038, Avg. loss: 0.052597
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 1.42, NNZs: 30, Bias: -0.295000, T: 13356, Avg. loss: 0.052016
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 1.43, NNZs: 30, Bias: -0.294000, T: 13674, Avg. loss: 0.051611
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 1.44, NNZs: 30, Bias: -0.296000, T: 13992, Avg. loss: 0.051139
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 1.46, NNZs: 30, Bias: -0.296000, T: 14310, Avg. loss: 0.050676
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 1.47, NNZs: 30, Bias: -0.297000, T: 14628, Avg. loss: 0.050292
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 1.47, NNZs: 30, Bias: -0.298000, T: 14946, Avg. loss: 0.049794
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 1.48, NNZs: 30, Bias: -0.298000, T: 15264, Avg. loss: 0.049468
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 1.49, NNZs: 30, Bias: -0.297000, T: 15582, Avg. loss: 0.049107
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 1.50, NNZs: 30, Bias: -0.299000, T: 15900, Avg. loss: 0.048726
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 1.51, NNZs: 30, Bias: -0.296000, T: 16218, Avg. loss: 0.048418
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 1.51, NNZs: 30, Bias: -0.294000, T: 16536, Avg. loss: 0.048201
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 1.52, NNZs: 30, Bias: -0.293000, T: 16854, Avg. loss: 0.047931
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 1.53, NNZs: 30, Bias: -0.292000, T: 17172, Avg. loss: 0.047693
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 1.54, NNZs: 30, Bias: -0.289000, T: 17490, Avg. loss: 0.047401
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 1.54, NNZs: 30, Bias: -0.287000, T: 17808, Avg. loss: 0.047207
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 1.55, NNZs: 30, Bias: -0.285000, T: 18126, Avg. loss: 0.046956
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 1.56, NNZs: 30, Bias: -0.282000, T: 18444, Avg. loss: 0.046683
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 1.57, NNZs: 30, Bias: -0.280000, T: 18762, Avg. loss: 0.046473
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 1.57, NNZs: 30, Bias: -0.277000, T: 19080, Avg. loss: 0.046218
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 1.58, NNZs: 30, Bias: -0.274000, T: 19398, Avg. loss: 0.045990
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 1.59, NNZs: 30, Bias: -0.273000, T: 19716, Avg. loss: 0.045754
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 1.60, NNZs: 30, Bias: -0.270000, T: 20034, Avg. loss: 0.045528
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 1.60, NNZs: 30, Bias: -0.267000, T: 20352, Avg. loss: 0.045263
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 1.61, NNZs: 30, Bias: -0.265000, T: 20670, Avg. loss: 0.045067
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 1.62, NNZs: 30, Bias: -0.263000, T: 20988, Avg. loss: 0.044796
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 1.62, NNZs: 30, Bias: -0.262000, T: 21306, Avg. loss: 0.044620
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 1.63, NNZs: 30, Bias: -0.259000, T: 21624, Avg. loss: 0.044409
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 1.64, NNZs: 30, Bias: -0.258000, T: 21942, Avg. loss: 0.044236
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 1.64, NNZs: 30, Bias: -0.255000, T: 22260, Avg. loss: 0.044029
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 1.65, NNZs: 30, Bias: -0.254000, T: 22578, Avg. loss: 0.043853
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 1.66, NNZs: 30, Bias: -0.253000, T: 22896, Avg. loss: 0.043649
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 1.66, NNZs: 30, Bias: -0.251000, T: 23214, Avg. loss: 0.043391
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 1.67, NNZs: 30, Bias: -0.249000, T: 23532, Avg. loss: 0.043319
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 1.67, NNZs: 30, Bias: -0.247000, T: 23850, Avg. loss: 0.043116
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 1.68, NNZs: 30, Bias: -0.246000, T: 24168, Avg. loss: 0.042874
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 1.69, NNZs: 30, Bias: -0.245000, T: 24486, Avg. loss: 0.042755
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 1.69, NNZs: 30, Bias: -0.243000, T: 24804, Avg. loss: 0.042566
# Total training time: 0.00 seconds.
# -- Epoch 79
# Norm: 1.70, NNZs: 30, Bias: -0.241000, T: 25122, Avg. loss: 0.042427
# Total training time: 0.00 seconds.
# -- Epoch 80
# Norm: 1.70, NNZs: 30, Bias: -0.240000, T: 25440, Avg. loss: 0.042294
# Total training time: 0.00 seconds.
# -- Epoch 81
# Norm: 1.71, NNZs: 30, Bias: -0.239000, T: 25758, Avg. loss: 0.042146
# Total training time: 0.00 seconds.
# -- Epoch 82
# Norm: 1.71, NNZs: 30, Bias: -0.240000, T: 26076, Avg. loss: 0.042026
# Total training time: 0.00 seconds.
# -- Epoch 83
# Norm: 1.72, NNZs: 30, Bias: -0.238000, T: 26394, Avg. loss: 0.041889
# Total training time: 0.00 seconds.
# -- Epoch 84
# Norm: 1.72, NNZs: 30, Bias: -0.237000, T: 26712, Avg. loss: 0.041866
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 1.73, NNZs: 30, Bias: -0.236000, T: 27030, Avg. loss: 0.041732
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 1.73, NNZs: 30, Bias: -0.235000, T: 27348, Avg. loss: 0.041557
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 1.74, NNZs: 30, Bias: -0.236000, T: 27666, Avg. loss: 0.041537
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 1.74, NNZs: 30, Bias: -0.236000, T: 27984, Avg. loss: 0.041406
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 1.74, NNZs: 30, Bias: -0.235000, T: 28302, Avg. loss: 0.041355
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 1.75, NNZs: 30, Bias: -0.234000, T: 28620, Avg. loss: 0.041303
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 1.75, NNZs: 30, Bias: -0.233000, T: 28938, Avg. loss: 0.041211
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 1.76, NNZs: 30, Bias: -0.234000, T: 29256, Avg. loss: 0.041052
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 1.76, NNZs: 30, Bias: -0.234000, T: 29574, Avg. loss: 0.041076
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 1.77, NNZs: 30, Bias: -0.234000, T: 29892, Avg. loss: 0.040992
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 1.77, NNZs: 30, Bias: -0.233000, T: 30210, Avg. loss: 0.040890
# Total training time: 0.00 seconds.
# -- Epoch 96
# Norm: 1.77, NNZs: 30, Bias: -0.232000, T: 30528, Avg. loss: 0.040850
# Total training time: 0.00 seconds.
# -- Epoch 97
# Norm: 1.78, NNZs: 30, Bias: -0.231000, T: 30846, Avg. loss: 0.040774
# Total training time: 0.00 seconds.
# -- Epoch 98
# Norm: 1.78, NNZs: 30, Bias: -0.231000, T: 31164, Avg. loss: 0.040709
# Total training time: 0.00 seconds.
# -- Epoch 99
# Norm: 1.79, NNZs: 30, Bias: -0.229000, T: 31482, Avg. loss: 0.040679
# Total training time: 0.00 seconds.
# -- Epoch 100
# Norm: 1.79, NNZs: 30, Bias: -0.228000, T: 31800, Avg. loss: 0.040602
# Total training time: 0.00 seconds.
# Convergence after 100 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 0.43, NNZs: 30, Bias: -0.081000, T: 318, Avg. loss: 0.395474
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.52, NNZs: 30, Bias: -0.117000, T: 636, Avg. loss: 0.201775
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.59, NNZs: 30, Bias: -0.141000, T: 954, Avg. loss: 0.171093
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.65, NNZs: 30, Bias: -0.158000, T: 1272, Avg. loss: 0.153302
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.70, NNZs: 30, Bias: -0.171000, T: 1590, Avg. loss: 0.141179
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.75, NNZs: 30, Bias: -0.183000, T: 1908, Avg. loss: 0.131429
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.79, NNZs: 30, Bias: -0.193000, T: 2226, Avg. loss: 0.124231
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.82, NNZs: 30, Bias: -0.202000, T: 2544, Avg. loss: 0.118942
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.85, NNZs: 30, Bias: -0.207000, T: 2862, Avg. loss: 0.114064
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.88, NNZs: 30, Bias: -0.217000, T: 3180, Avg. loss: 0.110037
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.91, NNZs: 30, Bias: -0.224000, T: 3498, Avg. loss: 0.106512
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 0.93, NNZs: 30, Bias: -0.232000, T: 3816, Avg. loss: 0.102993
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 0.96, NNZs: 30, Bias: -0.239000, T: 4134, Avg. loss: 0.099750
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 0.98, NNZs: 30, Bias: -0.245000, T: 4452, Avg. loss: 0.097265
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 1.00, NNZs: 30, Bias: -0.250000, T: 4770, Avg. loss: 0.095180
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 1.02, NNZs: 30, Bias: -0.254000, T: 5088, Avg. loss: 0.093198
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 1.04, NNZs: 30, Bias: -0.255000, T: 5406, Avg. loss: 0.091425
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 1.06, NNZs: 30, Bias: -0.260000, T: 5724, Avg. loss: 0.090100
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 1.08, NNZs: 30, Bias: -0.263000, T: 6042, Avg. loss: 0.088623
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 1.09, NNZs: 30, Bias: -0.264000, T: 6360, Avg. loss: 0.087282
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 1.11, NNZs: 30, Bias: -0.266000, T: 6678, Avg. loss: 0.086297
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 1.12, NNZs: 30, Bias: -0.267000, T: 6996, Avg. loss: 0.085371
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 1.14, NNZs: 30, Bias: -0.269000, T: 7314, Avg. loss: 0.084103
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 1.15, NNZs: 30, Bias: -0.270000, T: 7632, Avg. loss: 0.083365
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 1.17, NNZs: 30, Bias: -0.272000, T: 7950, Avg. loss: 0.082381
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 1.18, NNZs: 30, Bias: -0.272000, T: 8268, Avg. loss: 0.081419
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 1.20, NNZs: 30, Bias: -0.275000, T: 8586, Avg. loss: 0.080194
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 1.21, NNZs: 30, Bias: -0.277000, T: 8904, Avg. loss: 0.079705
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 1.22, NNZs: 30, Bias: -0.278000, T: 9222, Avg. loss: 0.079140
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 1.23, NNZs: 30, Bias: -0.278000, T: 9540, Avg. loss: 0.078462
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 1.24, NNZs: 30, Bias: -0.280000, T: 9858, Avg. loss: 0.077910
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 1.25, NNZs: 30, Bias: -0.284000, T: 10176, Avg. loss: 0.077216
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 1.26, NNZs: 30, Bias: -0.285000, T: 10494, Avg. loss: 0.077077
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 1.27, NNZs: 30, Bias: -0.287000, T: 10812, Avg. loss: 0.076329
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 1.28, NNZs: 30, Bias: -0.286000, T: 11130, Avg. loss: 0.076092
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 1.29, NNZs: 30, Bias: -0.288000, T: 11448, Avg. loss: 0.075484
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 1.30, NNZs: 30, Bias: -0.287000, T: 11766, Avg. loss: 0.074964
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 1.31, NNZs: 30, Bias: -0.289000, T: 12084, Avg. loss: 0.074497
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 1.32, NNZs: 30, Bias: -0.290000, T: 12402, Avg. loss: 0.073932
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 1.33, NNZs: 30, Bias: -0.292000, T: 12720, Avg. loss: 0.073616
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 1.34, NNZs: 30, Bias: -0.293000, T: 13038, Avg. loss: 0.072970
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 1.35, NNZs: 30, Bias: -0.295000, T: 13356, Avg. loss: 0.072532
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 1.36, NNZs: 30, Bias: -0.294000, T: 13674, Avg. loss: 0.072157
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 1.37, NNZs: 30, Bias: -0.295000, T: 13992, Avg. loss: 0.071799
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 1.38, NNZs: 30, Bias: -0.297000, T: 14310, Avg. loss: 0.071303
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 1.39, NNZs: 30, Bias: -0.296000, T: 14628, Avg. loss: 0.070890
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 1.40, NNZs: 30, Bias: -0.297000, T: 14946, Avg. loss: 0.070691
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 1.41, NNZs: 30, Bias: -0.297000, T: 15264, Avg. loss: 0.070277
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 1.42, NNZs: 30, Bias: -0.296000, T: 15582, Avg. loss: 0.069958
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 1.42, NNZs: 30, Bias: -0.294000, T: 15900, Avg. loss: 0.069777
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 1.43, NNZs: 30, Bias: -0.293000, T: 16218, Avg. loss: 0.069545
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 1.43, NNZs: 30, Bias: -0.292000, T: 16536, Avg. loss: 0.069231
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 1.44, NNZs: 30, Bias: -0.291000, T: 16854, Avg. loss: 0.069096
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 1.45, NNZs: 30, Bias: -0.288000, T: 17172, Avg. loss: 0.068810
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 1.45, NNZs: 30, Bias: -0.289000, T: 17490, Avg. loss: 0.068709
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 1.46, NNZs: 30, Bias: -0.289000, T: 17808, Avg. loss: 0.068446
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 1.46, NNZs: 30, Bias: -0.289000, T: 18126, Avg. loss: 0.068253
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 1.47, NNZs: 30, Bias: -0.289000, T: 18444, Avg. loss: 0.068047
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 1.47, NNZs: 30, Bias: -0.288000, T: 18762, Avg. loss: 0.067812
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 1.48, NNZs: 30, Bias: -0.288000, T: 19080, Avg. loss: 0.067665
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 1.48, NNZs: 30, Bias: -0.288000, T: 19398, Avg. loss: 0.067473
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 1.49, NNZs: 30, Bias: -0.287000, T: 19716, Avg. loss: 0.067192
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 1.49, NNZs: 30, Bias: -0.287000, T: 20034, Avg. loss: 0.067053
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 1.50, NNZs: 30, Bias: -0.286000, T: 20352, Avg. loss: 0.066892
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 1.50, NNZs: 30, Bias: -0.284000, T: 20670, Avg. loss: 0.066764
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 1.51, NNZs: 30, Bias: -0.283000, T: 20988, Avg. loss: 0.066461
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 1.51, NNZs: 30, Bias: -0.283000, T: 21306, Avg. loss: 0.066400
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 1.52, NNZs: 30, Bias: -0.283000, T: 21624, Avg. loss: 0.066148
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 1.52, NNZs: 30, Bias: -0.283000, T: 21942, Avg. loss: 0.065929
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 1.53, NNZs: 30, Bias: -0.280000, T: 22260, Avg. loss: 0.065982
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 1.53, NNZs: 30, Bias: -0.279000, T: 22578, Avg. loss: 0.065632
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 1.54, NNZs: 30, Bias: -0.279000, T: 22896, Avg. loss: 0.065627
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 1.54, NNZs: 30, Bias: -0.278000, T: 23214, Avg. loss: 0.065144
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 1.55, NNZs: 30, Bias: -0.277000, T: 23532, Avg. loss: 0.065377
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 1.55, NNZs: 30, Bias: -0.276000, T: 23850, Avg. loss: 0.065085
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 1.56, NNZs: 30, Bias: -0.275000, T: 24168, Avg. loss: 0.065000
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 1.56, NNZs: 30, Bias: -0.275000, T: 24486, Avg. loss: 0.064750
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 1.57, NNZs: 30, Bias: -0.273000, T: 24804, Avg. loss: 0.064661
# Total training time: 0.00 seconds.
# -- Epoch 79
# Norm: 1.57, NNZs: 30, Bias: -0.272000, T: 25122, Avg. loss: 0.064465
# Total training time: 0.00 seconds.
# -- Epoch 80
# Norm: 1.57, NNZs: 30, Bias: -0.272000, T: 25440, Avg. loss: 0.064261
# Total training time: 0.00 seconds.
# -- Epoch 81
# Norm: 1.58, NNZs: 30, Bias: -0.271000, T: 25758, Avg. loss: 0.064153
# Total training time: 0.00 seconds.
# -- Epoch 82
# Norm: 1.58, NNZs: 30, Bias: -0.272000, T: 26076, Avg. loss: 0.064030
# Total training time: 0.00 seconds.
# -- Epoch 83
# Norm: 1.59, NNZs: 30, Bias: -0.271000, T: 26394, Avg. loss: 0.063900
# Total training time: 0.00 seconds.
# -- Epoch 84
# Norm: 1.60, NNZs: 30, Bias: -0.271000, T: 26712, Avg. loss: 0.063764
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 1.60, NNZs: 30, Bias: -0.269000, T: 27030, Avg. loss: 0.063577
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 1.60, NNZs: 30, Bias: -0.269000, T: 27348, Avg. loss: 0.063474
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 1.61, NNZs: 30, Bias: -0.268000, T: 27666, Avg. loss: 0.063322
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 1.61, NNZs: 30, Bias: -0.268000, T: 27984, Avg. loss: 0.063149
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 1.62, NNZs: 30, Bias: -0.266000, T: 28302, Avg. loss: 0.063075
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 1.62, NNZs: 30, Bias: -0.267000, T: 28620, Avg. loss: 0.062889
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 1.63, NNZs: 30, Bias: -0.266000, T: 28938, Avg. loss: 0.062839
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 1.63, NNZs: 30, Bias: -0.264000, T: 29256, Avg. loss: 0.062591
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 1.64, NNZs: 30, Bias: -0.264000, T: 29574, Avg. loss: 0.062504
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 1.64, NNZs: 30, Bias: -0.263000, T: 29892, Avg. loss: 0.062534
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 1.65, NNZs: 30, Bias: -0.262000, T: 30210, Avg. loss: 0.062314
# Total training time: 0.00 seconds.
# -- Epoch 96
# Norm: 1.65, NNZs: 30, Bias: -0.260000, T: 30528, Avg. loss: 0.062219
# Total training time: 0.00 seconds.
# -- Epoch 97
# Norm: 1.66, NNZs: 30, Bias: -0.260000, T: 30846, Avg. loss: 0.062162
# Total training time: 0.00 seconds.
# -- Epoch 98
# Norm: 1.66, NNZs: 30, Bias: -0.258000, T: 31164, Avg. loss: 0.061816
# Total training time: 0.00 seconds.
# -- Epoch 99
# Norm: 1.66, NNZs: 30, Bias: -0.258000, T: 31482, Avg. loss: 0.062069
# Total training time: 0.00 seconds.
# -- Epoch 100
# Norm: 1.67, NNZs: 30, Bias: -0.258000, T: 31800, Avg. loss: 0.061607
# Total training time: 0.00 seconds.
# -- Epoch 101
# Norm: 1.67, NNZs: 30, Bias: -0.259000, T: 32118, Avg. loss: 0.061840
# Total training time: 0.00 seconds.
# -- Epoch 102
# Norm: 1.68, NNZs: 30, Bias: -0.259000, T: 32436, Avg. loss: 0.061488
# Total training time: 0.00 seconds.
# -- Epoch 103
# Norm: 1.68, NNZs: 30, Bias: -0.260000, T: 32754, Avg. loss: 0.061340
# Total training time: 0.00 seconds.
# -- Epoch 104
# Norm: 1.69, NNZs: 30, Bias: -0.259000, T: 33072, Avg. loss: 0.061407
# Total training time: 0.00 seconds.
# -- Epoch 105
# Norm: 1.69, NNZs: 30, Bias: -0.260000, T: 33390, Avg. loss: 0.061158
# Total training time: 0.00 seconds.
# -- Epoch 106
# Norm: 1.69, NNZs: 30, Bias: -0.260000, T: 33708, Avg. loss: 0.061168
# Total training time: 0.00 seconds.
# -- Epoch 107
# Norm: 1.70, NNZs: 30, Bias: -0.262000, T: 34026, Avg. loss: 0.060958
# Total training time: 0.00 seconds.
# -- Epoch 108
# Norm: 1.70, NNZs: 30, Bias: -0.260000, T: 34344, Avg. loss: 0.060889
# Total training time: 0.00 seconds.
# -- Epoch 109
# Norm: 1.70, NNZs: 30, Bias: -0.260000, T: 34662, Avg. loss: 0.060953
# Total training time: 0.00 seconds.
# -- Epoch 110
# Norm: 1.71, NNZs: 30, Bias: -0.260000, T: 34980, Avg. loss: 0.060732
# Total training time: 0.00 seconds.
# -- Epoch 111
# Norm: 1.71, NNZs: 30, Bias: -0.261000, T: 35298, Avg. loss: 0.060867
# Total training time: 0.00 seconds.
# -- Epoch 112
# Norm: 1.71, NNZs: 30, Bias: -0.260000, T: 35616, Avg. loss: 0.060596
# Total training time: 0.00 seconds.
# -- Epoch 113
# Norm: 1.71, NNZs: 30, Bias: -0.261000, T: 35934, Avg. loss: 0.060549
# Total training time: 0.00 seconds.
# -- Epoch 114
# Norm: 1.72, NNZs: 30, Bias: -0.263000, T: 36252, Avg. loss: 0.060487
# Total training time: 0.00 seconds.
# -- Epoch 115
# Norm: 1.72, NNZs: 30, Bias: -0.261000, T: 36570, Avg. loss: 0.060433
# Total training time: 0.00 seconds.
# -- Epoch 116
# Norm: 1.72, NNZs: 30, Bias: -0.262000, T: 36888, Avg. loss: 0.060455
# Total training time: 0.00 seconds.
# -- Epoch 117
# Norm: 1.73, NNZs: 30, Bias: -0.262000, T: 37206, Avg. loss: 0.060424
# Total training time: 0.00 seconds.
# Convergence after 117 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 0.42, NNZs: 30, Bias: -0.080000, T: 319, Avg. loss: 0.397188
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.53, NNZs: 30, Bias: -0.114000, T: 638, Avg. loss: 0.193743
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.60, NNZs: 30, Bias: -0.137000, T: 957, Avg. loss: 0.158574
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.65, NNZs: 30, Bias: -0.155000, T: 1276, Avg. loss: 0.142613
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.70, NNZs: 30, Bias: -0.168000, T: 1595, Avg. loss: 0.131954
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.75, NNZs: 30, Bias: -0.179000, T: 1914, Avg. loss: 0.123488
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.79, NNZs: 30, Bias: -0.191000, T: 2233, Avg. loss: 0.116081
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.82, NNZs: 30, Bias: -0.204000, T: 2552, Avg. loss: 0.109908
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.85, NNZs: 30, Bias: -0.215000, T: 2871, Avg. loss: 0.104687
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.88, NNZs: 30, Bias: -0.225000, T: 3190, Avg. loss: 0.100846
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.91, NNZs: 30, Bias: -0.235000, T: 3509, Avg. loss: 0.097454
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 0.93, NNZs: 30, Bias: -0.247000, T: 3828, Avg. loss: 0.094187
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 0.96, NNZs: 30, Bias: -0.255000, T: 4147, Avg. loss: 0.091383
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 0.98, NNZs: 30, Bias: -0.265000, T: 4466, Avg. loss: 0.088813
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 1.00, NNZs: 30, Bias: -0.272000, T: 4785, Avg. loss: 0.086472
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 1.02, NNZs: 30, Bias: -0.279000, T: 5104, Avg. loss: 0.084642
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 1.04, NNZs: 30, Bias: -0.286000, T: 5423, Avg. loss: 0.082984
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 1.06, NNZs: 30, Bias: -0.291000, T: 5742, Avg. loss: 0.081604
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 1.08, NNZs: 30, Bias: -0.295000, T: 6061, Avg. loss: 0.079977
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 1.10, NNZs: 30, Bias: -0.301000, T: 6380, Avg. loss: 0.078615
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 1.12, NNZs: 30, Bias: -0.305000, T: 6699, Avg. loss: 0.077337
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 1.13, NNZs: 30, Bias: -0.308000, T: 7018, Avg. loss: 0.076168
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 1.15, NNZs: 30, Bias: -0.311000, T: 7337, Avg. loss: 0.075205
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 1.16, NNZs: 30, Bias: -0.315000, T: 7656, Avg. loss: 0.074427
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 1.17, NNZs: 30, Bias: -0.320000, T: 7975, Avg. loss: 0.073613
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 1.18, NNZs: 30, Bias: -0.324000, T: 8294, Avg. loss: 0.072824
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 1.20, NNZs: 30, Bias: -0.326000, T: 8613, Avg. loss: 0.072311
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 1.21, NNZs: 30, Bias: -0.329000, T: 8932, Avg. loss: 0.071554
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 1.22, NNZs: 30, Bias: -0.332000, T: 9251, Avg. loss: 0.070861
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 1.23, NNZs: 30, Bias: -0.333000, T: 9570, Avg. loss: 0.070183
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 1.24, NNZs: 30, Bias: -0.335000, T: 9889, Avg. loss: 0.069673
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 1.25, NNZs: 30, Bias: -0.337000, T: 10208, Avg. loss: 0.069175
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 1.26, NNZs: 30, Bias: -0.340000, T: 10527, Avg. loss: 0.068637
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 1.27, NNZs: 30, Bias: -0.340000, T: 10846, Avg. loss: 0.068318
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 1.28, NNZs: 30, Bias: -0.340000, T: 11165, Avg. loss: 0.067915
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 1.29, NNZs: 30, Bias: -0.341000, T: 11484, Avg. loss: 0.067506
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 1.30, NNZs: 30, Bias: -0.341000, T: 11803, Avg. loss: 0.067068
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 1.31, NNZs: 30, Bias: -0.340000, T: 12122, Avg. loss: 0.066596
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 1.32, NNZs: 30, Bias: -0.339000, T: 12441, Avg. loss: 0.066500
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 1.33, NNZs: 30, Bias: -0.342000, T: 12760, Avg. loss: 0.065942
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 1.34, NNZs: 30, Bias: -0.341000, T: 13079, Avg. loss: 0.065777
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 1.34, NNZs: 30, Bias: -0.340000, T: 13398, Avg. loss: 0.065388
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 1.35, NNZs: 30, Bias: -0.340000, T: 13717, Avg. loss: 0.065098
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 1.36, NNZs: 30, Bias: -0.338000, T: 14036, Avg. loss: 0.064674
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 1.37, NNZs: 30, Bias: -0.338000, T: 14355, Avg. loss: 0.064266
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 1.38, NNZs: 30, Bias: -0.338000, T: 14674, Avg. loss: 0.063917
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 1.38, NNZs: 30, Bias: -0.338000, T: 14993, Avg. loss: 0.063853
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 1.39, NNZs: 30, Bias: -0.336000, T: 15312, Avg. loss: 0.063577
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 1.40, NNZs: 30, Bias: -0.335000, T: 15631, Avg. loss: 0.063234
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 1.41, NNZs: 30, Bias: -0.334000, T: 15950, Avg. loss: 0.062763
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 1.41, NNZs: 30, Bias: -0.333000, T: 16269, Avg. loss: 0.062673
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 1.42, NNZs: 30, Bias: -0.331000, T: 16588, Avg. loss: 0.062489
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 1.43, NNZs: 30, Bias: -0.331000, T: 16907, Avg. loss: 0.062249
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 1.44, NNZs: 30, Bias: -0.329000, T: 17226, Avg. loss: 0.061952
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 1.44, NNZs: 30, Bias: -0.328000, T: 17545, Avg. loss: 0.061698
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 1.45, NNZs: 30, Bias: -0.328000, T: 17864, Avg. loss: 0.061414
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 1.46, NNZs: 30, Bias: -0.326000, T: 18183, Avg. loss: 0.061216
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 1.46, NNZs: 30, Bias: -0.326000, T: 18502, Avg. loss: 0.061003
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 1.47, NNZs: 30, Bias: -0.324000, T: 18821, Avg. loss: 0.060747
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 1.48, NNZs: 30, Bias: -0.324000, T: 19140, Avg. loss: 0.060439
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 1.48, NNZs: 30, Bias: -0.324000, T: 19459, Avg. loss: 0.060261
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 1.49, NNZs: 30, Bias: -0.322000, T: 19778, Avg. loss: 0.060040
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 1.50, NNZs: 30, Bias: -0.323000, T: 20097, Avg. loss: 0.059760
# Total training time: 0.00 seconds.
# -- Epoch 64
# ...
# -- Epoch 192
# Norm: 2.15, NNZs: 30, Bias: -0.325000, T: 61248, Avg. loss: 0.042610
# Total training time: 0.00 seconds.
# -- Epoch 193
# Norm: 2.15, NNZs: 30, Bias: -0.323000, T: 61567, Avg. loss: 0.042352
# Total training time: 0.00 seconds.
# -- Epoch 194
# Norm: 2.15, NNZs: 30, Bias: -0.324000, T: 61886, Avg. loss: 0.042342
# Total training time: 0.00 seconds.
# -- Epoch 195
# Norm: 2.16, NNZs: 30, Bias: -0.326000, T: 62205, Avg. loss: 0.042175
# Total training time: 0.00 seconds.
# -- Epoch 196
# Norm: 2.16, NNZs: 30, Bias: -0.324000, T: 62524, Avg. loss: 0.042226
# Total training time: 0.00 seconds.
# -- Epoch 197
# Norm: 2.16, NNZs: 30, Bias: -0.324000, T: 62843, Avg. loss: 0.042004
# Total training time: 0.00 seconds.
# -- Epoch 198
# Norm: 2.17, NNZs: 30, Bias: -0.323000, T: 63162, Avg. loss: 0.042163
# Total training time: 0.00 seconds.
# -- Epoch 199
# Norm: 2.17, NNZs: 30, Bias: -0.326000, T: 63481, Avg. loss: 0.041924
# Total training time: 0.00 seconds.
# -- Epoch 200
# Norm: 2.17, NNZs: 30, Bias: -0.325000, T: 63800, Avg. loss: 0.041972
# Total training time: 0.00 seconds.
# -- Epoch 201
# Norm: 2.18, NNZs: 30, Bias: -0.325000, T: 64119, Avg. loss: 0.041785
# Total training time: 0.00 seconds.
# -- Epoch 202
# Norm: 2.18, NNZs: 30, Bias: -0.324000, T: 64438, Avg. loss: 0.041661
# Total training time: 0.00 seconds.
# -- Epoch 203
# Norm: 2.18, NNZs: 30, Bias: -0.324000, T: 64757, Avg. loss: 0.041917
# Total training time: 0.00 seconds.
# -- Epoch 204
# Norm: 2.19, NNZs: 30, Bias: -0.326000, T: 65076, Avg. loss: 0.041583
# Total training time: 0.00 seconds.
# -- Epoch 205
# Norm: 2.19, NNZs: 30, Bias: -0.325000, T: 65395, Avg. loss: 0.041589
# Total training time: 0.00 seconds.
# -- Epoch 206
# Norm: 2.19, NNZs: 30, Bias: -0.328000, T: 65714, Avg. loss: 0.041534
# Total training time: 0.00 seconds.
# -- Epoch 207
# Norm: 2.20, NNZs: 30, Bias: -0.328000, T: 66033, Avg. loss: 0.041547
# Total training time: 0.00 seconds.
# Convergence after 207 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 0.42, NNZs: 30, Bias: -0.081000, T: 319, Avg. loss: 0.401251
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.53, NNZs: 30, Bias: -0.121000, T: 638, Avg. loss: 0.191444
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.60, NNZs: 30, Bias: -0.148000, T: 957, Avg. loss: 0.157462
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.65, NNZs: 30, Bias: -0.171000, T: 1276, Avg. loss: 0.138593
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.70, NNZs: 30, Bias: -0.190000, T: 1595, Avg. loss: 0.127766
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.75, NNZs: 30, Bias: -0.206000, T: 1914, Avg. loss: 0.118577
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.79, NNZs: 30, Bias: -0.221000, T: 2233, Avg. loss: 0.111655
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.82, NNZs: 30, Bias: -0.232000, T: 2552, Avg. loss: 0.105871
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.85, NNZs: 30, Bias: -0.241000, T: 2871, Avg. loss: 0.101765
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.88, NNZs: 30, Bias: -0.249000, T: 3190, Avg. loss: 0.098207
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.90, NNZs: 30, Bias: -0.256000, T: 3509, Avg. loss: 0.095109
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 0.93, NNZs: 30, Bias: -0.262000, T: 3828, Avg. loss: 0.092035
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 0.95, NNZs: 30, Bias: -0.265000, T: 4147, Avg. loss: 0.089587
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 0.97, NNZs: 30, Bias: -0.267000, T: 4466, Avg. loss: 0.086996
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 1.00, NNZs: 30, Bias: -0.270000, T: 4785, Avg. loss: 0.085851
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 1.02, NNZs: 30, Bias: -0.273000, T: 5104, Avg. loss: 0.083723
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 1.04, NNZs: 30, Bias: -0.277000, T: 5423, Avg. loss: 0.081695
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 1.05, NNZs: 30, Bias: -0.281000, T: 5742, Avg. loss: 0.080609
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 1.07, NNZs: 30, Bias: -0.285000, T: 6061, Avg. loss: 0.079249
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 1.09, NNZs: 30, Bias: -0.290000, T: 6380, Avg. loss: 0.077910
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 1.10, NNZs: 30, Bias: -0.292000, T: 6699, Avg. loss: 0.076812
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 1.12, NNZs: 30, Bias: -0.293000, T: 7018, Avg. loss: 0.075790
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 1.13, NNZs: 30, Bias: -0.294000, T: 7337, Avg. loss: 0.074924
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 1.15, NNZs: 30, Bias: -0.295000, T: 7656, Avg. loss: 0.074106
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 1.16, NNZs: 30, Bias: -0.296000, T: 7975, Avg. loss: 0.073319
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 1.17, NNZs: 30, Bias: -0.297000, T: 8294, Avg. loss: 0.072573
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 1.18, NNZs: 30, Bias: -0.297000, T: 8613, Avg. loss: 0.071926
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 1.20, NNZs: 30, Bias: -0.298000, T: 8932, Avg. loss: 0.071177
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 1.21, NNZs: 30, Bias: -0.299000, T: 9251, Avg. loss: 0.070436
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 1.22, NNZs: 30, Bias: -0.299000, T: 9570, Avg. loss: 0.069680
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 1.23, NNZs: 30, Bias: -0.298000, T: 9889, Avg. loss: 0.069059
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 1.24, NNZs: 30, Bias: -0.298000, T: 10208, Avg. loss: 0.068404
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 1.25, NNZs: 30, Bias: -0.299000, T: 10527, Avg. loss: 0.067670
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 1.27, NNZs: 30, Bias: -0.298000, T: 10846, Avg. loss: 0.067293
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 1.27, NNZs: 30, Bias: -0.299000, T: 11165, Avg. loss: 0.066542
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 1.28, NNZs: 30, Bias: -0.298000, T: 11484, Avg. loss: 0.066249
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 1.29, NNZs: 30, Bias: -0.295000, T: 11803, Avg. loss: 0.065682
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 1.30, NNZs: 30, Bias: -0.296000, T: 12122, Avg. loss: 0.065123
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 1.31, NNZs: 30, Bias: -0.294000, T: 12441, Avg. loss: 0.064907
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 1.32, NNZs: 30, Bias: -0.293000, T: 12760, Avg. loss: 0.064478
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 1.33, NNZs: 30, Bias: -0.293000, T: 13079, Avg. loss: 0.064194
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 1.34, NNZs: 30, Bias: -0.290000, T: 13398, Avg. loss: 0.063819
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 1.34, NNZs: 30, Bias: -0.288000, T: 13717, Avg. loss: 0.063390
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 1.35, NNZs: 30, Bias: -0.286000, T: 14036, Avg. loss: 0.063071
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 1.36, NNZs: 30, Bias: -0.285000, T: 14355, Avg. loss: 0.062792
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 1.37, NNZs: 30, Bias: -0.284000, T: 14674, Avg. loss: 0.062470
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 1.38, NNZs: 30, Bias: -0.283000, T: 14993, Avg. loss: 0.062116
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 1.38, NNZs: 30, Bias: -0.281000, T: 15312, Avg. loss: 0.061801
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 1.39, NNZs: 30, Bias: -0.280000, T: 15631, Avg. loss: 0.061439
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 1.40, NNZs: 30, Bias: -0.279000, T: 15950, Avg. loss: 0.061090
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 1.40, NNZs: 30, Bias: -0.277000, T: 16269, Avg. loss: 0.060889
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 1.41, NNZs: 30, Bias: -0.276000, T: 16588, Avg. loss: 0.060595
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 1.42, NNZs: 30, Bias: -0.277000, T: 16907, Avg. loss: 0.060244
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 1.43, NNZs: 30, Bias: -0.274000, T: 17226, Avg. loss: 0.059926
# Total training time: 0.00 seconds.
# -- Epoch 55
# Norm: 1.43, NNZs: 30, Bias: -0.272000, T: 17545, Avg. loss: 0.059674
# Total training time: 0.00 seconds.
# -- Epoch 56
# Norm: 1.44, NNZs: 30, Bias: -0.272000, T: 17864, Avg. loss: 0.059398
# Total training time: 0.00 seconds.
# -- Epoch 57
# Norm: 1.45, NNZs: 30, Bias: -0.270000, T: 18183, Avg. loss: 0.059036
# Total training time: 0.00 seconds.
# -- Epoch 58
# Norm: 1.45, NNZs: 30, Bias: -0.271000, T: 18502, Avg. loss: 0.058746
# Total training time: 0.00 seconds.
# -- Epoch 59
# Norm: 1.46, NNZs: 30, Bias: -0.270000, T: 18821, Avg. loss: 0.058537
# Total training time: 0.00 seconds.
# -- Epoch 60
# Norm: 1.46, NNZs: 30, Bias: -0.269000, T: 19140, Avg. loss: 0.058385
# Total training time: 0.00 seconds.
# -- Epoch 61
# Norm: 1.47, NNZs: 30, Bias: -0.269000, T: 19459, Avg. loss: 0.058066
# Total training time: 0.00 seconds.
# -- Epoch 62
# Norm: 1.48, NNZs: 30, Bias: -0.270000, T: 19778, Avg. loss: 0.057669
# Total training time: 0.00 seconds.
# -- Epoch 63
# Norm: 1.48, NNZs: 30, Bias: -0.268000, T: 20097, Avg. loss: 0.057504
# Total training time: 0.00 seconds.
# -- Epoch 64
# Norm: 1.49, NNZs: 30, Bias: -0.266000, T: 20416, Avg. loss: 0.057175
# Total training time: 0.00 seconds.
# -- Epoch 65
# Norm: 1.49, NNZs: 30, Bias: -0.266000, T: 20735, Avg. loss: 0.056894
# Total training time: 0.00 seconds.
# -- Epoch 66
# Norm: 1.50, NNZs: 30, Bias: -0.265000, T: 21054, Avg. loss: 0.056888
# Total training time: 0.00 seconds.
# -- Epoch 67
# Norm: 1.51, NNZs: 30, Bias: -0.265000, T: 21373, Avg. loss: 0.056580
# Total training time: 0.00 seconds.
# -- Epoch 68
# Norm: 1.51, NNZs: 30, Bias: -0.263000, T: 21692, Avg. loss: 0.056195
# Total training time: 0.00 seconds.
# -- Epoch 69
# Norm: 1.52, NNZs: 30, Bias: -0.261000, T: 22011, Avg. loss: 0.056179
# Total training time: 0.00 seconds.
# -- Epoch 70
# Norm: 1.52, NNZs: 30, Bias: -0.257000, T: 22330, Avg. loss: 0.055788
# Total training time: 0.00 seconds.
# -- Epoch 71
# Norm: 1.53, NNZs: 30, Bias: -0.255000, T: 22649, Avg. loss: 0.055587
# Total training time: 0.00 seconds.
# -- Epoch 72
# Norm: 1.53, NNZs: 30, Bias: -0.255000, T: 22968, Avg. loss: 0.055398
# Total training time: 0.00 seconds.
# -- Epoch 73
# Norm: 1.54, NNZs: 30, Bias: -0.254000, T: 23287, Avg. loss: 0.055436
# Total training time: 0.00 seconds.
# -- Epoch 74
# Norm: 1.54, NNZs: 30, Bias: -0.252000, T: 23606, Avg. loss: 0.054939
# Total training time: 0.00 seconds.
# -- Epoch 75
# Norm: 1.55, NNZs: 30, Bias: -0.250000, T: 23925, Avg. loss: 0.055050
# Total training time: 0.00 seconds.
# -- Epoch 76
# Norm: 1.55, NNZs: 30, Bias: -0.248000, T: 24244, Avg. loss: 0.054801
# Total training time: 0.00 seconds.
# -- Epoch 77
# Norm: 1.56, NNZs: 30, Bias: -0.246000, T: 24563, Avg. loss: 0.054505
# Total training time: 0.00 seconds.
# -- Epoch 78
# Norm: 1.56, NNZs: 30, Bias: -0.245000, T: 24882, Avg. loss: 0.054355
# Total training time: 0.00 seconds.
# -- Epoch 79
# Norm: 1.57, NNZs: 30, Bias: -0.243000, T: 25201, Avg. loss: 0.054015
# Total training time: 0.00 seconds.
# -- Epoch 80
# Norm: 1.57, NNZs: 30, Bias: -0.241000, T: 25520, Avg. loss: 0.054038
# Total training time: 0.00 seconds.
# -- Epoch 81
# Norm: 1.58, NNZs: 30, Bias: -0.240000, T: 25839, Avg. loss: 0.053386
# Total training time: 0.00 seconds.
# -- Epoch 82
# Norm: 1.58, NNZs: 30, Bias: -0.239000, T: 26158, Avg. loss: 0.053638
# Total training time: 0.00 seconds.
# -- Epoch 83
# Norm: 1.59, NNZs: 30, Bias: -0.237000, T: 26477, Avg. loss: 0.053391
# Total training time: 0.00 seconds.
# -- Epoch 84
# Norm: 1.59, NNZs: 30, Bias: -0.235000, T: 26796, Avg. loss: 0.053146
# Total training time: 0.00 seconds.
# -- Epoch 85
# Norm: 1.60, NNZs: 30, Bias: -0.234000, T: 27115, Avg. loss: 0.053024
# Total training time: 0.00 seconds.
# -- Epoch 86
# Norm: 1.61, NNZs: 30, Bias: -0.234000, T: 27434, Avg. loss: 0.052865
# Total training time: 0.00 seconds.
# -- Epoch 87
# Norm: 1.61, NNZs: 30, Bias: -0.233000, T: 27753, Avg. loss: 0.052938
# Total training time: 0.00 seconds.
# -- Epoch 88
# Norm: 1.62, NNZs: 30, Bias: -0.231000, T: 28072, Avg. loss: 0.052461
# Total training time: 0.00 seconds.
# -- Epoch 89
# Norm: 1.62, NNZs: 30, Bias: -0.229000, T: 28391, Avg. loss: 0.052367
# Total training time: 0.00 seconds.
# -- Epoch 90
# Norm: 1.63, NNZs: 30, Bias: -0.227000, T: 28710, Avg. loss: 0.052336
# Total training time: 0.00 seconds.
# -- Epoch 91
# Norm: 1.63, NNZs: 30, Bias: -0.226000, T: 29029, Avg. loss: 0.052337
# Total training time: 0.00 seconds.
# -- Epoch 92
# Norm: 1.64, NNZs: 30, Bias: -0.225000, T: 29348, Avg. loss: 0.051917
# Total training time: 0.00 seconds.
# -- Epoch 93
# Norm: 1.64, NNZs: 30, Bias: -0.225000, T: 29667, Avg. loss: 0.051754
# Total training time: 0.00 seconds.
# -- Epoch 94
# Norm: 1.65, NNZs: 30, Bias: -0.224000, T: 29986, Avg. loss: 0.051587
# Total training time: 0.00 seconds.
# -- Epoch 95
# Norm: 1.65, NNZs: 30, Bias: -0.224000, T: 30305, Avg. loss: 0.051431
# Total training time: 0.00 seconds.
# -- Epoch 96
# Norm: 1.66, NNZs: 30, Bias: -0.223000, T: 30624, Avg. loss: 0.051672
# Total training time: 0.00 seconds.
# -- Epoch 97
# Norm: 1.66, NNZs: 30, Bias: -0.221000, T: 30943, Avg. loss: 0.051246
# Total training time: 0.00 seconds.
# -- Epoch 98
# Norm: 1.67, NNZs: 30, Bias: -0.219000, T: 31262, Avg. loss: 0.050994
# Total training time: 0.00 seconds.
# -- Epoch 99
# Norm: 1.67, NNZs: 30, Bias: -0.219000, T: 31581, Avg. loss: 0.050743
# Total training time: 0.00 seconds.
# -- Epoch 100
# Norm: 1.67, NNZs: 30, Bias: -0.219000, T: 31900, Avg. loss: 0.051165
# Total training time: 0.00 seconds.
# -- Epoch 101
# Norm: 1.68, NNZs: 30, Bias: -0.218000, T: 32219, Avg. loss: 0.050729
# Total training time: 0.00 seconds.
# -- Epoch 102
# Norm: 1.68, NNZs: 30, Bias: -0.219000, T: 32538, Avg. loss: 0.050337
# Total training time: 0.00 seconds.
# -- Epoch 103
# Norm: 1.69, NNZs: 30, Bias: -0.220000, T: 32857, Avg. loss: 0.050780
# Total training time: 0.00 seconds.
# -- Epoch 104
# Norm: 1.69, NNZs: 30, Bias: -0.220000, T: 33176, Avg. loss: 0.050269
# Total training time: 0.00 seconds.
# -- Epoch 105
# Norm: 1.70, NNZs: 30, Bias: -0.218000, T: 33495, Avg. loss: 0.050398
# Total training time: 0.00 seconds.
# -- Epoch 106
# Norm: 1.70, NNZs: 30, Bias: -0.216000, T: 33814, Avg. loss: 0.049859
# Total training time: 0.00 seconds.
# -- Epoch 107
# Norm: 1.70, NNZs: 30, Bias: -0.214000, T: 34133, Avg. loss: 0.050046
# Total training time: 0.00 seconds.
# -- Epoch 108
# Norm: 1.71, NNZs: 30, Bias: -0.213000, T: 34452, Avg. loss: 0.050212
# Total training time: 0.00 seconds.
# -- Epoch 109
# Norm: 1.71, NNZs: 30, Bias: -0.212000, T: 34771, Avg. loss: 0.049842
# Total training time: 0.00 seconds.
# -- Epoch 110
# Norm: 1.72, NNZs: 30, Bias: -0.213000, T: 35090, Avg. loss: 0.049726
# Total training time: 0.00 seconds.
# -- Epoch 111
# Norm: 1.72, NNZs: 30, Bias: -0.213000, T: 35409, Avg. loss: 0.049661
# Total training time: 0.00 seconds.
# -- Epoch 112
# Norm: 1.72, NNZs: 30, Bias: -0.214000, T: 35728, Avg. loss: 0.049458
# Total training time: 0.00 seconds.
# -- Epoch 113
# Norm: 1.73, NNZs: 30, Bias: -0.213000, T: 36047, Avg. loss: 0.049379
# Total training time: 0.00 seconds.
# -- Epoch 114
# Norm: 1.73, NNZs: 30, Bias: -0.215000, T: 36366, Avg. loss: 0.049119
# Total training time: 0.00 seconds.
# -- Epoch 115
# Norm: 1.74, NNZs: 30, Bias: -0.214000, T: 36685, Avg. loss: 0.048971
# Total training time: 0.00 seconds.
# -- Epoch 116
# Norm: 1.74, NNZs: 30, Bias: -0.215000, T: 37004, Avg. loss: 0.049035
# Total training time: 0.00 seconds.
# -- Epoch 117
# Norm: 1.74, NNZs: 30, Bias: -0.214000, T: 37323, Avg. loss: 0.049171
# Total training time: 0.00 seconds.
# -- Epoch 118
# Norm: 1.75, NNZs: 30, Bias: -0.213000, T: 37642, Avg. loss: 0.049159
# Total training time: 0.00 seconds.
# -- Epoch 119
# Norm: 1.75, NNZs: 30, Bias: -0.213000, T: 37961, Avg. loss: 0.048947
# Total training time: 0.00 seconds.
# -- Epoch 120
# Norm: 1.75, NNZs: 30, Bias: -0.214000, T: 38280, Avg. loss: 0.049111
# Total training time: 0.00 seconds.
# Convergence after 120 epochs took 0.00 seconds
# 📊 MÉTRIQUES DE CALIBRATION:
# ECE: 0.0654 | Brier Score: 0.0204
# ✅ Modèle calibré sauvegardé: 'sgd_svm_calibre.pkl'

# %% [markdown]
# # DSO2: Precision Medical Risk Stratification

# %%
print("=" * 70)
print("PRECISION MEDICAL RISK STRATIFICATION - 5 TIER SYSTEM")
print("=" * 70)

# Define precise medical risk thresholds
risk_thresholds = {
    'BENIGN_LIKELY': 0.10,    # <10% - Very low probability
    'LOW_SUSPICION': 0.20,    # 10-25% - Low suspicion  
    'INDETERMINATE': 0.40,    # 25-50% - Uncertain, needs workup
    'SUSPICIOUS': 0.70,       # 50-75% - High suspicion
    'HIGHLY_SUSPICIOUS': 0.90 # 75-90% - Very high suspicion
    # >90% - Almost certain malignancy
}

print("🎯 PRECISION RISK STRATIFICATION THRESHOLDS:")
thresholds_display = [
    ('🟢 BENIGN LIKELY', '< 0.10', 'Very low probability'),
    ('🟡 LOW SUSPICION', '0.10 - 0.20', 'Low suspicion'), 
    ('🟠 INDETERMINATE', '0.20 - 0.40', 'Uncertain, needs workup'),
    ('🔴 SUSPICIOUS', '0.40 - 0.70', 'High suspicion'),
    ('🚨 HIGHLY SUSPICIOUS', '0.70 - 0.90', 'Very high suspicion'),
    ('⚡ PROBABLE MALIGNANCY', '> 0.90', 'Almost certain malignancy')
]

for level, prob_range, description in thresholds_display:
    print(f"   {level:<20} {prob_range:<15} {description}")
# Out:
# ======================================================================
# PRECISION MEDICAL RISK STRATIFICATION - 5 TIER SYSTEM
# ======================================================================
# 🎯 PRECISION RISK STRATIFICATION THRESHOLDS:
#    🟢 BENIGN LIKELY      < 0.10          Very low probability
#    🟡 LOW SUSPICION      0.10 - 0.20     Low suspicion
#    🟠 INDETERMINATE      0.20 - 0.40     Uncertain, needs workup
#    🔴 SUSPICIOUS         0.40 - 0.70     High suspicion
#    🚨 HIGHLY SUSPICIOUS  0.70 - 0.90     Very high suspicion
#    ⚡ PROBABLE MALIGNANCY > 0.90          Almost certain malignancy

# %%
# Apply precision medical risk stratification
def precision_risk_stratification(probability):
    if probability < risk_thresholds['BENIGN_LIKELY']:
        return 'BENIGN_LIKELY', '🟢 BENIGN LIKELY'
    elif probability < risk_thresholds['LOW_SUSPICION']:
        return 'LOW_SUSPICION', '🟡 LOW SUSPICION'
    elif probability < risk_thresholds['INDETERMINATE']:
        return 'INDETERMINATE', '🟠 INDETERMINATE' 
    elif probability < risk_thresholds['HIGHLY_SUSPICIOUS']:
        return 'SUSPICIOUS', '🔴 SUSPICIOUS'
    elif probability < 0.90:
        return 'HIGHLY_SUSPICIOUS', '🚨 HIGHLY SUSPICIOUS'
    else:
        return 'PROBABLE_MALIGNANCY', '⚡ PROBABLE MALIGNANCY'

# Apply precision stratification
precision_risks = []
precision_zones = []
for prob in y_proba_calibrated:
    risk_level, zone = precision_risk_stratification(prob)
    precision_risks.append(risk_level)
    precision_zones.append(zone)

precision_risks = np.array(precision_risks)
precision_zones = np.array(precision_zones)

print("📊 PRECISION RISK DISTRIBUTION:")
risk_order = ['BENIGN_LIKELY', 'LOW_SUSPICION', 'INDETERMINATE', 'SUSPICIOUS', 'HIGHLY_SUSPICIOUS', 'PROBABLE_MALIGNANCY']
risk_counts = pd.Series(precision_risks).value_counts().reindex(risk_order, fill_value=0)

for risk_level in risk_order:
    count = risk_counts[risk_level]
    percentage = (count / len(y_test)) * 100
    display_name = risk_level.replace('_', ' ').title()
    print(f"   {display_name:<20}: {count:>3} cases ({percentage:5.1f}%)")
# Out:
# 📊 PRECISION RISK DISTRIBUTION:
#    Benign Likely       :  83 cases ( 48.5%)
#    Low Suspicion       :  16 cases (  9.4%)
#    Indeterminate       :   9 cases (  5.3%)
#    Suspicious          :  12 cases (  7.0%)
#    Highly Suspicious   :   0 cases (  0.0%)
#    Probable Malignancy :  51 cases ( 29.8%)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ============================================================================
# 1. ANALYSE DES FACTEURS DE RISQUE (Feature Importance)
# ============================================================================

# On récupère les coefficients (poids) du modèle SVM
# Note : On utilise X.columns si X est un DataFrame. Sinon, remplace par tes noms de colonnes.
feature_importance = pd.DataFrame({
    'Feature': X.columns,  # Assure-toi que X est bien ton DataFrame initial
    'Weight': sgd_svm.coef_[0]
})

# On calcule l'importance absolue pour le tri (car un poids très négatif est aussi important)
feature_importance['Absolute_Importance'] = feature_importance['Weight'].abs()

# On prend les 10 critères les plus influents
top_features = feature_importance.sort_values(by='Absolute_Importance', ascending=False).head(10)

# Visualisation
plt.figure(figsize=(10, 6))
# Couleur : Rose (Danger/Positif) vs Vert (Protecteur/Négatif)
colors = ['#ff1493' if x > 0 else '#51cf66' for x in top_features['Weight']]

sns.barplot(x='Weight', y='Feature', data=top_features, palette=colors)
plt.title("TOP 10 des caractéristiques qui influencent le modèle SVM")
plt.xlabel("Importance (Poids du coefficient)")
plt.axvline(x=0, color='black', linestyle='-', linewidth=0.5)
plt.show()

print("Interprétation : \n- Barres ROSES (droite) = Facteurs qui augmentent le risque de cancer.\n- Barres VERTES (gauche) = Facteurs qui indiquent plutôt un cas bénin.")
# Out:
# Interprétation :
# - Barres ROSES (droite) = Facteurs qui augmentent le risque de cancer.
# - Barres VERTES (gauche) = Facteurs qui indiquent plutôt un cas bénin.

# %%
 #Feature Distributions by Diagnosis
print("\n" + "=" * 70)
print("METHOD 3: FEATURE DISTRIBUTIONS - MALIGNANT vs BENIGN")
print("=" * 70)

# Analyze top 6 features from SGD SVM
top_6_features = feature_importance_sgd.head(6)['feature'].tolist()

print("🔍 Analyzing Distributions for Top 6 Features:")
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.ravel()

for i, feature in enumerate(top_6_features):
    # Separate malignant and benign cases
    benign_values = X[y == 0][feature]
    malignant_values = X[y == 1][feature]
    
    # Plot distributions
    axes[i].hist(benign_values, bins=20, alpha=0.7, label='Benign', color='blue', density=True)
    axes[i].hist(malignant_values, bins=20, alpha=0.7, label='Malignant', color='red', density=True)
    axes[i].set_title(f'{feature}\nDistribution by Diagnosis', fontweight='bold')
    axes[i].set_xlabel('Feature Value')
    axes[i].set_ylabel('Density')
    axes[i].legend()
    axes[i].grid(alpha=0.3)
    
    # Calculate and display separation metrics
    benign_mean = benign_values.mean()
    malignant_mean = malignant_values.mean()
    separation = malignant_mean - benign_mean
    axes[i].text(0.05, 0.95, f'Separation: {separation:.3f}', 
                transform=axes[i].transAxes, fontweight='bold',
                bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8))

plt.tight_layout()
plt.show()
# Out:
# ======================================================================
# METHOD 3: FEATURE DISTRIBUTIONS - MALIGNANT vs BENIGN
# ======================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 7
#       4 print("=" * 70)
#       6 # Analyze top 6 features from SGD SVM
# ----> 7 top_6_features = feature_importance_sgd.head(6)['feature'].tolist()
#       9 print("🔍 Analyzing Distributions for Top 6 Features:")
#      10 fig, axes = plt.subplots(2, 3, figsize=(18, 12))
#
# NameError: name 'feature_importance_sgd' is not defined

# %%
# Phase 1 Summary and Initial Findings
print("\n" + "=" * 70)
print("PHASE 1 SUMMARY: INITIAL CLINICAL INSIGHTS")
print("=" * 70)

# Combine results from all methods
combined_importance = pd.DataFrame({
    'feature': X.columns,
    'svm_weight_rank': feature_importance_sgd['abs_weight'].rank(ascending=False),
})

# Calculate consensus rank
combined_importance['consensus_rank'] = (
    combined_importance['svm_weight_rank'] 
) / 1

combined_importance = combined_importance.sort_values('consensus_rank')

print("🏆 TOP 10 FEATURES - CONSENSUS ACROSS ALL METHODS:")
top_10_consensus = combined_importance.head(10)[['feature', 'consensus_rank']]
print(tabulate(top_10_consensus, headers=['Feature', 'Consensus Rank'], 
               tablefmt='grid', floatfmt=".2f"))

# Identify strongest clinical indicators
print(f"\n🎯 STRONGEST CLINICAL INDICATORS (Phase 1):")
top_3_features = top_10_consensus.head(3)['feature'].tolist()
for i, feature in enumerate(top_3_features, 1):
    svm_weight = feature_importance_sgd[feature_importance_sgd['feature'] == feature]['weight'].iloc[0]
    
    print(f"   #{i}: {feature}")
    print(f"      • SVM Weight: {svm_weight:+.4f} ({'Malignant' if svm_weight > 0 else 'Benign'} indicator)")

print(f"\n🚀 READY FOR PHASE 2:")
print(f"   • Top features identified: {', '.join(top_3_features)}")
print(f"   • Strong statistical significance confirmed")
# Out:
# ======================================================================
# PHASE 1 SUMMARY: INITIAL CLINICAL INSIGHTS
# ======================================================================
# 🏆 TOP 10 FEATURES - CONSENSUS ACROSS ALL METHODS:
# +----+------------------------+------------------+
# |    | Feature                |   Consensus Rank |
# +====+========================+==================+
# | 10 | radius_mean            |             1.00 |
# +----+------------------------+------------------+
# | 21 | texture_mean           |             2.00 |
# +----+------------------------+------------------+
# |  7 | perimeter_mean         |             3.00 |
# +----+------------------------+------------------+
# | 28 | area_mean              |             4.00 |
# +----+------------------------+------------------+
# | 26 | smoothness_mean        |             5.00 |
# +----+------------------------+------------------+
# |  6 | compactness_mean       |             6.00 |
# +----+------------------------+------------------+
# | 13 | concavity_mean         |             7.00 |
# +----+------------------------+------------------+
# | 12 | concave points_mean    |             8.00 |
# +----+------------------------+------------------+
# | 23 | symmetry_mean          |             9.00 |
# +----+------------------------+------------------+
# | 24 | fractal_dimension_mean |            10.00 |
# +----+------------------------+------------------+
#
# 🎯 STRONGEST CLINICAL INDICATORS (Phase 1):
#    #1: radius_mean
#       • SVM Weight: +0.2754 (Malignant indicator)
#    #2: texture_mean
#       • SVM Weight: +0.2954 (Malignant indicator)
#    #3: perimeter_mean
#       • SVM Weight: +0.2525 (Malignant indicator)
#
# 🚀 READY FOR PHASE 2:
#    • Top features identified: radius_mean, texture_mean, perimeter_mean
#    • Strong statistical significance confirmed

# %%
print("=" * 70)
print("ANALYSE SHAP SIMPLIFIÉE - MODÈLE SGD SVM ORIGINAL")
print("=" * 70)

import shap

print("🔮 Calcul des valeurs SHAP avec le modèle SGD SVM original...")

# Utiliser le modèle SGD SVM original (non calibré) pour SHAP
explainer = shap.LinearExplainer(sgd_svm, X_train_scaled)

# Calculer les valeurs SHAP
shap_values = explainer(X_test_scaled)

print("✅ Analyse SHAP terminée!")

# 1. Summary Plot - Importance globale
print("\n📊 IMPORTANCE GLOBALE DES CARACTÉRISTIQUES (SHAP):")
plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test_scaled, feature_names=X.columns, show=False)
plt.title("Importance des Caractéristiques - Analyse SHAP\n(Plus rouge = plus de risque)", 
          fontweight='bold', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# ======================================================================
# ANALYSE SHAP SIMPLIFIÉE - MODÈLE SGD SVM ORIGINAL
# ======================================================================
# 🔮 Calcul des valeurs SHAP avec le modèle SGD SVM original...
# ✅ Analyse SHAP terminée!
#
# 📊 IMPORTANCE GLOBALE DES CARACTÉRISTIQUES (SHAP):

# %%
# 2. Analyse détaillée des valeurs SHAP
print("\n" + "=" * 70)
print("ANALYSE DÉTAILLÉE DES VALEURS SHAP")
print("=" * 70)

# Calculer l'importance moyenne SHAP
shap_importance = pd.DataFrame({
    'feature': X.columns,
    'shap_importance': np.abs(shap_values.values).mean(axis=0)
}).sort_values('shap_importance', ascending=False)

print("🎯 TOP 10 CARACTÉRISTIQUES PAR IMPORTANCE SHAP:")
print(tabulate(shap_importance.head(10), headers='keys', tablefmt='grid', floatfmt=".4f"))

# Vérifier la cohérence avec les autres méthodes
print("\n🔍 COMPARAISON DES MÉTHODES D'IMPORTANCE:")
comparison = pd.merge(
    feature_importance_sgd[['feature', 'abs_weight']], 
    shap_importance, 
    on='feature'
)
comparison = comparison.sort_values('shap_importance', ascending=False)
print(tabulate(comparison.head(10), headers='keys', tablefmt='grid', floatfmt=".4f"))
# Out:
# ======================================================================
# ANALYSE DÉTAILLÉE DES VALEURS SHAP
# ======================================================================
# 🎯 TOP 10 CARACTÉRISTIQUES PAR IMPORTANCE SHAP:
# +----+----------------------+-------------------+
# |    | feature              |   shap_importance |
# +====+======================+===================+
# |  7 | concave points_mean  |            0.5592 |
# +----+----------------------+-------------------+
# | 21 | texture_worst        |            0.5550 |
# +----+----------------------+-------------------+
# | 26 | concavity_worst      |            0.4852 |
# +----+----------------------+-------------------+
# | 28 | symmetry_worst       |            0.4414 |
# +----+----------------------+-------------------+
# | 10 | radius_se            |            0.4401 |
# +----+----------------------+-------------------+
# |  6 | concavity_mean       |            0.4376 |
# +----+----------------------+-------------------+
# | 27 | concave points_worst |            0.3444 |
# +----+----------------------+-------------------+
# | 20 | radius_worst         |            0.3314 |
# +----+----------------------+-------------------+
# | 23 | area_worst           |            0.3116 |
# +----+----------------------+-------------------+
# | 24 | smoothness_worst     |            0.3022 |
# +----+----------------------+-------------------+
#
# 🔍 COMPARAISON DES MÉTHODES D'IMPORTANCE:
# +----+----------------------+--------------+-------------------+
# |    | feature              |   abs_weight |   shap_importance |
# +====+======================+==============+===================+
# |  2 | concave points_mean  |       0.6279 |            0.5592 |
# +----+----------------------+--------------+-------------------+
# |  1 | texture_worst        |       0.6479 |            0.5550 |
# +----+----------------------+--------------+-------------------+
# |  4 | concavity_worst      |       0.5274 |            0.4852 |
# +----+----------------------+--------------+-------------------+
# |  3 | symmetry_worst       |       0.6055 |            0.4414 |
# +----+----------------------+--------------+-------------------+
# |  0 | radius_se            |       0.6503 |            0.4401 |
# +----+----------------------+--------------+-------------------+
# |  5 | concavity_mean       |       0.4994 |            0.4376 |
# +----+----------------------+--------------+-------------------+
# | 11 | concave points_worst |       0.3722 |            0.3444 |
# +----+----------------------+--------------+-------------------+
# | 10 | radius_worst         |       0.4036 |            0.3314 |
# +----+----------------------+--------------+-------------------+
# |  8 | area_worst           |       0.4046 |            0.3116 |
# +----+----------------------+--------------+-------------------+
# |  9 | smoothness_worst     |       0.4045 |            0.3022 |
# +----+----------------------+--------------+-------------------+

# %% [markdown]
# # 🏥 Interprétation Clinique SHAP
#
# ## **Top 3 Caractéristiques**
# - **Points concaves moyens** (0.5592) - Morphologie cellulaire
# - **Texture la plus dégradée** (0.5550) - Hétérogénéité tissulaire
# - **Concavité maximale** (0.4852) - Indentations tumorales
